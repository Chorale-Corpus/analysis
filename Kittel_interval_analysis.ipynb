# %% [markdown]
# # Kittel Data

# %%
from music21 import *
import copy
import collections
import itertools

kittelBundle = corpus.search('Kittel-24-Worksheets')
melBundle = corpus.search('melodic')

# %%
# pass in the function that extracts what we want, and the bundle of scores we want to analyse, coalesces the data
def getData(func, bundle):
    data = []
    for b in bundle:
        d = func(converter.parse(b))
        data.extend(d)
    counter=collections.Counter(data)
    for k,v in sorted(counter.items(), key=lambda x: -x[1]):
        print(k,',',v)

# m is the melody as a chord, b is the bass as a chord
# if either are empty return "R" to represent rest, otherwise return the interval
def getHarmony(m, b):
    if len(m) == 0 or len(b) == 0:
        return "R"
    else:
        return interval.Interval(m[0], b[0]).semiSimpleName
    
def getInterval(m, b):
    if len(m) == 0 or len(b) == 0:
        return "R"
    else:
        return interval.Interval(m[0], b[0]).directedName

# %% [markdown]
# ## 2 Half Note Segments

# %% [markdown]
# ### Melodic

# %%
def melody2HN(k):
    graceNotes = []
    for n in k.recurse().notes:
        if n.duration.isGrace:
            graceNotes.append(n)

    # remove grace notes  
    for grace in graceNotes:
        grace.activeSite.remove(grace)

    k_ = copy.deepcopy(k)
    k_c = k_.chordify()
    data = []
    for i in range(1, len(k_.parts[0].getElementsByClass('Measure')) + 1):
        k_mel = k_.measure(i).parts[0].asTimespans()
        mel = []
        off = k_.parts[0].measure(i).recurse().notes[0].offset

        # starting window
        mel.append(interval.Interval(k_mel.getVerticalityAt(off).toChord()[0],
                                     k_mel.getVerticalityAt(off + 2).toChord()[0]).directedName)
        data.append(mel.copy())
        off += 2

        # slide the window
        while off <= k_c.measure(i).notes[-1].offset - 2:
            mel.pop(0)
            mel.append(interval.Interval(k_mel.getVerticalityAt(off).toChord()[0],
                                         k_mel.getVerticalityAt(off + 2).toChord()[0]).directedName)
            data.append(mel.copy())
            off += 2
    data = map(lambda x: tuple(x), data)
    return data

# %%
getData(melody2HN, melBundle)
# Out:
# ('M-2',) , 213
# ('P1',) , 158
# ('M2',) , 141
# ('m-2',) , 87
# ('m2',) , 69
# ('m-3',) , 37
# ('m3',) , 26
# ('P4',) , 23
# ('M-3',) , 15
# ('M3',) , 14
# ('P5',) , 6
# ('P-4',) , 5
# ('P-5',) , 2

# %% [markdown]
# ### Melodic Phrase Ending

# %%
def melody2HNPhraseEnd(k):
    graceNotes = []
    for n in k.recurse().notes:
        if n.duration.isGrace:
            graceNotes.append(n)

    # remove grace notes  
    for grace in graceNotes:
        grace.activeSite.remove(grace)

    k_ = copy.deepcopy(k)
    k_c = k_.chordify()
    data = []
    for i in range(1, len(k_.parts[0].getElementsByClass('Measure')) + 1):
        k_mel = k_.measure(i).parts[0].asTimespans()
        mel = []
        off = k_c.measure(i).notes[-1].offset - 2

        # starting window
        mel.append(interval.Interval(k_mel.getVerticalityAt(off).toChord()[0],
                                     k_mel.getVerticalityAt(off + 2).toChord()[0]).directedName)
        data.append(mel.copy())
    data = map(lambda x: tuple(x), data)
    return data

# %%
getData(melody2HNPhraseEnd, melBundle)
# Out:
# ('M-2',) , 64
# ('m2',) , 21
# ('M2',) , 15
# ('m-2',) , 7
# ('P1',) , 6
# ('m-3',) , 4
# ('M-3',) , 2
# ('m3',) , 1

# %% [markdown]
# ### Full

# %%
# the func to be passed into getData, this is a sliding window of size two half notes in the melody,
# three quarter notes in the bass
def full2HN(k):
    graceNotes = []
    for n in k.recurse().notes:
        if n.duration.isGrace:
            graceNotes.append(n)

    # remove grace notes  
    for grace in graceNotes:
        grace.activeSite.remove(grace)

    k_ = copy.deepcopy(k)
    k_c = k_.chordify()
    data = []
    for i in range(1, len(k_.parts[0].getElementsByClass('Measure')) + 1):
        k_mel = k_.measure(i).parts[0].asTimespans()
        k_bass = k_.measure(i).parts[1].asTimespans()
        mel = []
        bass = []
        off = k_.parts[0].measure(i).recurse().notes[0].offset

        # starting window
        har_1 = getHarmony(k_mel.getVerticalityAt(off).toChord(),
                           k_bass.getVerticalityAt(off).toChord())
        mel.append(getInterval(k_mel.getVerticalityAt(off).toChord(),
                               k_mel.getVerticalityAt(off + 2).toChord()))
        bass.append(getInterval(k_bass.getVerticalityAt(off).toChord(),
                                k_bass.getVerticalityAt(off + 2).toChord()))
        har_2 = getHarmony(k_mel.getVerticalityAt(off + 2).toChord(),
                           k_bass.getVerticalityAt(off + 2).toChord())
        data.append((har_1, mel.copy(), bass.copy(), har_2))
        off += 2

        # slide the window
        while off <= k_c.measure(i).notes[-1].offset - 2:
            mel.pop(0)
            bass.pop(0)
            har_1 = getHarmony(k_mel.getVerticalityAt(off).toChord(),
                           k_bass.getVerticalityAt(off).toChord())
            mel.append(getInterval(k_mel.getVerticalityAt(off).toChord(),
                                   k_mel.getVerticalityAt(off + 2).toChord()))
            bass.append(getInterval(k_bass.getVerticalityAt(off).toChord(),
                                    k_bass.getVerticalityAt(off + 2).toChord()))
            har_2 = getHarmony(k_mel.getVerticalityAt(off + 2).toChord(),
                           k_bass.getVerticalityAt(off + 2).toChord())
            data.append((har_1, mel.copy(), bass.copy(), har_2))
            off += 2
    data = map(lambda x: (x[0], tuple(x[1]), tuple(x[2]), x[3]), data)
    return data

# %%
getData(full2HN, kittelBundle)
# Out:
# ('P5', ('M-2',), ('P-5',), 'P8') , 246
# ('M6', ('P1',), ('M2',), 'P5') , 153
# ('P5', ('P1',), ('P1',), 'P5') , 118
# ('m3', ('M2',), ('m2',), 'M3') , 116
# ('P5', ('M2',), ('P4',), 'M3') , 114
# ('m6', ('m-3',), ('m2',), 'M3') , 105
# ('M6', ('M2',), ('m-2',), 'P8') , 104
# ('m3', ('M-2',), ('m2',), 'P8') , 104
# ('P8', ('M-2',), ('m3',), 'P5') , 95
# ('M6', ('m2',), ('M-2',), 'P8') , 95
# ('m6', ('P1',), ('m2',), 'P5') , 92
# ('M6', ('M-2',), ('m-2',), 'm6') , 89
# ('M3', ('M-2',), ('P-4',), 'P5') , 88
# ('M3', ('m2',), ('P-5',), 'P8') , 88
# ('P5', ('M-2',), ('P4',), 'P8') , 79
# ('M3', ('M-2',), ('P5',), 'P5') , 76
# ('m6', ('m-2',), ('M-2',), 'M6') , 70
# ('M6', ('M-2',), ('M-2',), 'M6') , 69
# ('P8', ('M2',), ('M-2',), 'M3') , 66
# ('M2', ('P1',), ('m-2',), 'm3') , 64
# ('A4', ('m2',), ('m-2',), 'm6') , 61
# ('m3', ('m-2',), ('M2',), 'P8') , 61
# ('m6', ('M2',), ('M-2',), 'P8') , 58
# ('P5', ('M-2',), ('M2',), 'm3') , 57
# ('d5', ('M-2',), ('m2',), 'm3') , 57
# ('P5', ('M-2',), ('m-3',), 'm6') , 55
# ('M3', ('m2',), ('m-3',), 'm6') , 54
# ('M3', ('M2',), ('m-3',), 'M6') , 53
# ('P5', ('M-2',), ('M-3',), 'M6') , 53
# ('d5', ('m-2',), ('m2',), 'M3') , 48
# ('M3', ('M-2',), ('P1',), 'M2') , 48
# ('P8', ('M-2',), ('m2',), 'M6') , 48
# ('M3', ('M-2',), ('M2',), 'P8') , 46
# ('P8', ('M-2',), ('M2',), 'm6') , 46
# ('P5', ('P1',), ('m-2',), 'm6') , 45
# ('M6', ('M-2',), ('P1',), 'P5') , 44
# ('m3', ('m-2',), ('P-4',), 'P5') , 42
# ('M3', ('P1',), ('P1',), 'M3') , 42
# ('m6', ('m-2',), ('m3',), 'M3') , 42
# ('P5', ('M2',), ('P-5',), 'M3') , 42
# ('P5', ('P1',), ('P-8',), 'P5') , 41
# ('m3', ('M2',), ('M-3',), 'M6') , 39
# ('P8', ('m2',), ('M-2',), 'm3') , 38
# ('M3', ('M-2',), ('P-5',), 'M6') , 38
# ('P4', ('M2',), ('M-2',), 'M6') , 38
# ('P8', ('P1',), ('P4',), 'P5') , 37
# ('P8', ('P1',), ('P1',), 'P8') , 37
# ('m6', ('M2',), ('m2',), 'M6') , 36
# ('P8', ('m-3',), ('P4',), 'M3') , 35
# ('P5', ('m-2',), ('M2',), 'M3') , 34
# ('P8', ('M2',), ('m-2',), 'm3') , 33
# ('P5', ('M-2',), ('m2',), 'M3') , 33
# ('M3', ('m3',), ('m-2',), 'm6') , 32
# ('M6', ('M-2',), ('P-8',), 'P5') , 32
# ('M3', ('P1',), ('m-3',), 'P5') , 32
# ('m3', ('m-2',), ('P5',), 'P5') , 32
# ('P5', ('m3',), ('P-4',), 'm3') , 32
# ('M3', ('m2',), ('P4',), 'P8') , 32
# ('P8', ('P1',), ('m-3',), 'm3') , 32
# ('m3', ('P1',), ('M-3',), 'P5') , 32
# ('m3', ('m-2',), ('M-2',), 'M3') , 31
# ('P8', ('m-2',), ('M2',), 'M6') , 30
# ('P5', ('P1',), ('P-4',), 'P8') , 29
# ('P5', ('M2',), ('P1',), 'M6') , 28
# ('M6', ('M2',), ('M2',), 'M6') , 26
# ('m7', ('m-2',), ('P4',), 'M3') , 26
# ('m3', ('m2',), ('m2',), 'm3') , 26
# ('P8', ('M2',), ('P1',), 'M2') , 26
# ('M3', ('m2',), ('M2',), 'm3') , 25
# ('M3', ('M-2',), ('m-2',), 'm3') , 25
# ('P8', ('m-3',), ('M2',), 'P5') , 25
# ('P4', ('P1',), ('M-2',), 'P5') , 25
# ('m6', ('M2',), ('P-4',), 'm3') , 23
# ('P5', ('M2',), ('m-3',), 'P8') , 23
# ('m3', ('P1',), ('P1',), 'm3') , 23
# ('M3', ('M-2',), ('P4',), 'M6') , 23
# ('P5', ('P4',), ('m-3',), 'm3') , 23
# ('M3', ('P1',), ('M3',), 'P8') , 22
# ('M3', ('M2',), ('P1',), 'A4') , 22
# ('m3', ('M2',), ('M2',), 'm3') , 22
# ('m6', ('M-3',), ('m2',), 'm3') , 22
# ('P8', ('m-2',), ('P-4',), 'M3') , 22
# ('m3', ('P1',), ('P-4',), 'm6') , 21
# ('m3', ('P1',), ('m3',), 'P8') , 21
# ('M3', ('m2',), ('P1',), 'P4') , 21
# ('P4', ('m-2',), ('P1',), 'M3') , 20
# ('m6', ('P1',), ('M-3',), 'P8') , 20
# ('m3', ('P1',), ('M-2',), 'P4') , 20
# ('M6', ('M-2',), ('A1',), 'd5') , 20
# ('P5', ('M-2',), ('P1',), 'P4') , 20
# ('M3', ('M-2',), ('d-4',), 'd5') , 20
# ('m6', ('m-2',), ('P1',), 'P5') , 20
# ('M3', ('P1',), ('P8',), 'M3') , 19
# ('P8', ('M3',), ('P8',), 'M3') , 19
# ('m6', ('M-2',), ('M-2',), 'm6') , 19
# ('m6', ('m-2',), ('P-4',), 'P8') , 18
# ('M3', ('M2',), ('M2',), 'M3') , 18
# ('m3', ('m-3',), ('P-5',), 'P5') , 18
# ('M6', ('M-2',), ('M2',), 'P4') , 18
# ('P4', ('m-2',), ('P-8',), 'M3') , 18
# ('m3', ('M2',), ('P1',), 'P4') , 18
# ('m6', ('M3',), ('M-3',), 'M3') , 18
# ('m3', ('M2',), ('m-3',), 'm6') , 18
# ('m3', ('m-2',), ('P4',), 'M6') , 17
# ('P8', ('P5',), ('m-2',), 'm6') , 17
# ('m6', ('P1',), ('d1',), 'M6') , 17
# ('M3', ('m-2',), ('m-2',), 'M3') , 17
# ('P8', ('m-2',), ('M3',), 'P5') , 17
# ('M2', ('P4',), ('m-2',), 'm6') , 17
# ('M2', ('M2',), ('M-2',), 'A4') , 16
# ('P8', ('m-3',), ('P-5',), 'M3') , 16
# ('A2', ('m2',), ('m-2',), 'P4') , 16
# ('M6', ('P1',), ('P1',), 'M6') , 16
# ('m3', ('M-2',), ('M-2',), 'm3') , 16
# ('P4', ('M2',), ('m-2',), 'm6') , 16
# ('M3', ('M-3',), ('M3',), 'm6') , 16
# ('M6', ('m3',), ('m-3',), 'm3') , 15
# ('P5', ('P1',), ('M-2',), 'M6') , 15
# ('M3', ('m3',), ('M3',), 'm3') , 15
# ('M3', ('M-2',), ('d-5',), 'm6') , 15
# ('m6', ('M-2',), ('m3',), 'm3') , 15
# ('M6', ('m2',), ('M2',), 'm6') , 15
# ('m3', ('M2',), ('d1',), 'A4') , 14
# ('P5', ('m3',), ('M2',), 'm6') , 14
# ('P5', ('P1',), ('M2',), 'P4') , 14
# ('P8', ('P4',), ('m-3',), 'm6') , 14
# ('m6', ('P4',), ('M-2',), 'm3') , 14
# ('m3', ('M2',), ('M-2',), 'P5') , 14
# ('M3', ('M-3',), ('m-3',), 'm3') , 14
# ('P5', ('m3',), ('M-2',), 'P8') , 13
# ('P5', ('M2',), ('A1',), 'm6') , 13
# ('P8', ('m-2',), ('P5',), 'M3') , 13
# ('m6', ('P1',), ('P1',), 'm6') , 13
# ('m6', ('P1',), ('M-2',), 'm7') , 13
# ('A4', ('m2',), ('M-2',), 'M6') , 12
# ('m6', ('P1',), ('M2',), 'd5') , 12
# ('M3', ('P1',), ('m-6',), 'P8') , 12
# ('P5', ('m2',), ('P-5',), 'm3') , 12
# ('P8', ('P1',), ('M3',), 'm6') , 12
# ('d7', ('m-2',), ('m2',), 'P5') , 11
# ('m3', ('M3',), ('P1',), 'P5') , 11
# ('P4', ('P1',), ('M2',), 'm3') , 11
# ('P8', ('M-2',), ('P-4',), 'm3') , 11
# ('P8', ('P1',), ('M-3',), 'M3') , 11
# ('m7', ('m-2',), ('P-5',), 'M3') , 11
# ('m3', ('m-2',), ('P-5',), 'M6') , 11
# ('P8', ('M2',), ('P4',), 'M6') , 10
# ('M3', ('m3',), ('P-4',), 'P8') , 10
# ('A4', ('P1',), ('m-2',), 'P5') , 10
# ('P5', ('P1',), ('P5',), 'P8') , 10
# ('m6', ('M2',), ('m3',), 'P5') , 10
# ('M6', ('M-3',), ('M2',), 'm3') , 10
# ('M3', ('P1',), ('P-8',), 'M3') , 10
# ('M3', ('P4',), ('m-3',), 'P8') , 10
# ('P5', ('P1',), ('M3',), 'm3') , 10
# ('m3', ('m-3',), ('m3',), 'M6') , 10
# ('A4', ('M2',), ('m-2',), 'M6') , 10
# ('P8', ('M2',), ('P5',), 'P5') , 9
# ('M2', ('M2',), ('P1',), 'M3') , 9
# ('P8', ('P1',), ('M2',), 'm7') , 9
# ('m7', ('M-2',), ('P4',), 'm3') , 9
# ('M6', ('M2',), ('M3',), 'P5') , 9
# ('M6', ('P1',), ('P4',), 'M3') , 9
# ('M3', ('M-3',), ('m-6',), 'm6') , 9
# ('P8', ('M-3',), ('P4',), 'm3') , 9
# ('P8', ('P1',), ('M-2',), 'M2') , 9
# ('M3', ('M-3',), ('P1',), 'P8') , 9
# ('M6', ('P1',), ('m-2',), 'm7') , 9
# ('M3', ('M-3',), ('P-8',), 'P8') , 9
# ('P5', ('P4',), ('M-3',), 'M3') , 9
# ('M3', ('P4',), ('P1',), 'M6') , 9
# ('P5', ('m-3',), ('P1',), 'M3') , 9
# ('P8', ('M-2',), ('A1',), 'd7') , 8
# ('m3', ('m-3',), ('P1',), 'P8') , 8
# ('M3', ('m3',), ('M-2',), 'M6') , 8
# ('M3', ('m2',), ('m-2',), 'd5') , 8
# ('M3', ('m3',), ('P1',), 'P5') , 8
# ('P5', ('M3',), ('m-2',), 'P8') , 8
# ('m3', ('M3',), ('P-4',), 'P8') , 8
# ('M3', ('m3',), ('A1',), 'd5') , 8
# ('P5', ('m2',), ('P4',), 'm3') , 8
# ('m3', ('m-2',), ('P1',), 'M2') , 8
# ('P5', ('P1',), ('m3',), 'M3') , 8
# ('m3', ('M3',), ('M-2',), 'M6') , 8
# ('M3', ('P1',), ('P5',), 'M6') , 7
# ('M6', ('m-2',), ('m-2',), 'M6') , 7
# ('m3', ('P1',), ('P-5',), 'm7') , 7
# ('P8', ('M2',), ('d1',), 'A2') , 7
# ('P8', ('P4',), ('M2',), 'm3') , 7
# ('m7', ('m-2',), ('P1',), 'M6') , 7
# ('M2', ('P4',), ('M-2',), 'M6') , 7
# ('P8', ('P1',), ('P5',), 'P4') , 7
# ('M2', ('P1',), ('M-2',), 'M3') , 7
# ('m6', ('P1',), ('m3',), 'P4') , 7
# ('M6', ('m2',), ('P5',), 'm3') , 6
# ('P5', ('P1',), ('P4',), 'M2') , 6
# ('M6', ('m3',), ('M3',), 'm6') , 6
# ('P4', ('P1',), ('m-2',), 'd5') , 6
# ('m6', ('m-2',), ('m-2',), 'm6') , 6
# ('m3', ('m-3',), ('P4',), 'P5') , 6
# ('M3', ('P-4',), ('M3',), 'P5') , 6
# ('m7', ('M-2',), ('P-5',), 'm3') , 6
# ('P8', ('M3',), ('P1',), 'M3') , 6
# ('m3', ('m-3',), ('M-3',), 'M3') , 6
# ('d5', ('m-2',), ('M2',), 'm3') , 6
# ('P8', ('P4',), ('M-3',), 'M6') , 6
# ('P5', ('m-2',), ('m-3',), 'M6') , 6
# ('m3', ('P1',), ('P4',), 'm7') , 6
# ('m6', ('M2',), ('M2',), 'm6') , 6
# ('M3', ('M-3',), ('P-5',), 'P5') , 6
# ('P8', ('P1',), ('M6',), 'm3') , 6
# ('P8', ('m3',), ('P1',), 'm3') , 5
# ('m6', ('P5',), ('M-2',), 'P4') , 5
# ('P8', ('P1',), ('P-5',), 'P5') , 5
# ('m3', ('P1',), ('M-6',), 'P8') , 5
# ('M6', ('M-2',), ('M3',), 'm3') , 5
# ('M3', ('M-3',), ('P4',), 'P5') , 5
# ('m3', ('P-4',), ('m3',), 'P5') , 5
# ('P8', ('M3',), ('M-2',), 'A4') , 5
# ('m6', ('m-2',), ('P-8',), 'P5') , 5
# ('M3', ('m2',), ('m2',), 'M3') , 5
# ('P5', ('m2',), ('P1',), 'm6') , 5
# ('P8', ('m3',), ('P-4',), 'm6') , 5
# ('m6', ('P1',), ('P4',), 'm3') , 5
# ('M6', ('P1',), ('m-3',), 'P8') , 5
# ('M6', ('m-3',), ('m-3',), 'M6') , 5
# ('P4', ('m-2',), ('A1',), 'm3') , 5
# ('M3', ('m2',), ('M6',), 'm6') , 5
# ('P4', ('P1',), ('P1',), 'P4') , 5
# ('M3', ('M-3',), ('P8',), 'P8') , 5
# ('d5', ('P1',), ('m2',), 'P4') , 5
# ('M3', ('m3',), ('M2',), 'P4') , 4
# ('P8', ('M2',), ('P8',), 'M2') , 4
# ('M6', ('M-2',), ('P-4',), 'P8') , 4
# ('R', ('P5',), ('R',), 'R') , 4
# ('M6', ('M2',), ('P4',), 'A4') , 4
# ('m3', ('M-2',), ('P-4',), 'd5') , 4
# ('P8', ('M3',), ('m-3',), 'P5') , 4
# ('m3', ('M2',), ('m6',), 'M6') , 4
# ('P8', ('P1',), ('P-8',), 'P8') , 4
# ('P8', ('m-3',), ('P1',), 'M6') , 4
# ('P8', ('M-2',), ('P5',), 'm3') , 4
# ('P4', ('P1',), ('P-5',), 'P8') , 4
# ('P5', ('M2',), ('d-5',), 'm3') , 4
# ('m3', ('P4',), ('M2',), 'd5') , 4
# ('M6', ('m2',), ('P-4',), 'm3') , 4
# ('P8', ('m-2',), ('d-4',), 'm3') , 4
# ('P4', ('m-3',), ('P1',), 'M2') , 4
# ('M6', ('m2',), ('m2',), 'M6') , 4
# ('P4', ('M-2',), ('m3',), 'P8') , 4
# ('P4', ('m-2',), ('M3',), 'P8') , 4
# ('P8', ('P1',), ('d-5',), 'd5') , 4
# ('M6', ('m-3',), ('M2',), 'M3') , 4
# ('M6', ('M-2',), ('m3',), 'M3') , 4
# ('P8', ('M-2',), ('M-6',), 'P5') , 4
# ('P4', ('m-3',), ('M-2',), 'M3') , 4
# ('P8', ('P5',), ('M3',), 'm3') , 4
# ('M3', ('P1',), ('M-2',), 'A4') , 4
# ('R', ('P1',), ('R',), 'M3') , 4
# ('M2', ('P1',), ('M2',), 'P8') , 4
# ('P8', ('P1',), ('P-4',), 'P4') , 4
# ('m3', ('P-5',), ('m2',), 'P5') , 4
# ('m6', ('M2',), ('P4',), 'P4') , 4
# ('M6', ('P4',), ('M2',), 'P8') , 4
# ('P8', ('P-4',), ('m-2',), 'm6') , 4
# ('m3', ('m-2',), ('d-5',), 'm6') , 4
# ('M6', ('P4',), ('m-3',), 'P4') , 4
# ('m3', ('P-4',), ('M2',), 'm6') , 4
# ('P4', ('m-3',), ('P5',), 'P5') , 4
# ('m6', ('P-5',), ('M-2',), 'm3') , 3
# ('M7', ('M-2',), ('P1',), 'M6') , 3
# ('M3', ('m2',), ('M-3',), 'M6') , 3
# ('P8', ('m3',), ('M-2',), 'P4') , 3
# ('P5', ('m2',), ('m-2',), 'd7') , 3
# ('P8', ('P5',), ('P1',), 'P5') , 3
# ('M6', ('M-2',), ('m2',), 'A4') , 3
# ('m3', ('P1',), ('m-3',), 'd5') , 3
# ('m7', ('M-2',), ('m2',), 'P5') , 3
# ('m3', ('P5',), ('M2',), 'm6') , 3
# ('m3', ('P-4',), ('P-4',), 'm3') , 3
# ('m6', ('P-4',), ('M-3',), 'P5') , 3
# ('m3', ('m-3',), ('m-3',), 'm3') , 3
# ('P8', ('m-3',), ('A1',), 'm6') , 3
# ('P4', ('M2',), ('P-8',), 'P5') , 3
# ('m6', ('P-4',), ('m3',), 'P8') , 3
# ('m3', ('M2',), ('P-5',), 'P8') , 3
# ('P5', ('m3',), ('P1',), 'm7') , 3
# ('P4', ('P4',), ('M-2',), 'P8') , 3
# ('m6', ('m-3',), ('P1',), 'P4') , 3
# ('P5', ('P1',), ('A1',), 'd5') , 3
# ('P8', ('P4',), ('m2',), 'M3') , 3
# ('M3', ('M-2',), ('M-2',), 'M3') , 3
# ('m6', ('P4',), ('m2',), 'P8') , 3
# ('m3', ('P1',), ('m2',), 'M2') , 3
# ('P5', ('M-2',), ('m6',), 'M6') , 3
# ('m6', ('P5',), ('P-4',), 'm6') , 3
# ('M6', ('P4',), ('M-2',), 'M3') , 3
# ('m3', ('M3',), ('m3',), 'M3') , 3
# ('P8', ('P1',), ('P8',), 'P8') , 3
# ('m3', ('M-2',), ('P-5',), 'm6') , 3
# ('m3', ('P4',), ('M-3',), 'P8') , 3
# ('M3', ('P1',), ('m-2',), 'P4') , 3
# ('m3', ('m-2',), ('m-2',), 'm3') , 3
# ('M6', ('P4',), ('m-2',), 'm3') , 3
# ('m3', ('P1',), ('d1',), 'M3') , 3
# ('M2', ('M-2',), ('m3',), 'M6') , 3
# ('M3', ('m3',), ('m-6',), 'm3') , 3
# ('m6', ('m-3',), ('M-3',), 'M6') , 3
# ('R', ('m-3',), ('R',), 'M3') , 3
# ('M3', ('P4',), ('P4',), 'M3') , 3
# ('m7', ('m-2',), ('M2',), 'P5') , 3
# ('P8', ('M3',), ('P5',), 'M6') , 3
# ('R', ('M2',), ('R',), 'R') , 2
# ('R', ('M2',), ('R',), 'M3') , 2
# ('P4', ('P-5',), ('M2',), 'm6') , 2
# ('M3', ('m3',), ('R',), 'R') , 2
# ('M3', ('M2',), ('P8',), 'A4') , 2
# ('P8', ('M2',), ('M7',), 'm3') , 2
# ('m6', ('m-2',), ('R',), 'R') , 2
# ('R', ('M-2',), ('R',), 'M6') , 2
# ('R', ('P1',), ('R',), 'P5') , 2
# ('P5', ('P1',), ('m-6',), 'm3') , 2
# ('R', ('M-2',), ('R',), 'R') , 2
# ('R', ('P1',), ('R',), 'P8') , 2
# ('M6', ('M2',), ('P1',), 'M7') , 2
# ('M7', ('m2',), ('P1',), 'P8') , 2
# ('m3', ('M3',), ('m-2',), 'm6') , 2
# ('P8', ('P1',), ('m3',), 'M6') , 2
# ('m6', ('M-2',), ('M-3',), 'm7') , 2
# ('P5', ('M-2',), ('m-2',), 'd5') , 2
# ('m3', ('M-2',), ('m3',), 'm7') , 2
# ('P8', ('M-2',), ('P1',), 'm7') , 2
# ('M3', ('M-2',), ('M6',), 'P4') , 2
# ('m3', ('P-4',), ('M-2',), 'P8') , 2
# ('m6', ('m-3',), ('P4',), 'P8') , 2
# ('m3', ('m3',), ('M-2',), 'm6') , 2
# ('P5', ('P4',), ('M3',), 'm6') , 2
# ('m2', ('m-2',), ('P1',), 'P8') , 2
# ('P4', ('P1',), ('m3',), 'M2') , 2
# ('M6', ('M2',), ('d-4',), 'm3') , 2
# ('M6', ('M-2',), ('M7',), 'm6') , 2
# ('P5', ('P4',), ('P8',), 'P8') , 2
# ('m3', ('M-2',), ('d4',), 'M6') , 2
# ('P5', ('P4',), ('m3',), 'M6') , 2
# ('M3', ('M2',), ('d-3',), 'm6') , 2
# ('m6', ('m2',), ('m2',), 'm6') , 2
# ('P4', ('M2',), ('P1',), 'P5') , 2
# ('M6', ('M2',), ('d-7',), 'm6') , 2
# ('m6', ('m-3',), ('m-3',), 'm6') , 2
# ('m3', ('P5',), ('P-4',), 'm3') , 2
# ('A4', ('P4',), ('m-2',), 'P8') , 2
# ('m3', ('P5',), ('P5',), 'm3') , 2
# ('M2', ('M-2',), ('M-2',), 'M2') , 2
# ('M2', ('M-2',), ('m-2',), 'm2') , 2
# ('P8', ('P1',), ('m6',), 'M3') , 2
# ('M3', ('M2',), ('d-7',), 'm3') , 2
# ('M3', ('P1',), ('A1',), 'm3') , 2
# ('P5', ('M3',), ('P-4',), 'M3') , 2
# ('R', ('M3',), ('R',), 'M3') , 2
# ('P5', ('P4',), ('M6',), 'm3') , 2
# ('P8', ('P4',), ('M6',), 'm6') , 2
# ('M3', ('M2',), ('m-2',), 'P5') , 2
# ('m3', ('M-2',), ('d1',), 'M2') , 2
# ('P4', ('m-3',), ('P-4',), 'P5') , 2
# ('M3', ('m3',), ('P8',), 'P5') , 2
# ('P8', ('P4',), ('P1',), 'P4') , 2
# ('m6', ('P-5',), ('m2',), 'P8') , 2
# ('P8', ('M2',), ('P-5',), 'M6') , 2
# ('P4', ('m-3',), ('d1',), 'A2') , 2
# ('M2', ('M2',), ('m-2',), 'P4') , 2
# ('m3', ('P4',), ('P1',), 'm6') , 2
# ('P4', ('M3',), ('P1',), 'M6') , 2
# ('P5', ('P4',), ('P-8',), 'P8') , 2
# ('m3', ('P1',), ('P5',), 'm6') , 2
# ('M6', ('P4',), ('d-5',), 'm6') , 2
# ('P5', ('M3',), ('P5',), 'M3') , 2
# ('P5', ('m-3',), ('M3',), 'P8') , 2
# ('P8', ('m-2',), ('P-5',), 'A4') , 2
# ('P4', ('P1',), ('P4',), 'P8') , 2
# ('m3', ('M2',), ('P4',), 'P8') , 2
# ('P4', ('m-2',), ('m2',), 'A2') , 2
# ('M3', ('M-3',), ('M6',), 'm3') , 2
# ('M6', ('m3',), ('P1',), 'P8') , 2
# ('P5', ('P1',), ('P8',), 'P5') , 2
# ('m6', ('P-4',), ('M-2',), 'P4') , 2
# ('m6', ('m-3',), ('d1',), 'A4') , 2
# ('A4', ('m3',), ('m-2',), 'm7') , 2
# ('P4', ('m-2',), ('M-2',), 'A4') , 2
# ('P5', ('P1',), ('m2',), 'A4') , 2
# ('P8', ('M2',), ('P-4',), 'P5') , 2
# ('P8', ('M-3',), ('m2',), 'P5') , 2
# ('P8', ('P-5',), ('m-2',), 'd5') , 1
# ('P8', ('P-5',), ('M2',), 'm3') , 1
# ('M3', ('P1',), ('P-5',), 'M7') , 1
# ('R', ('P-5',), ('R',), 'd5') , 1
# ('R', ('P-5',), ('R',), 'm6') , 1
# ('M2', ('M2',), ('P-4',), 'M6') , 1
# ('M6', ('M2',), ('P8',), 'M7') , 1
# ('M7', ('m2',), ('m-3',), 'm3') , 1
# ('m3', ('M2',), ('P-4',), 'm7') , 1
# ('m7', ('M2',), ('m3',), 'M6') , 1
# ('M6', ('M-2',), ('R',), 'R') , 1
# ('R', ('M-2',), ('R',), 'P8') , 1
# ('P8', ('M3',), ('P-8',), 'M3') , 1
# ('m3', ('M2',), ('m-2',), 'd5') , 1
# ('R', ('m-2',), ('R',), 'M6') , 1
# ('m7', ('P1',), ('P-4',), 'm3') , 1
# ('m6', ('M3',), ('P4',), 'P5') , 1
# ('P8', ('m-2',), ('m-6',), 'P5') , 1
# ('P8', ('P5',), ('M2',), 'P4') , 1
# ('P8', ('m3',), ('m-3',), 'd5') , 1
# ('d5', ('m-2',), ('m-3',), 'm6') , 1
# ('m7', ('M-2',), ('P1',), 'm6') , 1
# ('P5', ('M-2',), ('P-4',), 'm7') , 1
# ('M6', ('P1',), ('d-7',), 'd5') , 1
# ('P8', ('m-2',), ('A1',), 'm7') , 1
# ('M6', ('M-3',), ('m-3',), 'm6') , 1
# ('M2', ('M-2',), ('P1',), 'P8') , 1
# ('M3', ('P-4',), ('P5',), 'M3') , 1
# ('m6', ('M3',), ('P-5',), 'P5') , 1
# ('m7', ('m3',), ('P1',), 'm2') , 1
# ('P8', ('P4',), ('m-2',), 'd5') , 1
# ('P8', ('M2',), ('d-5',), 'm6') , 1
# ('M2', ('M2',), ('P-8',), 'M3') , 1
# ('m3', ('m-3',), ('M2',), 'm7') , 1
# ('P8', ('P-4',), ('M-2',), 'M6') , 1
# ('P8', ('P-4',), ('m3',), 'M3') , 1
# ('m3', ('P4',), ('d1',), 'M6') , 1
# ('P5', ('P4',), ('P-4',), 'P4') , 1
# ('P5', ('m-2',), ('P1',), 'A4') , 1
# ('M3', ('P1',), ('d-5',), 'm7') , 1
# ('m6', ('M2',), ('m6',), 'M2') , 1
# ('P8', ('M-2',), ('P-8',), 'm7') , 1
# ('m7', ('M-2',), ('M2',), 'd5') , 1
# ('M3', ('P4',), ('M2',), 'P5') , 1
# ('M2', ('M-2',), ('m-3',), 'm3') , 1
# ('M6', ('P1',), ('M3',), 'P4') , 1
# ('m6', ('P5',), ('M-3',), 'P5') , 1
# ('M3', ('P4',), ('P-5',), 'M3') , 1
# ('M3', ('P1',), ('P4',), 'M7') , 1
# ('m3', ('P5',), ('M-2',), 'P8') , 1
# ('m3', ('m-2',), ('m-7',), 'P8') , 1
# ('m3', ('m-2',), ('P8',), 'M2') , 1
# ('m3', ('m-2',), ('M7',), 'm3') , 1
# ('M6', ('m-2',), ('M3',), 'M3') , 1
# ('M6', ('m3',), ('P4',), 'P5') , 1
# ('P4', ('M-2',), ('P1',), 'm3') , 1
# ('m3', ('m-2',), ('R',), 'R') , 1
# ('P4', ('m3',), ('P1',), 'm6') , 1
# ('M3', ('P1',), ('M7',), 'P4') , 1
# ('P4', ('m2',), ('M-2',), 'm6') , 1
# ('P8', ('m-3',), ('d-5',), 'm3') , 1
# ('M6', ('P4',), ('d-4',), 'd5') , 1
# ('d5', ('P1',), ('P1',), 'd5') , 1
# ('d5', ('m-3',), ('d5',), 'M6') , 1
# ('m7', ('m-3',), ('P1',), 'P5') , 1
# ('M3', ('M-2',), ('m-3',), 'P4') , 1
# ('P4', ('P4',), ('M2',), 'm6') , 1
# ('P4', ('m-2',), ('P-4',), 'M6') , 1
# ('M6', ('P4',), ('P4',), 'M6') , 1
# ('M6', ('M-2',), ('m-7',), 'P4') , 1
# ('P5', ('m3',), ('P5',), 'm3') , 1
# ('M3', ('m-2',), ('d-2',), 'm3') , 1
# ('m3', ('P1',), ('P-8',), 'm3') , 1
# ('P8', ('M-2',), ('P4',), 'P4') , 1
# ('P8', ('P-5',), ('P1',), 'P4') , 1
# ('P8', ('P-4',), ('P8',), 'P5') , 1
# ('M3', ('m3',), ('P-8',), 'P5') , 1
# ('M3', ('m3',), ('m7',), 'M6') , 1
# ('m6', ('M3',), ('m6',), 'M3') , 1
# ('M3', ('m2',), ('R',), 'R') , 1
# ('R', ('P1',), ('R',), 'm6') , 1
# ('R', ('M2',), ('R',), 'm3') , 1
# ('R', ('P4',), ('R',), 'R') , 1
# ('R', ('M2',), ('R',), 'P5') , 1
# ('M3', ('M-3',), ('M2',), 'm7') , 1
# ('M2', ('m3',), ('m-2',), 'd5') , 1
# ('M6', ('m3',), ('M2',), 'm7') , 1
# ('P5', ('m-2',), ('d-3',), 'm6') , 1
# ('P5', ('P4',), ('P1',), 'P8') , 1
# ('m2', ('m-2',), ('M-2',), 'M2') , 1
# ('M6', ('P1',), ('d-5',), 'm3') , 1
# ('m3', ('P1',), ('m6',), 'P5') , 1
# ('P8', ('m2',), ('P-4',), 'd5') , 1
# ('m3', ('M-2',), ('P4',), 'm6') , 1
# ('d5', ('M2',), ('m2',), 'P5') , 1
# ('P5', ('M-3',), ('P4',), 'm7') , 1
# ('M6', ('m2',), ('P1',), 'm7') , 1
# ('M2', ('M2',), ('d-4',), 'm6') , 1
# ('M6', ('m-2',), ('d-2',), 'm6') , 1
# ('M6', ('M-3',), ('m-2',), 'd5') , 1
# ('M2', ('M2',), ('A1',), 'm3') , 1
# ('m6', ('P5',), ('m3',), 'P8') , 1
# ('M2', ('P1',), ('P1',), 'M2') , 1
# ('M2', ('m-3',), ('A1',), 'm7') , 1
# ('m6', ('P1',), ('P-4',), 'm2') , 1
# ('m2', ('M3',), ('m2',), 'M3') , 1
# ('R', ('P1',), ('R',), 'R') , 1
# ('P4', ('m2',), ('d1',), 'P5') , 1
# ('m6', ('M3',), ('M-2',), 'M2') , 1
# ('P5', ('m2',), ('M-2',), 'm7') , 1
# ('m7', ('M2',), ('m-3',), 'm3') , 1
# ('P4', ('M3',), ('m-3',), 'P8') , 1
# ('m3', ('M3',), ('P8',), 'P5') , 1
# ('P4', ('P-4',), ('M-2',), 'M2') , 1
# ('P8', ('M3',), ('M6',), 'P5') , 1
# ('P4', ('M2',), ('m3',), 'M3') , 1
# ('m3', ('P4',), ('P4',), 'm3') , 1
# ('R', ('M3',), ('R',), 'R') , 1
# ('R', ('m3',), ('R',), 'P5') , 1
# ('R', ('m-3',), ('R',), 'P5') , 1
# ('R', ('P1',), ('R',), 'M6') , 1
# ('R', ('m2',), ('R',), 'R') , 1
# ('R', ('m-2',), ('R',), 'P8') , 1
# ('m6', ('P1',), ('d4',), 'M3') , 1
# ('m3', ('P4',), ('P-5',), 'm3') , 1
# ('M3', ('P1',), ('d-4',), 'm6') , 1
# ('m6', ('P4',), ('P-4',), 'd5') , 1
# ('P8', ('m3',), ('P4',), 'm7') , 1
# ('m3', ('P1',), ('d5',), 'M6') , 1
# ('m6', ('P4',), ('P4',), 'm6') , 1
# ('R', ('m-3',), ('R',), 'R') , 1
# ('R', ('M-3',), ('R',), 'P8') , 1
# ('m3', ('m3',), ('M-3',), 'm7') , 1
# ('m6', ('P-4',), ('P-4',), 'm6') , 1
# ('M6', ('M2',), ('P5',), 'M3') , 1
# ('m6', ('m-3',), ('M2',), 'm3') , 1
# ('P8', ('m-2',), ('P1',), 'M7') , 1
# ('M3', ('m3',), ('m-3',), 'm7') , 1
# ('M3', ('m3',), ('P5',), 'P8') , 1
# ('P8', ('m3',), ('P8',), 'm3') , 1
# ('P4', ('P-4',), ('P1',), 'P8') , 1
# ('m3', ('P-4',), ('P5',), 'm3') , 1
# ('m6', ('P1',), ('R',), 'R') , 1
# ('P8', ('P4',), ('P-8',), 'P4') , 1
# ('M6', ('P4',), ('P1',), 'M2') , 1
# ('M2', ('m-3',), ('M3',), 'P5') , 1
# ('P5', ('P4',), ('R',), 'R') , 1
# ('m7', ('P1',), ('m3',), 'P5') , 1
# ('m6', ('P1',), ('d5',), 'M2') , 1
# ('m6', ('M2',), ('P5',), 'm3') , 1
# ('M6', ('M2',), ('P-4',), 'M3') , 1
# ('P8', ('M-3',), ('P-5',), 'm3') , 1
# ('m3', ('P5',), ('m2',), 'M6') , 1
# ('M3', ('m2',), ('P8',), 'P4') , 1
# ('M3', ('M-2',), ('P8',), 'M2') , 1
# ('P8', ('P5',), ('m-6',), 'm3') , 1

# %% [markdown]
# ### Full Phrase Ending

# %%
# the func to be passed into getData, this is a sliding window of size two half notes in the melody,
# three quarter notes in the bass
def full2HNPhraseEnd(k):
    graceNotes = []
    for n in k.recurse().notes:
        if n.duration.isGrace:
            graceNotes.append(n)

    # remove grace notes  
    for grace in graceNotes:
        grace.activeSite.remove(grace)

    k_ = copy.deepcopy(k)
    k_c = k_.chordify()
    data = []
    for i in range(1, len(k_.parts[0].getElementsByClass('Measure')) + 1):
        k_mel = k_.measure(i).parts[0].asTimespans()
        k_bass = k_.measure(i).parts[1].asTimespans()
        mel = []
        bass = []
        off = k_c.measure(i).notes[-1].offset - 2

        # starting window
        har_1 = getHarmony(k_mel.getVerticalityAt(off).toChord(),
                           k_bass.getVerticalityAt(off).toChord())
        mel.append(getInterval(k_mel.getVerticalityAt(off).toChord(),
                               k_mel.getVerticalityAt(off + 2).toChord()))
        bass.append(getInterval(k_bass.getVerticalityAt(off).toChord(),
                                k_bass.getVerticalityAt(off + 2).toChord()))
        har_2 = getHarmony(k_mel.getVerticalityAt(off + 2).toChord(),
                           k_bass.getVerticalityAt(off + 2).toChord())
        data.append((har_1, mel.copy(), bass.copy(), har_2))
    data = map(lambda x: (x[0], tuple(x[1]), tuple(x[2]), x[3]), data)
    return data

# %%
getData(full2HNPhraseEnd, kittelBundle)
# Out:
# ('P5', ('M-2',), ('P-5',), 'P8') , 244
# ('M3', ('m2',), ('P-5',), 'P8') , 83
# ('P5', ('M-2',), ('P4',), 'P8') , 77
# ('M3', ('m2',), ('P4',), 'P8') , 27
# ('P5', ('M2',), ('P-5',), 'M3') , 27
# ('P8', ('M-2',), ('m3',), 'P5') , 25
# ('m3', ('M-2',), ('m2',), 'P8') , 25
# ('M6', ('m2',), ('M-2',), 'P8') , 25
# ('M3', ('M-2',), ('P5',), 'P5') , 23
# ('M3', ('M-2',), ('P-4',), 'P5') , 23
# ('P5', ('M2',), ('P4',), 'M3') , 23
# ('M6', ('M2',), ('m-2',), 'P8') , 18
# ('P5', ('M-2',), ('m-3',), 'm6') , 16
# ('m6', ('P1',), ('M-3',), 'P8') , 15
# ('m3', ('M2',), ('m2',), 'M3') , 13
# ('P5', ('P1',), ('P-4',), 'P8') , 12
# ('P8', ('m-3',), ('P-5',), 'M3') , 11
# ('M6', ('M-2',), ('m-2',), 'm6') , 10
# ('d5', ('M-2',), ('m2',), 'm3') , 10
# ('P8', ('m-3',), ('P4',), 'M3') , 10
# ('P5', ('P1',), ('P1',), 'P5') , 10
# ('m7', ('m-2',), ('P4',), 'M3') , 9
# ('m3', ('P1',), ('m3',), 'P8') , 9
# ('d5', ('m-2',), ('m2',), 'M3') , 8
# ('M3', ('m2',), ('m-3',), 'm6') , 8
# ('m7', ('m-2',), ('P-5',), 'M3') , 7
# ('P8', ('M2',), ('M-2',), 'M3') , 7
# ('m6', ('m-3',), ('m2',), 'M3') , 6
# ('M6', ('M2',), ('M3',), 'P5') , 6
# ('M3', ('M-3',), ('P-8',), 'P8') , 6
# ('m6', ('M2',), ('m3',), 'P5') , 6
# ('P5', ('M-2',), ('M2',), 'm3') , 5
# ('m3', ('m-2',), ('P-4',), 'P5') , 5
# ('M3', ('m-2',), ('m-2',), 'M3') , 5
# ('M6', ('M-2',), ('P1',), 'P5') , 4
# ('P8', ('m-3',), ('M2',), 'P5') , 4
# ('M2', ('P1',), ('M2',), 'P8') , 4
# ('P5', ('m2',), ('P-5',), 'm3') , 4
# ('m3', ('M2',), ('m-3',), 'm6') , 4
# ('M3', ('P1',), ('M3',), 'P8') , 4
# ('M6', ('M-2',), ('P-4',), 'P8') , 3
# ('P5', ('m3',), ('M-2',), 'P8') , 3
# ('m3', ('m-2',), ('M2',), 'P8') , 3
# ('m3', ('P1',), ('M-6',), 'P8') , 3
# ('m7', ('M-2',), ('P4',), 'm3') , 3
# ('m3', ('m-2',), ('M-2',), 'M3') , 3
# ('m7', ('M-2',), ('P-5',), 'm3') , 3
# ('P4', ('M2',), ('m-2',), 'm6') , 3
# ('P8', ('M2',), ('P5',), 'P5') , 3
# ('P8', ('m-2',), ('M3',), 'P5') , 3
# ('P8', ('P1',), ('P4',), 'P5') , 3
# ('M3', ('M-2',), ('P1',), 'M2') , 3
# ('m3', ('M2',), ('M-2',), 'P5') , 3
# ('P5', ('m3',), ('M2',), 'm6') , 2
# ('M3', ('m3',), ('m-2',), 'm6') , 2
# ('P5', ('P1',), ('P5',), 'P8') , 2
# ('m3', ('M-2',), ('M-2',), 'm3') , 2
# ('A4', ('m2',), ('M-2',), 'M6') , 2
# ('M6', ('m2',), ('m2',), 'M6') , 2
# ('A4', ('m2',), ('m-2',), 'm6') , 2
# ('M3', ('m2',), ('m2',), 'M3') , 2
# ('M3', ('M-3',), ('P1',), 'P8') , 2
# ('m3', ('m-3',), ('M-3',), 'M3') , 2
# ('P5', ('M-2',), ('m2',), 'M3') , 2
# ('P5', ('m-2',), ('M2',), 'M3') , 2
# ('P8', ('P1',), ('P-8',), 'P8') , 2
# ('M3', ('M2',), ('m-2',), 'P5') , 2
# ('m3', ('m2',), ('m2',), 'm3') , 2
# ('P5', ('M2',), ('A1',), 'm6') , 2
# ('P8', ('m-2',), ('P-4',), 'M3') , 2
# ('P8', ('M-2',), ('M-6',), 'P5') , 2
# ('m6', ('P1',), ('m2',), 'P5') , 2
# ('P4', ('P1',), ('M-2',), 'P5') , 2
# ('M3', ('M-2',), ('d-5',), 'm6') , 2
# ('m3', ('m-2',), ('d-5',), 'm6') , 2
# ('P8', ('P1',), ('P1',), 'P8') , 2
# ('P4', ('P1',), ('P4',), 'P8') , 2
# ('P5', ('P1',), ('P-8',), 'P5') , 2
# ('M3', ('P1',), ('P-8',), 'M3') , 2
# ('M3', ('M-3',), ('P-5',), 'P5') , 2
# ('P8', ('M-3',), ('P4',), 'm3') , 2
# ('R', ('M-2',), ('R',), 'P8') , 1
# ('M3', ('m2',), ('M-3',), 'M6') , 1
# ('P5', ('M-2',), ('M-3',), 'M6') , 1
# ('P5', ('m3',), ('P-4',), 'm3') , 1
# ('P8', ('m-2',), ('m-6',), 'P5') , 1
# ('d5', ('m-2',), ('m-3',), 'm6') , 1
# ('M2', ('M-2',), ('P1',), 'P8') , 1
# ('P8', ('M2',), ('d-5',), 'm6') , 1
# ('M3', ('m2',), ('M2',), 'm3') , 1
# ('P4', ('P1',), ('P-5',), 'P8') , 1
# ('M6', ('m-2',), ('M3',), 'M3') , 1
# ('m3', ('M-2',), ('P-5',), 'm6') , 1
# ('M6', ('m2',), ('M2',), 'm6') , 1
# ('m6', ('m-2',), ('m3',), 'M3') , 1
# ('d7', ('m-2',), ('m2',), 'P5') , 1
# ('m3', ('m-2',), ('P5',), 'P5') , 1
# ('P4', ('m-2',), ('P1',), 'M3') , 1
# ('P8', ('P1',), ('P-5',), 'P5') , 1
# ('P8', ('M-2',), ('M2',), 'm6') , 1
# ('P8', ('M2',), ('P1',), 'M2') , 1
# ('M3', ('P1',), ('m-6',), 'P8') , 1
# ('m3', ('m-2',), ('P1',), 'M2') , 1
# ('M2', ('M2',), ('d-4',), 'm6') , 1
# ('M6', ('M2',), ('d-7',), 'm6') , 1
# ('P5', ('M2',), ('d-5',), 'm3') , 1
# ('m7', ('M-2',), ('m2',), 'P5') , 1
# ('P8', ('m2',), ('M-2',), 'm3') , 1
# ('m3', ('P1',), ('M-3',), 'P5') , 1
# ('P5', ('m2',), ('m-2',), 'd7') , 1
# ('M3', ('M-2',), ('M2',), 'P8') , 1
# ('m6', ('P1',), ('R',), 'R') , 1
# ('M3', ('P1',), ('P1',), 'M3') , 1
# ('P8', ('M2',), ('P-4',), 'P5') , 1
# ('m6', ('M-3',), ('m2',), 'm3') , 1
# ('M3', ('M-3',), ('P4',), 'P5') , 1
# ('P8', ('M-3',), ('P-5',), 'm3') , 1
# ('P8', ('M-3',), ('m2',), 'P5') , 1

# %% [markdown]
# ## 3 Half Note Segments

# %% [markdown]
# ### 3HN Melodic

# %%
def melody3HN(k):
    graceNotes = []
    for n in k.recurse().notes:
        if n.duration.isGrace:
            graceNotes.append(n)

    # remove grace notes  
    for grace in graceNotes:
        grace.activeSite.remove(grace)

    k_ = copy.deepcopy(k)
    k_c = k_.chordify()
    data = []
    for i in range(1, len(k_.parts[0].getElementsByClass('Measure')) + 1):
        k_mel = k_.measure(i).parts[0].asTimespans()
        mel = []
        off = k_.parts[0].measure(i).recurse().notes[0].offset

        # starting window
        mel.append(interval.Interval(k_mel.getVerticalityAt(off).toChord()[0],
                                     k_mel.getVerticalityAt(off + 2).toChord()[0]).directedName)
        mel.append(interval.Interval(k_mel.getVerticalityAt(off + 2).toChord()[0],
                                     k_mel.getVerticalityAt(off + 4).toChord()[0]).directedName)
        data.append(mel.copy())
        off += 2

        # slide the window
        while off <= k_c.measure(i).notes[-1].offset - 4:
            mel.pop(0)
            mel.append(interval.Interval(k_mel.getVerticalityAt(off + 2).toChord()[0],
                                         k_mel.getVerticalityAt(off + 4).toChord()[0]).directedName)
            data.append(mel.copy())
            off += 2
    data = map(lambda x: tuple(x), data)
    return data

# %%
getData(melody3HN, melBundle)
# Out:
# ('P1', 'M-2') , 62
# ('m-2', 'M-2') , 52
# ('M-2', 'P1') , 41
# ('M-2', 'M-2') , 38
# ('M2', 'M2') , 33
# ('M2', 'm2') , 33
# ('M-2', 'm-2') , 33
# ('P1', 'P1') , 29
# ('M2', 'M-2') , 22
# ('P1', 'M2') , 22
# ('M2', 'P1') , 21
# ('P1', 'm-2') , 20
# ('M-2', 'M2') , 17
# ('m-2', 'm2') , 17
# ('m2', 'm-2') , 16
# ('m2', 'M2') , 15
# ('m-3', 'M-2') , 10
# ('P1', 'm-3') , 9
# ('m2', 'P1') , 9
# ('M-2', 'P4') , 9
# ('M-3', 'M2') , 7
# ('m3', 'M-2') , 7
# ('m3', 'M2') , 7
# ('M2', 'm3') , 6
# ('M3', 'M-2') , 6
# ('M-2', 'm-3') , 6
# ('m-3', 'M2') , 6
# ('m3', 'm-2') , 6
# ('P4', 'P1') , 6
# ('m-2', 'P1') , 6
# ('m-3', 'M-3') , 5
# ('m-3', 'P1') , 5
# ('P4', 'M2') , 5
# ('M2', 'm-3') , 5
# ('m2', 'm-3') , 4
# ('P4', 'M-2') , 4
# ('M-2', 'm3') , 4
# ('M3', 'm2') , 4
# ('P4', 'm-3') , 3
# ('P1', 'M-3') , 3
# ('m-3', 'm3') , 3
# ('P4', 'm-2') , 3
# ('M2', 'M-3') , 3
# ('m-3', 'm2') , 3
# ('m3', 'P-5') , 2
# ('M2', 'P4') , 2
# ('m-2', 'M-3') , 2
# ('P5', 'M2') , 2
# ('P5', 'P1') , 2
# ('m3', 'm-3') , 2
# ('M3', 'm3') , 2
# ('P4', 'P-4') , 2
# ('P-4', 'M2') , 2
# ('P5', 'm-3') , 2
# ('P1', 'P4') , 2
# ('m2', 'M3') , 2
# ('M-3', 'm-2') , 2
# ('P1', 'M3') , 2
# ('P-5', 'm-2') , 1
# ('M-2', 'M3') , 1
# ('M3', 'P1') , 1
# ('P1', 'm3') , 1
# ('M-3', 'M3') , 1
# ('M3', 'M2') , 1
# ('M2', 'P-4') , 1
# ('P-4', 'm3') , 1
# ('m-2', 'M2') , 1
# ('M-3', 'm-3') , 1
# ('m-2', 'P4') , 1
# ('M-3', 'P5') , 1
# ('P1', 'm2') , 1
# ('m2', 'M-2') , 1
# ('P-5', 'M2') , 1
# ('M-3', 'P1') , 1
# ('m-2', 'm3') , 1
# ('P1', 'P5') , 1
# ('m2', 'P-4') , 1
# ('P-4', 'P4') , 1
# ('m-3', 'P4') , 1
# ('m3', 'P-4') , 1
# ('P-4', 'm-3') , 1

# %% [markdown]
# ### 3HN Phrase Ending

# %%
def melody3HNPhraseEnd(k):
    graceNotes = []
    for n in k.recurse().notes:
        if n.duration.isGrace:
            graceNotes.append(n)

    # remove grace notes  
    for grace in graceNotes:
        grace.activeSite.remove(grace)

    k_ = copy.deepcopy(k)
    k_c = k_.chordify()
    data = []
    for i in range(1, len(k_.parts[0].getElementsByClass('Measure')) + 1):
        k_mel = k_.measure(i).parts[0].asTimespans()
        mel = []
        off = k_c.measure(i).notes[-1].offset - 4

        # starting window
        mel.append(interval.Interval(k_mel.getVerticalityAt(off).toChord()[0],
                                     k_mel.getVerticalityAt(off + 2).toChord()[0]).directedName)
        mel.append(interval.Interval(k_mel.getVerticalityAt(off + 2).toChord()[0],
                                     k_mel.getVerticalityAt(off + 4).toChord()[0]).directedName)
        data.append(mel.copy())
    data = map(lambda x: tuple(x), data)
    return data

# %%
getData(melody3HNPhraseEnd, melBundle)
# Out:
# ('P1', 'M-2') , 45
# ('m-2', 'm2') , 13
# ('M2', 'm2') , 8
# ('M-2', 'M-2') , 7
# ('m-2', 'M-2') , 7
# ('P1', 'M2') , 6
# ('P1', 'm-2') , 5
# ('M-2', 'M2') , 4
# ('P1', 'P1') , 4
# ('P1', 'm-3') , 3
# ('m-3', 'M-2') , 3
# ('M2', 'M2') , 3
# ('M-3', 'M2') , 2
# ('m-3', 'P1') , 1
# ('P1', 'M-3') , 1
# ('M-2', 'm-3') , 1
# ('M3', 'm3') , 1
# ('M2', 'M-2') , 1
# ('m-3', 'M-3') , 1
# ('M-2', 'm-2') , 1
# ('M-3', 'm-2') , 1
# ('M3', 'M-2') , 1
# ('M-2', 'P1') , 1

# %% [markdown]
# ### 3HN Full

# %%
def full3HN(k):
    graceNotes = []
    for n in k.recurse().notes:
        if n.duration.isGrace:
            graceNotes.append(n)

    # remove grace notes  
    for grace in graceNotes:
        grace.activeSite.remove(grace)

    k_ = copy.deepcopy(k)
    k_c = k_.chordify()
    data = []
    for i in range(1, len(k_.parts[0].getElementsByClass('Measure')) + 1):
        k_mel = k_.measure(i).parts[0].asTimespans()
        k_bass = k_.measure(i).parts[1].asTimespans()
        mel = []
        bass = []
        off = k_.parts[0].measure(i).recurse().notes[0].offset

        # starting window
        har_1 = getHarmony(k_mel.getVerticalityAt(off).toChord(),
                           k_bass.getVerticalityAt(off).toChord())
        mel.append(getInterval(k_mel.getVerticalityAt(off).toChord(),
                               k_mel.getVerticalityAt(off + 2).toChord()))
        mel.append(getInterval(k_mel.getVerticalityAt(off + 2).toChord(),
                               k_mel.getVerticalityAt(off + 4).toChord()))
        bass.append(getInterval(k_bass.getVerticalityAt(off).toChord(),
                                k_bass.getVerticalityAt(off + 2).toChord()))
        bass.append(getInterval(k_bass.getVerticalityAt(off + 2).toChord(),
                                k_bass.getVerticalityAt(off + 4).toChord()))
        har_2 = getHarmony(k_mel.getVerticalityAt(off + 4).toChord(),
                           k_bass.getVerticalityAt(off + 4).toChord())
        data.append((har_1, mel.copy(), bass.copy(), har_2))
        off += 2

        # slide the window
        while off <= k_c.measure(i).notes[-1].offset - 4:
            mel.pop(0)
            bass.pop(0)
            har_1 = getHarmony(k_mel.getVerticalityAt(off).toChord(),
                           k_bass.getVerticalityAt(off).toChord())
            mel.append(getInterval(k_mel.getVerticalityAt(off + 2).toChord(),
                                   k_mel.getVerticalityAt(off + 4).toChord()))
            bass.append(getInterval(k_bass.getVerticalityAt(off + 2).toChord(),
                                    k_bass.getVerticalityAt(off + 4).toChord()))
            har_2 = getHarmony(k_mel.getVerticalityAt(off + 4).toChord(),
                           k_bass.getVerticalityAt(off + 4).toChord())
            data.append((har_1, mel.copy(), bass.copy(), har_2))
            off += 2
    data = map(lambda x: (x[0], tuple(x[1]), tuple(x[2]), x[3]), data)
    return data

# %%
getData(full3HN, kittelBundle)
# Out:
# ('M6', ('P1', 'M-2'), ('M2', 'P-5'), 'P8') , 121
# ('P5', ('P1', 'M-2'), ('P1', 'P-5'), 'P8') , 62
# ('m6', ('M2', 'M2'), ('M-2', 'M-2'), 'M3') , 38
# ('P5', ('P1', 'M-2'), ('P-8', 'P4'), 'P8') , 37
# ('M3', ('M2', 'm2'), ('m-3', 'M-2'), 'P8') , 35
# ('M6', ('M2', 'm2'), ('m-2', 'M-2'), 'm3') , 31
# ('P5', ('m-2', 'm2'), ('M2', 'P-5'), 'P8') , 29
# ('M3', ('M-2', 'P1'), ('P5', 'P1'), 'P5') , 26
# ('M3', ('M-2', 'P1'), ('P-5', 'M2'), 'P5') , 25
# ('M3', ('M-2', 'M-2'), ('M2', 'M2'), 'm6') , 25
# ('m6', ('m-2', 'M-2'), ('M-2', 'M-2'), 'M6') , 25
# ('m3', ('m-2', 'M-2'), ('M2', 'm3'), 'P5') , 24
# ('M6', ('M-2', 'm-2'), ('m-2', 'M-2'), 'M6') , 24
# ('m3', ('m-2', 'M-2'), ('M2', 'm2'), 'M6') , 23
# ('M6', ('M-2', 'M-2'), ('P-8', 'P4'), 'P8') , 22
# ('M3', ('M-2', 'P1'), ('P1', 'm-2'), 'm3') , 22
# ('M6', ('M-2', 'M-2'), ('M-2', 'm-2'), 'm6') , 22
# ('P8', ('M-2', 'P1'), ('m2', 'M2'), 'P5') , 22
# ('M2', ('P1', 'M-2'), ('m-2', 'm2'), 'P8') , 21
# ('P5', ('M2', 'm2'), ('P4', 'P-5'), 'P8') , 21
# ('m6', ('m-2', 'M-2'), ('m3', 'P-4'), 'P5') , 21
# ('P8', ('M-2', 'P1'), ('m3', 'P-8'), 'P5') , 21
# ('M3', ('M-2', 'P1'), ('P-4', 'P1'), 'P5') , 19
# ('M3', ('M-2', 'M-2'), ('d-4', 'm2'), 'm3') , 19
# ('m3', ('M2', 'M2'), ('M2', 'm2'), 'M3') , 18
# ('P4', ('M2', 'm2'), ('M-2', 'M-2'), 'P8') , 18
# ('P5', ('M-2', 'P1'), ('M-3', 'M2'), 'P5') , 18
# ('m3', ('M-2', 'm-2'), ('m2', 'P-4'), 'M3') , 18
# ('P8', ('M2', 'M-2'), ('M-2', 'P5'), 'P5') , 17
# ('m3', ('M-2', 'm-2'), ('m2', 'M2'), 'M6') , 17
# ('P8', ('M-2', 'M-2'), ('m3', 'M2'), 'm3') , 17
# ('m3', ('m-3', 'M2'), ('P-5', 'P4'), 'M3') , 17
# ('m3', ('P1', 'm-2'), ('M-3', 'M2'), 'M3') , 17
# ('P4', ('m-2', 'm2'), ('P-8', 'P4'), 'P8') , 16
# ('P8', ('M-2', 'm-2'), ('M2', 'm3'), 'M3') , 16
# ('P8', ('m-2', 'M-2'), ('P-4', 'P5'), 'P5') , 16
# ('m3', ('M2', 'M2'), ('P1', 'M-2'), 'M6') , 15
# ('m6', ('P1', 'M-2'), ('m2', 'P-5'), 'P8') , 15
# ('m6', ('m-3', 'M-2'), ('m2', 'P-4'), 'P5') , 15
# ('d5', ('M-2', 'm-2'), ('m2', 'M2'), 'P8') , 15
# ('P5', ('M2', 'M2'), ('P4', 'm-3'), 'M6') , 15
# ('m6', ('m-2', 'M-2'), ('M-2', 'P1'), 'P5') , 14
# ('P8', ('m-2', 'M-2'), ('M2', 'P-8'), 'P5') , 14
# ('M2', ('P1', 'M2'), ('m-2', 'm2'), 'M3') , 14
# ('m3', ('M2', 'P1'), ('M-3', 'M2'), 'P5') , 14
# ('P5', ('M-2', 'P1'), ('m-3', 'm2'), 'P5') , 14
# ('M6', ('M-2', 'P1'), ('M-2', 'M2'), 'P5') , 14
# ('d5', ('m-2', 'M-2'), ('m2', 'P-4'), 'P5') , 13
# ('m3', ('M2', 'm2'), ('d1', 'm-2'), 'm6') , 13
# ('m6', ('m-2', 'M-2'), ('M-2', 'm-2'), 'm6') , 13
# ('M3', ('M-2', 'M-2'), ('P-4', 'M2'), 'm3') , 13
# ('m7', ('m-2', 'm2'), ('P4', 'P-5'), 'P8') , 13
# ('P8', ('M-2', 'P1'), ('m3', 'P1'), 'P5') , 13
# ('M6', ('M2', 'M-2'), ('m-2', 'm3'), 'P5') , 13
# ('M3', ('m2', 'M2'), ('m-3', 'M-2'), 'P8') , 12
# ('m3', ('M2', 'M-2'), ('m2', 'P-4'), 'P5') , 12
# ('m3', ('M2', 'M2'), ('M-3', 'm-2'), 'P8') , 12
# ('m3', ('P1', 'P1'), ('P-4', 'm2'), 'P5') , 12
# ('M6', ('M-2', 'M-2'), ('A1', 'm2'), 'm3') , 12
# ('m3', ('m-2', 'M-2'), ('P-4', 'M-3'), 'M6') , 12
# ('M6', ('m2', 'M2'), ('M-2', 'm-2'), 'm3') , 12
# ('P8', ('M2', 'M2'), ('P1', 'M-2'), 'A4') , 12
# ('M2', ('M2', 'm2'), ('M-2', 'm-2'), 'm6') , 11
# ('m3', ('M2', 'M-2'), ('m2', 'M2'), 'P8') , 11
# ('m3', ('P1', 'P1'), ('M-2', 'M-2'), 'P5') , 11
# ('P5', ('M2', 'M2'), ('P1', 'm-2'), 'P8') , 11
# ('m3', ('m-2', 'M-2'), ('P5', 'm2'), 'M3') , 11
# ('m6', ('m-3', 'M-3'), ('m2', 'M3'), 'm6') , 11
# ('M6', ('P1', 'M2'), ('M2', 'P-5'), 'M3') , 11
# ('M6', ('P1', 'P1'), ('M2', 'P1'), 'P5') , 11
# ('m6', ('m-2', 'M-2'), ('P-4', 'm3'), 'P5') , 10
# ('P8', ('M2', 'M2'), ('m-2', 'm2'), 'M3') , 10
# ('M3', ('M2', 'm2'), ('P1', 'm-2'), 'm6') , 10
# ('m3', ('m-2', 'M-2'), ('M-2', 'P5'), 'P5') , 10
# ('M3', ('P1', 'M-2'), ('P8', 'P1'), 'M2') , 10
# ('m6', ('M2', 'M2'), ('P-4', 'm2'), 'M3') , 10
# ('m6', ('P1', 'P1'), ('m2', 'P-4'), 'P8') , 10
# ('m6', ('M2', 'P1'), ('m2', 'M2'), 'P5') , 10
# ('P8', ('P1', 'M-2'), ('P4', 'P-5'), 'P8') , 10
# ('P5', ('P1', 'P1'), ('m-2', 'm2'), 'P5') , 10
# ('M6', ('M-2', 'M2'), ('M-2', 'm-2'), 'P8') , 10
# ('m3', ('M2', 'M2'), ('m2', 'm-3'), 'M6') , 10
# ('d5', ('M-2', 'm-2'), ('m2', 'P-4'), 'P5') , 10
# ('M3', ('P1', 'M-2'), ('M3', 'm3'), 'P5') , 9
# ('m6', ('M2', 'M2'), ('m2', 'M2'), 'M6') , 9
# ('A4', ('m2', 'm-2'), ('m-2', 'M-2'), 'M6') , 9
# ('m6', ('M2', 'M-2'), ('P-4', 'm2'), 'P8') , 9
# ('M6', ('M-2', 'P1'), ('m-2', 'm2'), 'P5') , 9
# ('M3', ('M-2', 'M-2'), ('P5', 'M2'), 'm3') , 9
# ('M3', ('M2', 'm2'), ('M2', 'P-5'), 'P8') , 9
# ('P5', ('m3', 'M-2'), ('P-4', 'm2'), 'P8') , 9
# ('m3', ('M-2', 'm-2'), ('m2', 'M3'), 'P5') , 9
# ('m6', ('m-2', 'm2'), ('M-2', 'M-2'), 'P8') , 9
# ('M3', ('M-2', 'P4'), ('P1', 'm-2'), 'm6') , 9
# ('m6', ('P1', 'm-2'), ('M-2', 'P4'), 'M3') , 9
# ('P5', ('M2', 'M2'), ('m-3', 'M-2'), 'M3') , 9
# ('M6', ('M2', 'M-2'), ('M2', 'P-8'), 'P5') , 8
# ('m3', ('m-2', 'M-2'), ('P-4', 'm2'), 'M3') , 8
# ('m6', ('m-2', 'M-2'), ('m3', 'P1'), 'M2') , 8
# ('M6', ('M-2', 'M2'), ('P-8', 'P4'), 'M3') , 8
# ('P5', ('M-2', 'm-3'), ('M2', 'P-5'), 'P5') , 8
# ('m3', ('m-2', 'M-2'), ('P5', 'M-3'), 'M6') , 8
# ('P8', ('M-2', 'm-2'), ('A1', 'm2'), 'P5') , 8
# ('m6', ('P1', 'M-2'), ('m2', 'm-3'), 'm6') , 8
# ('m6', ('P1', 'M2'), ('m2', 'P4'), 'M3') , 8
# ('M3', ('m2', 'm-2'), ('m-2', 'm2'), 'M3') , 8
# ('P5', ('M-2', 'm-2'), ('M2', 'P-4'), 'P5') , 8
# ('M3', ('m2', 'M2'), ('P1', 'm-2'), 'm6') , 8
# ('P4', ('M2', 'M2'), ('M-2', 'm-2'), 'P8') , 8
# ('M3', ('P1', 'M-2'), ('m-6', 'm3'), 'P5') , 8
# ('m6', ('P1', 'm-3'), ('P1', 'm2'), 'M3') , 8
# ('P8', ('M2', 'P1'), ('P4', 'M2'), 'P5') , 8
# ('m6', ('P1', 'M2'), ('m2', 'P-5'), 'M3') , 8
# ('A4', ('M2', 'm2'), ('m-2', 'M-2'), 'P8') , 8
# ('m6', ('P1', 'm-2'), ('m2', 'M2'), 'M3') , 8
# ('m6', ('m-3', 'm2'), ('m2', 'm-3'), 'm6') , 8
# ('P5', ('M-2', 'P1'), ('M2', 'M-3'), 'P5') , 8
# ('P5', ('P1', 'M-2'), ('P1', 'P4'), 'P8') , 7
# ('M3', ('m2', 'm-2'), ('m-3', 'P-4'), 'P8') , 7
# ('P8', ('M-2', 'M2'), ('m2', 'm-2'), 'P8') , 7
# ('A4', ('m2', 'M2'), ('m-2', 'P-4'), 'm3') , 7
# ('P8', ('m2', 'm-2'), ('M-2', 'P5'), 'P5') , 7
# ('M3', ('m2', 'M2'), ('M2', 'M2'), 'm3') , 7
# ('M3', ('M-2', 'M-2'), ('P-4', 'P-5'), 'P8') , 7
# ('M3', ('m2', 'm-2'), ('M2', 'M2'), 'P8') , 7
# ('m6', ('P1', 'M-2'), ('d1', 'm-2'), 'm6') , 7
# ('P4', ('P1', 'P1'), ('M-2', 'm-2'), 'm6') , 7
# ('m6', ('P1', 'M2'), ('d1', 'm-2'), 'P8') , 7
# ('P5', ('M-2', 'P1'), ('m-3', 'M-3'), 'P8') , 7
# ('P5', ('P1', 'P1'), ('M2', 'M2'), 'm3') , 7
# ('M3', ('m3', 'M2'), ('M3', 'm2'), 'M3') , 7
# ('m3', ('P1', 'm-2'), ('P-5', 'P4'), 'M3') , 7
# ('P5', ('M-2', 'm-2'), ('M2', 'M2'), 'P8') , 7
# ('A4', ('m2', 'P1'), ('m-2', 'm2'), 'P5') , 7
# ('M3', ('M-2', 'M-2'), ('m-2', 'm2'), 'P8') , 7
# ('m6', ('M-2', 'm-2'), ('M-2', 'M-2'), 'M6') , 7
# ('P8', ('M2', 'm2'), ('d1', 'm-2'), 'P4') , 7
# ('M3', ('M-2', 'M2'), ('P-4', 'P4'), 'M3') , 7
# ('P8', ('P1', 'P1'), ('M-2', 'm-2'), 'm3') , 7
# ('M3', ('P1', 'M-2'), ('P-8', 'P5'), 'P5') , 7
# ('M3', ('m3', 'M-2'), ('A1', 'm2'), 'm3') , 7
# ('m3', ('M2', 'M2'), ('M-2', 'P4'), 'M3') , 7
# ('M6', ('P1', 'm-2'), ('P4', 'm-2'), 'M3') , 7
# ('P8', ('P5', 'm-3'), ('m-2', 'm2'), 'M3') , 7
# ('M6', ('m2', 'm-2'), ('M-2', 'P5'), 'M3') , 7
# ('P8', ('P1', 'm-3'), ('P1', 'P4'), 'M3') , 7
# ('M3', ('M-2', 'P1'), ('P4', 'M2'), 'P5') , 7
# ('P5', ('P1', 'M2'), ('P1', 'P-5'), 'M3') , 7
# ('P5', ('P1', 'M2'), ('M-2', 'm-2'), 'P8') , 7
# ('P5', ('M-2', 'M-2'), ('M-3', 'm-2'), 'm6') , 7
# ('P4', ('m-2', 'm2'), ('P1', 'P-5'), 'P8') , 7
# ('m6', ('m-3', 'P1'), ('m2', 'P1'), 'M3') , 7
# ('M3', ('P1', 'M-2'), ('m-3', 'M-3'), 'M6') , 6
# ('P5', ('M-2', 'M2'), ('M-3', 'm-2'), 'P8') , 6
# ('P8', ('m2', 'm-2'), ('M-2', 'M-2'), 'M3') , 6
# ('m6', ('m-2', 'M-2'), ('m3', 'P-5'), 'M6') , 6
# ('A4', ('m2', 'M2'), ('m-2', 'M-2'), 'P8') , 6
# ('d5', ('m-2', 'M-2'), ('m2', 'P-5'), 'M6') , 6
# ('M3', ('m2', 'M2'), ('m-3', 'P-4'), 'm3') , 6
# ('M6', ('m3', 'm-2'), ('m-3', 'P4'), 'M6') , 6
# ('m6', ('m-3', 'M2'), ('m2', 'm-3'), 'M6') , 6
# ('P5', ('P1', 'P1'), ('P4', 'm-2'), 'm3') , 6
# ('P5', ('P1', 'P1'), ('m-2', 'd1'), 'M6') , 6
# ('m6', ('P1', 'M-2'), ('M2', 'm2'), 'm3') , 6
# ('P4', ('P1', 'M2'), ('M2', 'm2'), 'M3') , 6
# ('m6', ('m-2', 'M-2'), ('P-4', 'm2'), 'M6') , 6
# ('P8', ('M-2', 'M-2'), ('P-4', 'm2'), 'P8') , 6
# ('P5', ('m2', 'm-2'), ('P-5', 'M2'), 'P8') , 6
# ('M3', ('M-2', 'M-2'), ('m-2', 'M-2'), 'm3') , 6
# ('m3', ('P1', 'P1'), ('P1', 'm3'), 'P8') , 6
# ('P8', ('M-2', 'M-2'), ('M2', 'm3'), 'm3') , 6
# ('P8', ('M2', 'm2'), ('M-2', 'm-3'), 'm6') , 6
# ('M3', ('m2', 'P1'), ('m-3', 'M-3'), 'P8') , 6
# ('P5', ('M2', 'M-3'), ('A1', 'm2'), 'm3') , 6
# ('m6', ('P4', 'm-2'), ('M-2', 'M-2'), 'M3') , 6
# ('M3', ('M2', 'm2'), ('P1', 'M-2'), 'M6') , 6
# ('m3', ('M2', 'P1'), ('m2', 'P1'), 'M3') , 6
# ('d5', ('m-2', 'M-2'), ('M2', 'm2'), 'P8') , 6
# ('M6', ('M-2', 'm-2'), ('m-2', 'P1'), 'P5') , 6
# ('M3', ('M-2', 'P1'), ('P5', 'P-8'), 'P5') , 6
# ('P8', ('M-2', 'P1'), ('M2', 'm2'), 'P5') , 6
# ('m6', ('M2', 'P1'), ('M-2', 'P4'), 'P5') , 6
# ('P8', ('P1', 'm-3'), ('P1', 'P-5'), 'M3') , 6
# ('m3', ('M3', 'M-2'), ('P-4', 'm3'), 'P5') , 6
# ('m3', ('m-2', 'P1'), ('P-5', 'M2'), 'P5') , 6
# ('M3', ('M2', 'M2'), ('P1', 'm-2'), 'M6') , 6
# ('P8', ('m2', 'M2'), ('M-2', 'm-3'), 'm6') , 6
# ('M6', ('M2', 'P1'), ('M2', 'M2'), 'P5') , 6
# ('M6', ('M2', 'P1'), ('m-2', 'P1'), 'P8') , 6
# ('M6', ('M-2', 'P4'), ('m-2', 'M-2'), 'm3') , 6
# ('M6', ('M2', 'm2'), ('M2', 'M2'), 'm6') , 6
# ('m6', ('P1', 'm-2'), ('M2', 'm2'), 'M3') , 6
# ('m3', ('M2', 'M-2'), ('m2', 'P-5'), 'M6') , 6
# ('P4', ('M2', 'm-3'), ('m-2', 'm2'), 'M3') , 6
# ('M6', ('M-2', 'P1'), ('m-2', 'M-2'), 'm7') , 6
# ('P5', ('P1', 'M2'), ('m-2', 'M-2'), 'P8') , 6
# ('P5', ('M2', 'm3'), ('P4', 'm-2'), 'm6') , 5
# ('P5', ('M2', 'm2'), ('P4', 'm-3'), 'm6') , 5
# ('M6', ('m2', 'M2'), ('M-2', 'P4'), 'M6') , 5
# ('M3', ('M2', 'm2'), ('m-3', 'P5'), 'm3') , 5
# ('m3', ('M2', 'M2'), ('M-3', 'M2'), 'M6') , 5
# ('M6', ('M-2', 'M-2'), ('P1', 'P-5'), 'P8') , 5
# ('A4', ('m2', 'm-2'), ('m-2', 'P-4'), 'P8') , 5
# ('M3', ('P1', 'M-2'), ('M3', 'm2'), 'M6') , 5
# ('P5', ('P1', 'M-2'), ('P-4', 'm3'), 'P5') , 5
# ('M6', ('m2', 'm-2'), ('M-2', 'M2'), 'M6') , 5
# ('M6', ('m3', 'm-2'), ('m-3', 'M2'), 'P8') , 5
# ('m3', ('P1', 'P1'), ('M-3', 'm-2'), 'm6') , 5
# ('m3', ('m-3', 'M-2'), ('P1', 'm3'), 'P5') , 5
# ('P8', ('M-2', 'm-3'), ('M2', 'm2'), 'M3') , 5
# ('M3', ('m3', 'm-3'), ('m-2', 'm2'), 'M3') , 5
# ('M6', ('m2', 'P1'), ('M-2', 'P4'), 'P5') , 5
# ('M6', ('m2', 'P1'), ('M-2', 'm-3'), 'm3') , 5
# ('m6', ('m-3', 'M2'), ('m2', 'M2'), 'M3') , 5
# ('P5', ('m3', 'M2'), ('P-4', 'm2'), 'M3') , 5
# ('M3', ('P1', 'M-2'), ('m-3', 'm-3'), 'm6') , 5
# ('m3', ('m-2', 'M-2'), ('P-4', 'm-3'), 'm6') , 5
# ('m3', ('M2', 'M-2'), ('m2', 'd-4'), 'd5') , 5
# ('P8', ('P1', 'm-2'), ('m-3', 'M-2'), 'M3') , 5
# ('M6', ('M2', 'M-3'), ('m-2', 'P4'), 'm3') , 5
# ('P5', ('M-2', 'M2'), ('m2', 'm-3'), 'M6') , 5
# ('P8', ('M3', 'm2'), ('M-2', 'm-2'), 'm6') , 5
# ('P5', ('P1', 'P1'), ('P1', 'P1'), 'P5') , 5
# ('m6', ('M-2', 'm-2'), ('m3', 'P-4'), 'P5') , 5
# ('m6', ('m-2', 'M-2'), ('P-8', 'P4'), 'P8') , 5
# ('M6', ('P1', 'm-2'), ('m-2', 'P4'), 'M3') , 5
# ('P5', ('M-2', 'M-2'), ('m2', 'M2'), 'P8') , 5
# ('P8', ('P1', 'm-3'), ('P1', 'M2'), 'P5') , 5
# ('P8', ('M2', 'M2'), ('m-2', 'd1'), 'A4') , 5
# ('P5', ('P1', 'M2'), ('M3', 'm2'), 'M3') , 5
# ('m6', ('M2', 'M2'), ('m2', 'm-2'), 'P8') , 5
# ('P5', ('m-2', 'P1'), ('m-3', 'M2'), 'P5') , 5
# ('m6', ('m-2', 'P1'), ('P1', 'P-8'), 'P5') , 5
# ('P5', ('M3', 'm2'), ('m-2', 'M-2'), 'm3') , 5
# ('M6', ('M-2', 'P1'), ('P1', 'P1'), 'P5') , 5
# ('M6', ('P1', 'm-3'), ('P1', 'm-3'), 'M6') , 5
# ('M6', ('m-3', 'M-2'), ('m-3', 'M-2'), 'M6') , 5
# ('M2', ('P1', 'P1'), ('m-2', 'M-3'), 'P5') , 5
# ('M3', ('M-2', 'M-2'), ('P4', 'm-2'), 'm6') , 5
# ('M6', ('M-2', 'M-2'), ('P1', 'P1'), 'P4') , 5
# ('m6', ('M3', 'M-2'), ('M-3', 'P5'), 'P5') , 5
# ('P8', ('m-3', 'M-2'), ('P4', 'P-4'), 'P5') , 5
# ('P8', ('M2', 'M2'), ('P1', 'P1'), 'M3') , 5
# ('m3', ('M2', 'm-3'), ('m-3', 'm2'), 'M3') , 5
# ('M3', ('P1', 'M-3'), ('P1', 'm-3'), 'm3') , 5
# ('m6', ('P1', 'P1'), ('m2', 'm-2'), 'm6') , 5
# ('P8', ('M2', 'P1'), ('P1', 'm-2'), 'm3') , 5
# ('M6', ('M-2', 'P1'), ('A1', 'm2'), 'P4') , 5
# ('m3', ('M2', 'm3'), ('m2', 'P-4'), 'P8') , 4
# ('A4', ('m2', 'M2'), ('m-2', 'm2'), 'M6') , 4
# ('m3', ('m-2', 'M-2'), ('M-2', 'P1'), 'M2') , 4
# ('M6', ('P1', 'M-2'), ('M2', 'm-3'), 'm6') , 4
# ('P8', ('M3', 'm2'), ('P8', 'm-3'), 'm6') , 4
# ('P5', ('m3', 'm-2'), ('P-4', 'M2'), 'P8') , 4
# ('M6', ('M-2', 'm-2'), ('M2', 'P-8'), 'M3') , 4
# ('P5', ('P1', 'M-2'), ('M-2', 'M-2'), 'M6') , 4
# ('M3', ('M-2', 'm-3'), ('M2', 'M2'), 'P5') , 4
# ('P8', ('P1', 'P1'), ('m-3', 'M-3'), 'P5') , 4
# ('P5', ('P1', 'm-3'), ('m-2', 'm2'), 'M3') , 4
# ('P5', ('m3', 'm-3'), ('M2', 'm2'), 'M3') , 4
# ('m3', ('m-2', 'M-2'), ('M2', 'M2'), 'm6') , 4
# ('P5', ('P1', 'M2'), ('P1', 'P4'), 'M3') , 4
# ('M6', ('M2', 'P1'), ('P4', 'm-2'), 'P5') , 4
# ('P8', ('M-2', 'M-2'), ('m2', 'A1'), 'd5') , 4
# ('m3', ('M-2', 'm-2'), ('P-4', 'm2'), 'M3') , 4
# ('m6', ('m-3', 'm3'), ('m2', 'M3'), 'm3') , 4
# ('m6', ('M-2', 'm-2'), ('M-2', 'm3'), 'M3') , 4
# ('M3', ('m-2', 'm2'), ('m-2', 'm-3'), 'm6') , 4
# ('M6', ('M-2', 'M2'), ('M-2', 'M3'), 'P5') , 4
# ('M6', ('M2', 'M2'), ('m-2', 'd1'), 'A2') , 4
# ('m6', ('m-2', 'M-2'), ('P1', 'M-3'), 'M6') , 4
# ('M3', ('M-2', 'P1'), ('d-5', 'm2'), 'P5') , 4
# ('m6', ('P1', 'M2'), ('m2', 'm-3'), 'P8') , 4
# ('P8', ('M2', 'm2'), ('m-2', 'm2'), 'm3') , 4
# ('P5', ('M2', 'm2'), ('P1', 'M-2'), 'P8') , 4
# ('M3', ('P-4', 'm3'), ('M3', 'P-4'), 'm3') , 4
# ('M3', ('M-2', 'M2'), ('P-4', 'A1'), 'm6') , 4
# ('M6', ('m2', 'm-3'), ('M-2', 'M2'), 'P5') , 4
# ('m3', ('P4', 'm-2'), ('M2', 'm2'), 'M3') , 4
# ('P8', ('M-2', 'm-2'), ('P-4', 'P5'), 'P5') , 4
# ('P8', ('m-2', 'M-2'), ('d-4', 'm2'), 'P8') , 4
# ('M3', ('P1', 'M-2'), ('P5', 'P1'), 'P5') , 4
# ('P5', ('P4', 'M-2'), ('m-3', 'm2'), 'P8') , 4
# ('M3', ('m3', 'M-2'), ('m-2', 'M-2'), 'm6') , 4
# ('m3', ('M2', 'P1'), ('m2', 'M3'), 'P8') , 4
# ('P8', ('P1', 'M-2'), ('M-3', 'P5'), 'P5') , 4
# ('P4', ('m-2', 'M-2'), ('M3', 'm3'), 'P5') , 4
# ('M3', ('P1', 'M-2'), ('P1', 'P1'), 'M2') , 4
# ('P5', ('M-2', 'M2'), ('M-3', 'M2'), 'M6') , 4
# ('M6', ('m-3', 'M-3'), ('M2', 'P-8'), 'P8') , 4
# ('P8', ('P1', 'm-2'), ('P4', 'M2'), 'M3') , 4
# ('M3', ('m2', 'M2'), ('P1', 'M-2'), 'M6') , 4
# ('M6', ('M-2', 'm-2'), ('m-2', 'P-4'), 'P8') , 4
# ('M3', ('m-2', 'm2'), ('m-2', 'P-5'), 'P8') , 4
# ('P8', ('P1', 'm-2'), ('P5', 'P-8'), 'M3') , 4
# ('P4', ('P1', 'M-2'), ('M-2', 'P-5'), 'P8') , 4
# ('P8', ('M-2', 'M-2'), ('m2', 'm-2'), 'm6') , 4
# ('P5', ('M2', 'P1'), ('P4', 'P-8'), 'M3') , 4
# ('m6', ('P1', 'M2'), ('m2', 'A1'), 'm6') , 4
# ('P5', ('P1', 'M2'), ('P1', 'm-3'), 'P8') , 4
# ('P5', ('M-2', 'm-2'), ('P1', 'P1'), 'M3') , 4
# ('M6', ('M2', 'P1'), ('m-2', 'P4'), 'P5') , 4
# ('m3', ('m-2', 'P1'), ('P-4', 'P1'), 'P5') , 4
# ('m6', ('m-2', 'P1'), ('M-2', 'M2'), 'P5') , 4
# ('P5', ('M2', 'M2'), ('P4', 'P1'), 'A4') , 4
# ('M2', ('M2', 'm2'), ('M-2', 'M-2'), 'M6') , 4
# ('P8', ('m-2', 'M-2'), ('M3', 'm-3'), 'm6') , 4
# ('M2', ('P1', 'M-2'), ('M-2', 'P1'), 'M2') , 4
# ('M3', ('M-2', 'P1'), ('P1', 'M2'), 'P8') , 4
# ('P5', ('M-2', 'P4'), ('m2', 'm-3'), 'P8') , 4
# ('M3', ('P4', 'P1'), ('m-3', 'P1'), 'P8') , 4
# ('M3', ('P1', 'P1'), ('P1', 'P1'), 'M3') , 4
# ('M3', ('P1', 'M-2'), ('P1', 'P-5'), 'M6') , 4
# ('M3', ('M-2', 'M-2'), ('P-5', 'M2'), 'P4') , 4
# ('M3', ('M-2', 'M-2'), ('P4', 'M2'), 'P4') , 4
# ('P8', ('M2', 'm2'), ('M-2', 'M6'), 'm6') , 4
# ('M3', ('M-2', 'P4'), ('M2', 'M2'), 'm3') , 4
# ('P5', ('m3', 'P-5'), ('P-4', 'm2'), 'P5') , 4
# ('M3', ('m3', 'M2'), ('m-2', 'M-2'), 'P8') , 4
# ('m3', ('P1', 'm-3'), ('P-4', 'm2'), 'M3') , 4
# ('m3', ('P1', 'm-2'), ('P4', 'P-5'), 'M3') , 4
# ('m6', ('M2', 'P1'), ('P4', 'M-2'), 'P5') , 4
# ('M6', ('P1', 'M2'), ('P1', 'm-2'), 'P8') , 4
# ('m6', ('M-3', 'P1'), ('m2', 'P1'), 'm3') , 4
# ('P8', ('m-3', 'P1'), ('P4', 'P1'), 'M3') , 4
# ('M2', ('P1', 'P1'), ('m-2', 'P-4'), 'm6') , 4
# ('A4', ('m2', 'm-2'), ('m-2', 'm3'), 'M3') , 4
# ('M2', ('P1', 'P1'), ('m-2', 'M-2'), 'P4') , 4
# ('M3', ('M-3', 'M2'), ('m-6', 'm3'), 'P5') , 4
# ('M3', ('P1', 'P1'), ('P1', 'M3'), 'P8') , 4
# ('P5', ('M-2', 'M2'), ('M2', 'M-3'), 'M6') , 4
# ('M3', ('M-2', 'P1'), ('P1', 'M-2'), 'M3') , 4
# ('m3', ('m2', 'm-2'), ('m2', 'M2'), 'P8') , 4
# ('M3', ('P1', 'M-3'), ('P1', 'P-5'), 'P5') , 4
# ('m6', ('P1', 'm-3'), ('M-3', 'P4'), 'M3') , 4
# ('P4', ('P1', 'M2'), ('M-2', 'P4'), 'M3') , 4
# ('P5', ('P1', 'P1'), ('m-2', 'P1'), 'm6') , 4
# ('M6', ('P1', 'M-3'), ('P1', 'M2'), 'm3') , 4
# ('M6', ('M-3', 'M2'), ('M2', 'P1'), 'P4') , 4
# ('P5', ('M-2', 'M-2'), ('M2', 'm2'), 'P8') , 4
# ('m3', ('M3', 'm2'), ('M-2', 'M-2'), 'P8') , 4
# ('P5', ('M-2', 'M-2'), ('M-3', 'A1'), 'd5') , 4
# ('m3', ('m-2', 'M-2'), ('P4', 'P-8'), 'P5') , 4
# ('M3', ('M-3', 'M2'), ('m-3', 'M-2'), 'P5') , 4
# ('P5', ('m-3', 'P4'), ('P1', 'm-3'), 'P8') , 4
# ('P5', ('M2', 'M-2'), ('P-5', 'M2'), 'P8') , 4
# ('P4', ('m-3', 'P1'), ('P5', 'P1'), 'P5') , 4
# ('P8', ('M2', 'M2'), ('P5', 'P4'), 'M3') , 3
# ('M3', ('m3', 'P-5'), ('m-2', 'M-2'), 'm3') , 3
# ('M3', ('M-2', 'M-2'), ('P5', 'P-5'), 'P8') , 3
# ('M6', ('m2', 'M2'), ('P5', 'M-3'), 'M6') , 3
# ('P5', ('M2', 'm2'), ('P4', 'M2'), 'm3') , 3
# ('P5', ('M-2', 'P1'), ('m2', 'P1'), 'M3') , 3
# ('M3', ('P1', 'M-2'), ('P1', 'P-4'), 'P5') , 3
# ('m3', ('M2', 'M-2'), ('m2', 'P5'), 'P5') , 3
# ('M3', ('M-2', 'M-2'), ('P-4', 'P4'), 'P8') , 3
# ('m3', ('m-2', 'M-2'), ('P5', 'm-3'), 'm6') , 3
# ('M3', ('P1', 'M-2'), ('P8', 'm-2'), 'm3') , 3
# ('M3', ('M-2', 'M2'), ('m-2', 'd1'), 'A4') , 3
# ('P8', ('m2', 'm-2'), ('M-2', 'P4'), 'M6') , 3
# ('m3', ('M2', 'M-2'), ('M2', 'm2'), 'P8') , 3
# ('M6', ('M-2', 'm3'), ('M-2', 'm-3'), 'm3') , 3
# ('m3', ('m-2', 'M-2'), ('P4', 'M-2'), 'M6') , 3
# ('M6', ('M-2', 'm-3'), ('m-2', 'm2'), 'M3') , 3
# ('P8', ('m-2', 'M-2'), ('M2', 'M2'), 'P4') , 3
# ('M6', ('M-2', 'm-2'), ('M2', 'P1'), 'M3') , 3
# ('d5', ('M-2', 'm-2'), ('m2', 'P5'), 'P5') , 3
# ('M6', ('M2', 'm3'), ('m-2', 'P1'), 'm3') , 3
# ('P8', ('m3', 'M2'), ('P1', 'M-3'), 'M6') , 3
# ('m6', ('P1', 'M-2'), ('m2', 'M2'), 'm3') , 3
# ('P5', ('M-2', 'M3'), ('M2', 'P1'), 'P5') , 3
# ('M3', ('M-2', 'm-3'), ('M2', 'P-5'), 'M3') , 3
# ('P4', ('M2', 'P1'), ('M-2', 'M2'), 'P5') , 3
# ('P8', ('m-3', 'm3'), ('M2', 'P-4'), 'm3') , 3
# ('M6', ('M-2', 'P1'), ('m-2', 'd1'), 'M6') , 3
# ('A4', ('m2', 'm-2'), ('M-2', 'm-2'), 'M6') , 3
# ('M6', ('m-2', 'M-2'), ('m-2', 'm-2'), 'm6') , 3
# ('M6', ('m3', 'M2'), ('M3', 'm2'), 'M6') , 3
# ('P8', ('M-2', 'P1'), ('M2', 'M2'), 'd5') , 3
# ('P5', ('M2', 'm3'), ('P4', 'M-2'), 'M6') , 3
# ('M6', ('M-2', 'P1'), ('m2', 'm-2'), 'P5') , 3
# ('P4', ('m-2', 'M-2'), ('P1', 'P-5'), 'M6') , 3
# ('P8', ('P5', 'P1'), ('m-2', 'm2'), 'P5') , 3
# ('P8', ('m-3', 'm3'), ('P4', 'M3'), 'm3') , 3
# ('P8', ('P1', 'P1'), ('m-3', 'm3'), 'P8') , 3
# ('P5', ('M-2', 'P1'), ('P1', 'm-2'), 'd5') , 3
# ('P4', ('P1', 'm-2'), ('m-2', 'm2'), 'M3') , 3
# ('P8', ('m2', 'P1'), ('M-2', 'P1'), 'm3') , 3
# ('A4', ('P1', 'M-2'), ('m-2', 'm-3'), 'm6') , 3
# ('d5', ('M-2', 'P1'), ('m2', 'M-6'), 'P8') , 3
# ('m6', ('M-2', 'm-2'), ('M-2', 'm-2'), 'm6') , 3
# ('m6', ('P1', 'M2'), ('m2', 'P1'), 'M6') , 3
# ('M3', ('M-2', 'M-2'), ('M2', 'A1'), 'd7') , 3
# ('M2', ('P1', 'M-2'), ('m-2', 'M-2'), 'm3') , 3
# ('M6', ('M2', 'M-2'), ('m-2', 'P-4'), 'm3') , 3
# ('P5', ('P1', 'P1'), ('m-2', 'M-3'), 'P8') , 3
# ('M3', ('M-3', 'M3'), ('M3', 'M-3'), 'M3') , 3
# ('m6', ('M3', 'M2'), ('M-3', 'm-3'), 'M6') , 3
# ('P8', ('m-3', 'M-2'), ('M2', 'P-5'), 'P8') , 3
# ('P5', ('P4', 'P-4'), ('m-3', 'P-4'), 'm3') , 3
# ('m3', ('P-4', 'M2'), ('P-4', 'm2'), 'M3') , 3
# ('m3', ('m-3', 'M-2'), ('P4', 'P-5'), 'P8') , 3
# ('m6', ('P-4', 'M2'), ('M-3', 'P4'), 'M3') , 3
# ('P5', ('M2', 'm2'), ('d-5', 'm2'), 'm3') , 3
# ('m6', ('m-2', 'M-2'), ('M-2', 'P-8'), 'P5') , 3
# ('M3', ('M-2', 'M2'), ('P-5', 'm-2'), 'P8') , 3
# ('M6', ('M-2', 'm3'), ('P1', 'P1'), 'm7') , 3
# ('P5', ('m3', 'm-2'), ('P1', 'P1'), 'M6') , 3
# ('m7', ('m-2', 'M-2'), ('P1', 'P1'), 'P5') , 3
# ('P5', ('M-2', 'm-3'), ('m-3', 'm2'), 'M3') , 3
# ('P8', ('M2', 'M-2'), ('m-2', 'm2'), 'P8') , 3
# ('M3', ('M-2', 'M2'), ('m-2', 'm2'), 'M3') , 3
# ('P8', ('M2', 'P1'), ('M-2', 'M3'), 'P8') , 3
# ('M6', ('M-2', 'P4'), ('P1', 'm-3'), 'm3') , 3
# ('m3', ('M2', 'P1'), ('m2', 'P-8'), 'M3') , 3
# ('P8', ('M2', 'P1'), ('M-2', 'P8'), 'M3') , 3
# ('M6', ('M-2', 'P1'), ('P1', 'P-8'), 'P5') , 3
# ('m6', ('m-3', 'M2'), ('P1', 'M-2'), 'M6') , 3
# ('M3', ('M-2', 'P4'), ('P1', 'M-2'), 'M6') , 3
# ('P5', ('M-2', 'M2'), ('P1', 'M-2'), 'M6') , 3
# ('M6', ('M2', 'P1'), ('m-2', 'M-3'), 'M3') , 3
# ('P8', ('m-2', 'M-2'), ('M3', 'M-3'), 'M6') , 3
# ('M3', ('m3', 'M-2'), ('P1', 'P1'), 'P4') , 3
# ('P5', ('P1', 'M-2'), ('P-4', 'M2'), 'm6') , 3
# ('P5', ('M2', 'P1'), ('P4', 'm-3'), 'P5') , 3
# ('M6', ('m3', 'm-2'), ('M3', 'P-8'), 'P5') , 3
# ('P8', ('M3', 'm2'), ('P1', 'P1'), 'P4') , 3
# ('P4', ('M2', 'M-2'), ('M-2', 'm-2'), 'm6') , 3
# ('P5', ('P1', 'M-2'), ('P-4', 'm2'), 'M6') , 3
# ('m3', ('m-2', 'M-2'), ('P4', 'A1'), 'd5') , 3
# ('m3', ('M-2', 'm-2'), ('M-2', 'P5'), 'P5') , 3
# ('M3', ('M2', 'm-3'), ('m-3', 'M2'), 'M3') , 3
# ('P5', ('P1', 'M-2'), ('A1', 'm2'), 'm3') , 3
# ('M3', ('P1', 'm-2'), ('m-3', 'M2'), 'M3') , 3
# ('P5', ('m2', 'M2'), ('P1', 'M-2'), 'P8') , 3
# ('m6', ('m-3', 'M-3'), ('m2', 'P1'), 'P8') , 3
# ('P4', ('P1', 'M-2'), ('m-2', 'm2'), 'm3') , 3
# ('M3', ('m3', 'm-2'), ('m-2', 'P1'), 'P5') , 3
# ('m6', ('m-2', 'M-2'), ('P1', 'P-5'), 'P8') , 3
# ('m3', ('m-2', 'M-2'), ('M-2', 'M-2'), 'M3') , 3
# ('M2', ('P4', 'P1'), ('M-2', 'P4'), 'M3') , 3
# ('m3', ('M-2', 'M-2'), ('m2', 'A1'), 'd7') , 3
# ('P5', ('P1', 'm-2'), ('M2', 'P-8'), 'M3') , 3
# ('P5', ('M2', 'P1'), ('A1', 'm2'), 'P5') , 3
# ('P5', ('M-2', 'M-2'), ('m6', 'm-2'), 'm6') , 3
# ('P8', ('m-2', 'M-2'), ('P5', 'P-4'), 'P5') , 3
# ('P5', ('P4', 'M-2'), ('M-3', 'M2'), 'P8') , 3
# ('M3', ('M2', 'm2'), ('m-3', 'M2'), 'm6') , 3
# ('M3', ('M-2', 'M-2'), ('d-5', 'm3'), 'm3') , 3
# ('m3', ('M2', 'P1'), ('m2', 'm-6'), 'P8') , 3
# ('P5', ('P4', 'M-2'), ('M-3', 'd-4'), 'd5') , 3
# ('M3', ('P1', 'M2'), ('m-3', 'P4'), 'M3') , 3
# ('m3', ('m-2', 'P1'), ('P1', 'm-2'), 'm3') , 3
# ('m3', ('M3', 'M-2'), ('M-2', 'M-2'), 'M6') , 3
# ('M6', ('P1', 'M-2'), ('M2', 'm2'), 'M3') , 3
# ('A4', ('m2', 'P1'), ('M-2', 'm-2'), 'm7') , 3
# ('R', ('P1', 'M2'), ('R', 'M2'), 'M3') , 3
# ('P5', ('P1', 'M-2'), ('P1', 'm-3'), 'm6') , 3
# ('P5', ('M-2', 'P1'), ('m2', 'm-3'), 'P5') , 3
# ('P8', ('m-3', 'M-2'), ('M2', 'M-3'), 'M6') , 3
# ('m3', ('P1', 'M2'), ('M-3', 'P4'), 'M3') , 3
# ('P5', ('M2', 'P1'), ('P4', 'P1'), 'M3') , 3
# ('P8', ('P1', 'P1'), ('P1', 'M-3'), 'M3') , 3
# ('P8', ('P1', 'M-2'), ('M-3', 'P4'), 'M6') , 3
# ('m3', ('M-2', 'P4'), ('m2', 'M-3'), 'M6') , 3
# ('P8', ('P4', 'P1'), ('M-3', 'P1'), 'M6') , 3
# ('M6', ('M-2', 'M2'), ('M-2', 'M2'), 'M6') , 3
# ('M3', ('M-2', 'M-2'), ('P-5', 'm-2'), 'm6') , 3
# ('M6', ('P4', 'P1'), ('m-2', 'P1'), 'm3') , 3
# ('m6', ('P1', 'm-2'), ('M-2', 'P1'), 'M6') , 3
# ('m7', ('m-2', 'm2'), ('P1', 'M-2'), 'P8') , 3
# ('M6', ('M-2', 'm-2'), ('M2', 'A1'), 'm3') , 3
# ('P4', ('m-2', 'm2'), ('A1', 'm2'), 'm3') , 3
# ('M3', ('m2', 'm-2'), ('M6', 'M-2'), 'M6') , 3
# ('P4', ('m-2', 'm2'), ('P1', 'm-3'), 'm6') , 3
# ('m3', ('P1', 'm-2'), ('d1', 'm-2'), 'M3') , 3
# ('m6', ('m-2', 'm2'), ('P1', 'P-5'), 'm3') , 3
# ('M6', ('m2', 'm-2'), ('M2', 'M-2'), 'M6') , 3
# ('P5', ('M2', 'M-2'), ('P1', 'P1'), 'P5') , 3
# ('M3', ('m2', 'M2'), ('M2', 'm-3'), 'm6') , 3
# ('m3', ('M2', 'M-2'), ('m2', 'd-5'), 'm6') , 3
# ('M3', ('P1', 'P4'), ('m-3', 'M-3'), 'M3') , 3
# ('P5', ('M2', 'M-2'), ('P4', 'P-5'), 'M6') , 3
# ('M3', ('P4', 'M-2'), ('P1', 'P1'), 'P5') , 3
# ('M6', ('M2', 'M-2'), ('m-2', 'm2'), 'M6') , 3
# ('m6', ('P1', 'P1'), ('m2', 'P1'), 'P5') , 3
# ('A2', ('m2', 'M2'), ('m-2', 'M-2'), 'M6') , 3
# ('M3', ('m2', 'm-3'), ('m-3', 'm2'), 'M3') , 3
# ('m6', ('m-3', 'P1'), ('m2', 'P-8'), 'M3') , 3
# ('m6', ('M2', 'm-3'), ('M-2', 'P4'), 'M3') , 3
# ('M3', ('M-3', 'M2'), ('M3', 'm3'), 'P5') , 3
# ('m3', ('m-2', 'M-2'), ('M2', 'M-6'), 'P5') , 3
# ('M6', ('m2', 'M3'), ('M-2', 'P8'), 'M3') , 3
# ('P8', ('M3', 'M-2'), ('P8', 'P1'), 'M2') , 3
# ('d5', ('m-2', 'm2'), ('m2', 'm-3'), 'm6') , 3
# ('m6', ('m-3', 'P1'), ('m2', 'm-6'), 'P8') , 3
# ('M3', ('M-3', 'M2'), ('P1', 'P1'), 'M2') , 3
# ('P8', ('P4', 'M2'), ('m-3', 'M-2'), 'P8') , 3
# ('M3', ('M-3', 'M2'), ('P-5', 'P4'), 'M3') , 3
# ('M3', ('M-3', 'M2'), ('m-3', 'm2'), 'M3') , 3
# ('M6', ('m2', 'P1'), ('M-2', 'P1'), 'P8') , 3
# ('m7', ('M-2', 'm-2'), ('P-5', 'M2'), 'P8') , 3
# ('M2', ('P4', 'm-3'), ('m-2', 'm2'), 'M3') , 3
# ('m6', ('m-3', 'M-2'), ('m2', 'P5'), 'P5') , 3
# ('M6', ('m2', 'P-4'), ('M-2', 'm-2'), 'm6') , 3
# ('P8', ('P-4', 'P4'), ('m-2', 'M-2'), 'm3') , 3
# ('m6', ('m-3', 'M-2'), ('m2', 'P1'), 'M2') , 3
# ('P5', ('M2', 'M-2'), ('P1', 'M-2'), 'M6') , 3
# ('M6', ('m2', 'm-2'), ('M2', 'm3'), 'M3') , 3
# ('P8', ('m-3', 'P1'), ('P4', 'm-3'), 'P5') , 3
# ('P8', ('P1', 'm-2'), ('m-3', 'P5'), 'P5') , 3
# ('M3', ('m3', 'M-2'), ('M3', 'm2'), 'P8') , 3
# ('m6', ('P1', 'M3'), ('P1', 'M-3'), 'M3') , 3
# ('m6', ('M3', 'M-2'), ('M-3', 'P4'), 'M6') , 3
# ('M3', ('P1', 'M-3'), ('P1', 'm-6'), 'm6') , 3
# ('A4', ('m2', 'P1'), ('m-2', 'P1'), 'm6') , 3
# ('m3', ('m-2', 'P1'), ('P-5', 'P1'), 'M6') , 3
# ('m6', ('M2', 'm-3'), ('M2', 'm2'), 'M3') , 3
# ('m6', ('M-3', 'M2'), ('m2', 'M-3'), 'M6') , 3
# ('P8', ('P1', 'P1'), ('M6', 'M-3'), 'P5') , 3
# ('m3', ('P-4', 'P4'), ('m3', 'm-3'), 'm3') , 3
# ('M2', ('P4', 'M2'), ('m-2', 'M-2'), 'P8') , 3
# ('P8', ('M3', 'm3'), ('P8', 'm-2'), 'm6') , 3
# ('m3', ('M2', 'P1'), ('m2', 'P8'), 'M3') , 3
# ('m6', ('P1', 'm-2'), ('m3', 'P-8'), 'M3') , 3
# ('P8', ('M2', 'm2'), ('M-2', 'P4'), 'P8') , 3
# ('M3', ('m2', 'm-2'), ('m-3', 'M-2'), 'M6') , 3
# ('P8', ('P1', 'm-2'), ('m-3', 'P-4'), 'P5') , 3
# ('M3', ('M-3', 'M2'), ('M3', 'm2'), 'M6') , 3
# ('P8', ('P1', 'm-2'), ('M2', 'M2'), 'P5') , 3
# ('m7', ('m-2', 'M-2'), ('M2', 'm2'), 'M3') , 3
# ('m3', ('M2', 'M-2'), ('m2', 'P4'), 'M6') , 3
# ('P5', ('m3', 'P-4'), ('P-4', 'M2'), 'm6') , 3
# ('m3', ('P-4', 'm-3'), ('M2', 'm2'), 'M3') , 3
# ('M3', ('m2', 'P1'), ('m2', 'm-3'), 'P5') , 3
# ('m3', ('P1', 'M2'), ('M-2', 'm-2'), 'm6') , 3
# ('d5', ('P1', 'm-2'), ('m2', 'P1'), 'M3') , 3
# ('P4', ('P1', 'M-2'), ('M-2', 'm-3'), 'm6') , 3
# ('M6', ('P4', 'm-3'), ('m-3', 'P5'), 'P5') , 3
# ('P8', ('P4', 'm-3'), ('m-3', 'm2'), 'M3') , 3
# ('P8', ('m-2', 'M-3'), ('M2', 'M2'), 'm3') , 3
# ('m6', ('M2', 'P1'), ('M-2', 'P1'), 'P8') , 3
# ('m6', ('P-5', 'm-2'), ('M-2', 'M-2'), 'M3') , 2
# ('P8', ('M-2', 'M2'), ('m3', 'P4'), 'M3') , 2
# ('P8', ('M2', 'm3'), ('M-2', 'm-2'), 'm6') , 2
# ('M3', ('M-2', 'M2'), ('P1', 'M-2'), 'A4') , 2
# ('M3', ('m2', 'M2'), ('M2', 'M-3'), 'M6') , 2
# ('M3', ('m3', 'P-5'), ('M2', 'M2'), 'm6') , 2
# ('P4', ('P-5', 'm-2'), ('M2', 'm3'), 'M3') , 2
# ('M2', ('M2', 'm2'), ('P1', 'm-3'), 'm6') , 2
# ('M3', ('M2', 'm2'), ('M2', 'M2'), 'm3') , 2
# ('M3', ('M2', 'm2'), ('P8', 'm-2'), 'm6') , 2
# ('m6', ('m-2', 'M-2'), ('R', 'R'), 'M6') , 2
# ('R', ('M-2', 'P1'), ('R', 'M2'), 'P5') , 2
# ('M6', ('m2', 'M2'), ('M-2', 'P8'), 'M2') , 2
# ('P8', ('M-2', 'm3'), ('m3', 'P-4'), 'm3') , 2
# ('M3', ('P1', 'M-2'), ('P5', 'M-2'), 'M6') , 2
# ('m6', ('m-3', 'm3'), ('m2', 'P-4'), 'P8') , 2
# ('M3', ('m3', 'm-3'), ('P-4', 'M2'), 'P5') , 2
# ('P8', ('m-3', 'M-2'), ('M2', 'm-3'), 'm6') , 2
# ('d7', ('m-2', 'M-2'), ('m2', 'm-3'), 'm6') , 2
# ('m3', ('M3', 'm3'), ('P1', 'M2'), 'm6') , 2
# ('m6', ('P1', 'P1'), ('M-3', 'P4'), 'P5') , 2
# ('P5', ('P1', 'M2'), ('m-6', 'm2'), 'M3') , 2
# ('M6', ('M2', 'm3'), ('m-2', 'M-2'), 'P4') , 2
# ('P8', ('m3', 'M2'), ('M-2', 'M-2'), 'M6') , 2
# ('P5', ('P1', 'm-3'), ('P-4', 'M2'), 'P5') , 2
# ('P5', ('m3', 'm-3'), ('P-4', 'P1'), 'P8') , 2
# ('m6', ('M3', 'm3'), ('M-3', 'm-2'), 'm6') , 2
# ('m6', ('P5', 'P1'), ('M-2', 'M-2'), 'P5') , 2
# ('M6', ('M2', 'M-2'), ('m-2', 'M2'), 'm6') , 2
# ('P8', ('m-3', 'm3'), ('M2', 'M2'), 'm6') , 2
# ('P5', ('m2', 'm-2'), ('m-2', 'm2'), 'P5') , 2
# ('P8', ('P5', 'P1'), ('P1', 'P1'), 'P5') , 2
# ('m3', ('M2', 'P1'), ('m-3', 'm2'), 'P5') , 2
# ('m6', ('m-3', 'm3'), ('m2', 'm-2'), 'm6') , 2
# ('R', ('P5', 'P1'), ('R', 'R'), 'P8') , 2
# ('M3', ('m3', 'M2'), ('M-2', 'P4'), 'A4') , 2
# ('P8', ('P1', 'P1'), ('P1', 'P4'), 'P5') , 2
# ('P8', ('P1', 'P1'), ('P4', 'm-2'), 'm6') , 2
# ('M6', ('m-2', 'M-2'), ('m-2', 'm2'), 'A4') , 2
# ('P8', ('P1', 'P1'), ('P4', 'P-4'), 'P8') , 2
# ('M6', ('M-2', 'm-2'), ('A1', 'm2'), 'M3') , 2
# ('P8', ('m-2', 'M-2'), ('M2', 'P1'), 'P5') , 2
# ('P8', ('M-2', 'P1'), ('m2', 'P1'), 'M6') , 2
# ('M6', ('P1', 'M-2'), ('P1', 'm-2'), 'm6') , 2
# ('m3', ('M2', 'M-2'), ('m2', 'm-2'), 'm3') , 2
# ('m3', ('M2', 'M2'), ('m2', 'P1'), 'A4') , 2
# ('M3', ('M-2', 'M-2'), ('P-4', 'P1'), 'P4') , 2
# ('M6', ('M2', 'm2'), ('P1', 'P1'), 'P8') , 2
# ('d5', ('M-2', 'm-3'), ('m2', 'P-5'), 'P5') , 2
# ('P5', ('M-2', 'M-2'), ('m-3', 'M-2'), 'm6') , 2
# ('m6', ('m-3', 'm3'), ('m2', 'P1'), 'P5') , 2
# ('M3', ('m3', 'M2'), ('P1', 'm-3'), 'P8') , 2
# ('P5', ('M2', 'M-2'), ('m-3', 'm3'), 'P5') , 2
# ('P5', ('M-2', 'P1'), ('M2', 'P1'), 'm3') , 2
# ('m3', ('P1', 'm-2'), ('P1', 'P-4'), 'P5') , 2
# ('m3', ('M-2', 'm-3'), ('m2', 'M2'), 'P5') , 2
# ('m7', ('M-2', 'm-2'), ('P4', 'P-4'), 'P5') , 2
# ('P8', ('M3', 'm2'), ('P8', 'P1'), 'P4') , 2
# ('P4', ('M2', 'M-2'), ('m-2', 'M-2'), 'm6') , 2
# ('M3', ('M-2', 'M2'), ('P-5', 'M3'), 'P5') , 2
# ('P8', ('m2', 'M2'), ('M-2', 'm6'), 'M6') , 2
# ('m3', ('m-3', 'M2'), ('P1', 'M-2'), 'M3') , 2
# ('M3', ('M-2', 'M-2'), ('P4', 'M3'), 'm3') , 2
# ('m6', ('m-2', 'M-2'), ('m-2', 'M-3'), 'm7') , 2
# ('m6', ('M-2', 'M-2'), ('M-3', 'P4'), 'm3') , 2
# ('d5', ('M-2', 'P1'), ('m2', 'm-3'), 'd5') , 2
# ('P5', ('M2', 'M2'), ('m-3', 'm-2'), 'm3') , 2
# ('m3', ('m2', 'P1'), ('m2', 'P1'), 'm3') , 2
# ('m3', ('M-2', 'P1'), ('M-2', 'P-5'), 'm7') , 2
# ('M3', ('m3', 'M2'), ('M-2', 'm-2'), 'P8') , 2
# ('m3', ('M-2', 'P1'), ('m2', 'm-3'), 'm3') , 2
# ('P8', ('P1', 'm3'), ('P4', 'P-4'), 'm3') , 2
# ('P5', ('m3', 'M-2'), ('P-4', 'm3'), 'm7') , 2
# ('P5', ('M2', 'M-3'), ('P4', 'm-6'), 'm6') , 2
# ('M3', ('M-3', 'm-3'), ('m-6', 'm2'), 'M3') , 2
# ('P5', ('P1', 'P1'), ('P1', 'm-2'), 'm6') , 2
# ('P5', ('m3', 'm-2'), ('M2', 'm3'), 'M3') , 2
# ('A4', ('m2', 'M2'), ('m-2', 'm3'), 'P5') , 2
# ('m6', ('M2', 'M-2'), ('m3', 'P-5'), 'P8') , 2
# ('P8', ('P4', 'm-2'), ('m-3', 'M-2'), 'M6') , 2
# ('P8', ('m2', 'm-3'), ('M-2', 'P4'), 'P5') , 2
# ('P8', ('P4', 'P-4'), ('m-3', 'M-3'), 'P5') , 2
# ('P5', ('M2', 'P-4'), ('P4', 'M3'), 'P5') , 2
# ('P5', ('P1', 'P1'), ('P5', 'P-8'), 'P8') , 2
# ('P8', ('P1', 'P1'), ('P-8', 'P4'), 'P5') , 2
# ('P8', ('M-2', 'M-2'), ('P1', 'P-5'), 'm3') , 2
# ('m3', ('P-4', 'M2'), ('M-2', 'M-2'), 'M3') , 2
# ('P8', ('M-2', 'm-2'), ('P5', 'P-4'), 'P5') , 2
# ('m3', ('m-2', 'M2'), ('P-4', 'P4'), 'M3') , 2
# ('P8', ('M-2', 'M2'), ('m3', 'P-5'), 'M3') , 2
# ('P5', ('M2', 'M-3'), ('P-5', 'M3'), 'm6') , 2
# ('m6', ('m-3', 'M2'), ('P4', 'M-2'), 'M3') , 2
# ('P5', ('P1', 'P1'), ('M2', 'P-5'), 'P8') , 2
# ('P4', ('P1', 'P1'), ('P-5', 'P4'), 'P5') , 2
# ('P8', ('M2', 'P-4'), ('M-2', 'M3'), 'P5') , 2
# ('P8', ('M-3', 'm-3'), ('P4', 'P-5'), 'P5') , 2
# ('M2', ('P1', 'm3'), ('m-2', 'M-2'), 'm6') , 2
# ('m3', ('M2', 'm2'), ('m2', 'm-3'), 'm6') , 2
# ('P8', ('m-3', 'M-3'), ('A1', 'm2'), 'm3') , 2
# ('M3', ('m2', 'M2'), ('P1', 'P-8'), 'P5') , 2
# ('P4', ('M2', 'M-2'), ('P-8', 'P4'), 'P8') , 2
# ('M3', ('m2', 'm-3'), ('M2', 'P-5'), 'P5') , 2
# ('M2', ('P4', 'P-4'), ('m-2', 'm3'), 'P8') , 2
# ('m6', ('P-4', 'M2'), ('m3', 'M-2'), 'M3') , 2
# ('M3', ('P-4', 'm3'), ('M3', 'M-2'), 'P8') , 2
# ('m6', ('m-3', 'M-3'), ('m2', 'P4'), 'P5') , 2
# ('M3', ('M2', 'm2'), ('m-3', 'P-4'), 'm3') , 2
# ('P5', ('P4', 'P-4'), ('m-3', 'm3'), 'P5') , 2
# ('m3', ('P-4', 'M2'), ('m3', 'P-5'), 'M3') , 2
# ('m6', ('P1', 'M-2'), ('m2', 'M-3'), 'M6') , 2
# ('P5', ('M-2', 'm3'), ('M-3', 'm-3'), 'm3') , 2
# ('P8', ('M-2', 'M-2'), ('m2', 'M2'), 'P4') , 2
# ('M6', ('m2', 'm-2'), ('M-2', 'd-4'), 'm3') , 2
# ('M6', ('M2', 'm2'), ('d-4', 'm2'), 'm3') , 2
# ('m3', ('M2', 'M-2'), ('P-5', 'M2'), 'm6') , 2
# ('M6', ('M-2', 'M-2'), ('P1', 'm-3'), 'm6') , 2
# ('M2', ('P4', 'm-2'), ('m-2', 'M-2'), 'M6') , 2
# ('M3', ('m3', 'M-2'), ('m-2', 'm3'), 'm3') , 2
# ('M3', ('m2', 'm-3'), ('P-5', 'P4'), 'M3') , 2
# ('P8', ('m-3', 'M2'), ('P4', 'm-3'), 'M6') , 2
# ('P8', ('M-2', 'P4'), ('m3', 'm-3'), 'm3') , 2
# ('M3', ('M-2', 'M-2'), ('P5', 'm-3'), 'm6') , 2
# ('P5', ('P1', 'M-2'), ('M-2', 'P1'), 'P5') , 2
# ('P8', ('P1', 'm-2'), ('m-3', 'P4'), 'M6') , 2
# ('M3', ('m3', 'M-2'), ('M-2', 'M-2'), 'M6') , 2
# ('M6', ('M-2', 'm-2'), ('M-2', 'm-2'), 'M6') , 2
# ('P8', ('P1', 'm-2'), ('M3', 'M-2'), 'M6') , 2
# ('M3', ('P1', 'M-2'), ('P8', 'P-4'), 'P5') , 2
# ('M3', ('M-2', 'M-2'), ('P5', 'P1'), 'P4') , 2
# ('m6', ('M-2', 'm-2'), ('m3', 'M2'), 'P8') , 2
# ('M3', ('m2', 'm-3'), ('P1', 'P1'), 'M2') , 2
# ('P5', ('M-2', 'm-2'), ('P1', 'M3'), 'P8') , 2
# ('P8', ('P1', 'm-2'), ('d-5', 'm2'), 'M3') , 2
# ('M6', ('M-2', 'M-2'), ('M7', 'M-2'), 'm6') , 2
# ('M3', ('m3', 'M-2'), ('M2', 'm3'), 'P8') , 2
# ('P4', ('M-2', 'm-2'), ('m3', 'M2'), 'M6') , 2
# ('m3', ('m2', 'm-2'), ('m2', 'P-4'), 'P5') , 2
# ('P5', ('M-2', 'm3'), ('M-3', 'M3'), 'm6') , 2
# ('P4', ('m-2', 'm2'), ('P-8', 'm2'), 'M3') , 2
# ('P5', ('M-2', 'm-3'), ('M2', 'M-3'), 'M3') , 2
# ('m3', ('m-3', 'M2'), ('M-3', 'M2'), 'M3') , 2
# ('m6', ('m-2', 'M-2'), ('P1', 'm2'), 'M3') , 2
# ('M3', ('M2', 'm-3'), ('d-3', 'm2'), 'M3') , 2
# ('m3', ('m-2', 'P4'), ('P1', 'M-2'), 'M6') , 2
# ('d7', ('m-2', 'M-2'), ('m2', 'm2'), 'M3') , 2
# ('P5', ('M-2', 'm3'), ('m2', 'm-2'), 'm6') , 2
# ('M6', ('P1', 'M-2'), ('m-2', 'P4'), 'm3') , 2
# ('P5', ('M-2', 'm3'), ('m2', 'P-4'), 'P8') , 2
# ('P8', ('m-2', 'M-2'), ('M3', 'P-5'), 'P8') , 2
# ('M3', ('P1', 'M-2'), ('P8', 'P-5'), 'M6') , 2
# ('m3', ('M-2', 'm3'), ('m2', 'P-4'), 'm6') , 2
# ('P5', ('P1', 'M-2'), ('m-2', 'M-2'), 'm6') , 2
# ('M3', ('M-2', 'M-2'), ('M2', 'P-4'), 'm3') , 2
# ('m3', ('m2', 'm-2'), ('m2', 'P4'), 'M6') , 2
# ('P5', ('M2', 'P1'), ('P4', 'M3'), 'P8') , 2
# ('P5', ('M2', 'P1'), ('m-3', 'P4'), 'P5') , 2
# ('P8', ('M2', 'm2'), ('M-2', 'm-2'), 'd5') , 2
# ('d5', ('m-2', 'M-2'), ('m2', 'P4'), 'M6') , 2
# ('M3', ('m-2', 'm2'), ('m-2', 'P4'), 'P8') , 2
# ('m6', ('P5', 'm-3'), ('M-2', 'M-2'), 'M3') , 2
# ('M3', ('M-3', 'P5'), ('P1', 'm-2'), 'm6') , 2
# ('P8', ('P5', 'M2'), ('m-2', 'M-2'), 'P8') , 2
# ('P5', ('P1', 'M2'), ('P-8', 'P4'), 'M3') , 2
# ('m6', ('m-3', 'M-3'), ('m2', 'm-3'), 'm3') , 2
# ('P5', ('M2', 'P1'), ('P-5', 'P8'), 'M3') , 2
# ('m3', ('m-2', 'M-2'), ('P4', 'm3'), 'M3') , 2
# ('P8', ('m-2', 'M-2'), ('P5', 'P1'), 'M2') , 2
# ('M6', ('P4', 'M-2'), ('M-2', 'm-2'), 'm3') , 2
# ('P8', ('M-2', 'P1'), ('m3', 'M3'), 'm3') , 2
# ('m3', ('M2', 'P1'), ('m2', 'm-3'), 'P5') , 2
# ('M3', ('P4', 'M-2'), ('P1', 'M-2'), 'M6') , 2
# ('m3', ('P5', 'm-3'), ('M2', 'm2'), 'M3') , 2
# ('P8', ('m-2', 'M-2'), ('P5', 'P-5'), 'M6') , 2
# ('M3', ('P1', 'M-2'), ('m-6', 'M2'), 'm6') , 2
# ('m3', ('M-2', 'M-2'), ('M-2', 'M-2'), 'm3') , 2
# ('M3', ('P1', 'm2'), ('M-2', 'm-2'), 'm6') , 2
# ('M6', ('m2', 'M-2'), ('M-2', 'P5'), 'm3') , 2
# ('d5', ('M-2', 'm-2'), ('m2', 'P-5'), 'M6') , 2
# ('P5', ('P1', 'M2'), ('m3', 'P1'), 'A4') , 2
# ('A4', ('m2', 'P1'), ('M-2', 'P4'), 'M3') , 2
# ('A4', ('m2', 'm-2'), ('m-2', 'P1'), 'P5') , 2
# ('P5', ('P1', 'M2'), ('P5', 'P1'), 'M2') , 2
# ('P8', ('m-2', 'M-2'), ('P5', 'd-5'), 'm6') , 2
# ('P5', ('P1', 'M2'), ('m-2', 'm2'), 'M6') , 2
# ('m3', ('M3', 'M-2'), ('P1', 'M-3'), 'M6') , 2
# ('P5', ('M-2', 'M-2'), ('M-3', 'P1'), 'P5') , 2
# ('M6', ('M-2', 'm-2'), ('P1', 'm-3'), 'M6') , 2
# ('M3', ('M2', 'm2'), ('d-7', 'm2'), 'm3') , 2
# ('d5', ('m-2', 'm2'), ('m2', 'P-5'), 'P8') , 2
# ('M6', ('M-2', 'M-2'), ('P1', 'M2'), 'm3') , 2
# ('A2', ('m2', 'P1'), ('m-2', 'm-2'), 'd5') , 2
# ('M3', ('P1', 'M-2'), ('A1', 'm2'), 'P8') , 2
# ('M3', ('M2', 'M2'), ('M2', 'P1'), 'A4') , 2
# ('M6', ('m2', 'm-2'), ('M-2', 'M3'), 'P5') , 2
# ('m6', ('P1', 'M-2'), ('P4', 'P-5'), 'm6') , 2
# ('m6', ('M-2', 'm-2'), ('m3', 'P-5'), 'M6') , 2
# ('M3', ('M2', 'm2'), ('m-3', 'm2'), 'M6') , 2
# ('M3', ('M-2', 'P4'), ('P-4', 'M6'), 'm3') , 2
# ('P5', ('P4', 'P1'), ('M6', 'M-3'), 'P5') , 2
# ('P8', ('M2', 'M-2'), ('M-2', 'm-2'), 'm3') , 2
# ('P8', ('P1', 'P1'), ('P4', 'M-2'), 'M6') , 2
# ('m3', ('M-2', 'P4'), ('m2', 'M6'), 'm6') , 2
# ('M3', ('M-2', 'P4'), ('M2', 'm-3'), 'm6') , 2
# ('P4', ('M2', 'M-2'), ('M-2', 'M-2'), 'M6') , 2
# ('P4', ('m-2', 'm2'), ('P1', 'P4'), 'P8') , 2
# ('m3', ('P1', 'm-3'), ('P1', 'm-3'), 'm3') , 2
# ('m3', ('m-3', 'M-2'), ('m-3', 'm2'), 'P8') , 2
# ('m3', ('M-2', 'M2'), ('m2', 'P4'), 'M6') , 2
# ('M2', ('P4', 'P1'), ('m-2', 'M-2'), 'm7') , 2
# ('P8', ('m-2', 'M-2'), ('M2', 'M-2'), 'M6') , 2
# ('M6', ('M-2', 'P4'), ('M-2', 'm-2'), 'm3') , 2
# ('A4', ('P1', 'M-2'), ('m-2', 'P-5'), 'P8') , 2
# ('P5', ('m3', 'M2'), ('M-2', 'm-2'), 'm3') , 2
# ('P8', ('M2', 'M-2'), ('m-2', 'd1'), 'M2') , 2
# ('m6', ('P1', 'm-2'), ('P4', 'M-2'), 'M3') , 2
# ('m3', ('m-2', 'm2'), ('M-2', 'm-3'), 'm6') , 2
# ('m6', ('P1', 'm-2'), ('m3', 'P1'), 'M3') , 2
# ('M3', ('M2', 'P1'), ('m-3', 'M2'), 'P5') , 2
# ('P8', ('m3', 'M2'), ('P-4', 'm2'), 'M6') , 2
# ('m6', ('M2', 'M-2'), ('m2', 'm-2'), 'm6') , 2
# ('P5', ('m3', 'M2'), ('M2', 'm2'), 'M6') , 2
# ('m6', ('P4', 'P1'), ('M-2', 'd1'), 'M3') , 2
# ('P5', ('P4', 'P1'), ('m-3', 'M-3'), 'P5') , 2
# ('M6', ('M2', 'P1'), ('M3', 'P1'), 'P5') , 2
# ('P8', ('M3', 'm2'), ('P1', 'M2'), 'm3') , 2
# ('M6', ('M-2', 'M2'), ('P1', 'P4'), 'M3') , 2
# ('P8', ('P1', 'm-2'), ('P-4', 'P1'), 'M3') , 2
# ('m3', ('P-5', 'M2'), ('m2', 'm-3'), 'P8') , 2
# ('m3', ('M2', 'm2'), ('m2', 'M2'), 'm3') , 2
# ('m3', ('P-5', 'M2'), ('m2', 'P1'), 'M6') , 2
# ('m3', ('P1', 'm-2'), ('m3', 'M3'), 'P5') , 2
# ('M3', ('m3', 'M2'), ('P-4', 'P4'), 'M6') , 2
# ('P8', ('P1', 'm-3'), ('M3', 'm2'), 'M3') , 2
# ('m6', ('m-3', 'm2'), ('m2', 'M2'), 'm3') , 2
# ('m6', ('P1', 'M2'), ('m2', 'd-5'), 'm3') , 2
# ('m3', ('m2', 'P1'), ('m2', 'P4'), 'm7') , 2
# ('P5', ('P1', 'm-3'), ('P1', 'P1'), 'M3') , 2
# ('P5', ('m-3', 'm2'), ('P1', 'P1'), 'P4') , 2
# ('P4', ('M2', 'P1'), ('m-2', 'd1'), 'M6') , 2
# ('M2', ('P1', 'm-3'), ('m-2', 'm3'), 'M6') , 2
# ('m3', ('m-3', 'm2'), ('m3', 'M-2'), 'P8') , 2
# ('M6', ('M-2', 'P1'), ('M-2', 'm-2'), 'm7') , 2
# ('P5', ('P1', 'P1'), ('P1', 'P-4'), 'P8') , 2
# ('m3', ('P1', 'm-3'), ('M-2', 'd1'), 'A2') , 2
# ('P4', ('m-3', 'm2'), ('d1', 'm-2'), 'P4') , 2
# ('P5', ('P1', 'M-2'), ('P1', 'm2'), 'M3') , 2
# ('M3', ('P1', 'P1'), ('m-3', 'M2'), 'P4') , 2
# ('M6', ('m2', 'M3'), ('M2', 'M-3'), 'M3') , 2
# ('m3', ('P1', 'P1'), ('m3', 'P-5'), 'P5') , 2
# ('P5', ('P4', 'M2'), ('m-3', 'M-2'), 'P5') , 2
# ('M3', ('m3', 'M-2'), ('m-6', 'm2'), 'P8') , 2
# ('P8', ('P1', 'M3'), ('m-3', 'P-4'), 'P8') , 2
# ('P5', ('M-2', 'm-2'), ('m-3', 'M-2'), 'M6') , 2
# ('M3', ('m2', 'm-3'), ('m-3', 'M-3'), 'M6') , 2
# ('m6', ('m-3', 'P1'), ('M-3', 'M2'), 'P5') , 2
# ('m3', ('M2', 'm3'), ('m2', 'A1'), 'd5') , 2
# ('P8', ('P1', 'P1'), ('M3', 'M2'), 'd5') , 2
# ('P4', ('m-3', 'P1'), ('P1', 'm-2'), 'm3') , 2
# ('m6', ('P4', 'M2'), ('M-2', 'M-2'), 'P5') , 2
# ('m3', ('P1', 'P4'), ('P1', 'M2'), 'd5') , 2
# ('m3', ('P1', 'm-2'), ('m-3', 'm2'), 'M3') , 2
# ('P8', ('P4', 'M2'), ('M2', 'M2'), 'm3') , 2
# ('R', ('m-3', 'P1'), ('R', 'P1'), 'M3') , 2
# ('M3', ('m3', 'M-2'), ('M-2', 'm-2'), 'm6') , 2
# ('m3', ('P1', 'm-2'), ('M-6', 'M3'), 'P5') , 2
# ('P8', ('m-2', 'P1'), ('M3', 'P-8'), 'P5') , 2
# ('P5', ('M2', 'M-2'), ('P4', 'm-2'), 'm3') , 2
# ('m3', ('m-2', 'm3'), ('P5', 'P-4'), 'm3') , 2
# ('P5', ('P4', 'm-3'), ('P-8', 'P4'), 'M3') , 2
# ('m3', ('P1', 'm-2'), ('P5', 'P1'), 'P5') , 2
# ('P5', ('M2', 'M-2'), ('P-5', 'P4'), 'M6') , 2
# ('M3', ('M-2', 'M2'), ('P4', 'm-2'), 'P8') , 2
# ('m3', ('M2', 'P1'), ('M-3', 'm-3'), 'P8') , 2
# ('M6', ('P1', 'M2'), ('m-3', 'M-2'), 'M3') , 2
# ('m6', ('M-2', 'M-2'), ('M-2', 'M-2'), 'm6') , 2
# ('M3', ('P1', 'P1'), ('m-3', 'P-4'), 'P8') , 2
# ('m3', ('m-2', 'P1'), ('P5', 'P-8'), 'P5') , 2
# ('m6', ('M-3', 'M2'), ('m2', 'P1'), 'P4') , 2
# ('m6', ('m-2', 'M-3'), ('m-2', 'm2'), 'm3') , 2
# ('M6', ('P4', 'm-3'), ('d-5', 'm2'), 'M3') , 2
# ('P8', ('P1', 'P1'), ('P1', 'P1'), 'P8') , 2
# ('M6', ('M-2', 'M2'), ('P1', 'P1'), 'M6') , 2
# ('P4', ('m-3', 'P1'), ('M-2', 'P1'), 'M3') , 2
# ('P8', ('P1', 'P5'), ('P8', 'm-2'), 'm6') , 2
# ('M3', ('M-3', 'm-2'), ('m-6', 'm3'), 'M3') , 2
# ('m6', ('m-2', 'P1'), ('m3', 'P1'), 'M3') , 2
# ('M3', ('M-3', 'm-2'), ('m-3', 'P-5'), 'M6') , 2
# ('m6', ('M3', 'M-2'), ('M-3', 'P1'), 'M2') , 2
# ('M2', ('P1', 'P1'), ('m-2', 'P1'), 'm3') , 2
# ('m3', ('P1', 'M-2'), ('P1', 'm2'), 'P8') , 2
# ('M3', ('P1', 'M-3'), ('P1', 'P-8'), 'P8') , 2
# ('M3', ('M-3', 'm-2'), ('P-8', 'P5'), 'M3') , 2
# ('P8', ('m-2', 'P1'), ('P5', 'P1'), 'M3') , 2
# ('M3', ('M-2', 'P1'), ('P-4', 'A1'), 'd5') , 2
# ('P5', ('m-3', 'M-2'), ('M3', 'm3'), 'P5') , 2
# ('M6', ('m2', 'P1'), ('P5', 'P1'), 'm3') , 2
# ('m3', ('P1', 'M3'), ('P1', 'P-4'), 'P8') , 2
# ('M6', ('M-2', 'P1'), ('P-8', 'P1'), 'P5') , 2
# ('M6', ('m2', 'M2'), ('M2', 'm2'), 'M6') , 2
# ('M3', ('P1', 'M-2'), ('m-3', 'M2'), 'm3') , 2
# ('m3', ('M-2', 'm-2'), ('m2', 'P-5'), 'A4') , 2
# ('P8', ('m-2', 'm2'), ('P-5', 'm-2'), 'm6') , 2
# ('A4', ('m2', 'M3'), ('m-2', 'M-3'), 'M3') , 2
# ('M6', ('M-2', 'M2'), ('m-2', 'P4'), 'P4') , 2
# ('P8', ('M2', 'm-3'), ('m-2', 'P1'), 'P8') , 2
# ('m3', ('m2', 'P-4'), ('m2', 'm3'), 'P5') , 2
# ('m3', ('M2', 'm-3'), ('P4', 'P-5'), 'M3') , 2
# ('P4', ('m-2', 'm2'), ('m2', 'm-2'), 'P4') , 2
# ('P5', ('P4', 'M2'), ('m-3', 'P1'), 'P4') , 2
# ('m3', ('M2', 'M2'), ('P1', 'm-2'), 'm6') , 2
# ('P8', ('M3', 'M-2'), ('P8', 'P-4'), 'P5') , 2
# ('M3', ('M-2', 'm-3'), ('d-5', 'm2'), 'M3') , 2
# ('m6', ('m-3', 'M-2'), ('m2', 'M2'), 'P8') , 2
# ('P8', ('M3', 'm3'), ('m-3', 'M2'), 'm6') , 2
# ('P5', ('M2', 'M2'), ('P4', 'M2'), 'M3') , 2
# ('d5', ('P1', 'm-2'), ('m2', 'P-8'), 'M3') , 2
# ('m6', ('m-3', 'M-2'), ('m2', 'P-5'), 'M6') , 2
# ('M6', ('M2', 'M2'), ('m-2', 'M-2'), 'M3') , 2
# ('M6', ('M-2', 'P1'), ('m-2', 'm3'), 'P4') , 2
# ('P8', ('P1', 'm-2'), ('P-5', 'M2'), 'M3') , 2
# ('d5', ('M-2', 'P1'), ('m2', 'M-3'), 'P5') , 2
# ('m3', ('m-3', 'M-2'), ('m3', 'M-2'), 'M6') , 2
# ('P8', ('M-2', 'M2'), ('m3', 'm-3'), 'P8') , 2
# ('P5', ('M-2', 'P1'), ('m-3', 'M-2'), 'm7') , 2
# ('m6', ('M2', 'm3'), ('m2', 'm-3'), 'm3') , 2
# ('M3', ('M-2', 'M-2'), ('P-4', 'm-3'), 'm6') , 2
# ('M3', ('M-3', 'M2'), ('M3', 'M-2'), 'P8') , 2
# ('P8', ('P4', 'M2'), ('M2', 'M-3'), 'M6') , 2
# ('M3', ('M-3', 'M2'), ('P4', 'm-3'), 'P8') , 2
# ('P8', ('P1', 'm-2'), ('d-5', 'M2'), 'm3') , 2
# ('P4', ('m-2', 'M-2'), ('A1', 'm2'), 'P8') , 2
# ('P5', ('m-3', 'P4'), ('P1', 'P4'), 'M3') , 2
# ('M3', ('P4', 'M2'), ('m-3', 'M-2'), 'M3') , 2
# ('M3', ('m2', 'm-2'), ('m-3', 'm3'), 'M3') , 2
# ('P8', ('P1', 'm-2'), ('M2', 'P-5'), 'M3') , 2
# ('M3', ('m2', 'm-2'), ('P1', 'M3'), 'P8') , 2
# ('P8', ('M2', 'M-2'), ('M-2', 'P1'), 'M2') , 2
# ('P5', ('M2', 'm-3'), ('A1', 'm2'), 'M3') , 2
# ('m6', ('m-3', 'm3'), ('m2', 'A1'), 'd5') , 2
# ('m3', ('P1', 'M2'), ('P-4', 'M-2'), 'P8') , 2
# ('A4', ('m3', 'M-2'), ('m-2', 'P4'), 'm3') , 2
# ('d5', ('M-2', 'P1'), ('m2', 'P1'), 'm3') , 2
# ('P5', ('M2', 'm3'), ('P4', 'M3'), 'm3') , 2
# ('M3', ('m3', 'M2'), ('M3', 'M-3'), 'M6') , 2
# ('P5', ('M2', 'M-2'), ('P1', 'A1'), 'd5') , 2
# ('P4', ('m-2', 'M-2'), ('P1', 'P-4'), 'P5') , 2
# ('P5', ('M2', 'P1'), ('P4', 'm-6'), 'P8') , 2
# ('M6', ('M-2', 'm-2'), ('M2', 'M-2'), 'A4') , 2
# ('M2', ('P1', 'P1'), ('m-2', 'm3'), 'P8') , 2
# ('P5', ('P1', 'P1'), ('m2', 'm-2'), 'P5') , 2
# ('d7', ('m-2', 'M-2'), ('m2', 'M-3'), 'M6') , 2
# ('P4', ('M2', 'P1'), ('m-2', 'm2'), 'P5') , 2
# ('P5', ('M-2', 'P1'), ('P1', 'P1'), 'P4') , 2
# ('m6', ('M2', 'P1'), ('M-2', 'M6'), 'm3') , 2
# ('m6', ('M2', 'm-3'), ('P-4', 'm3'), 'M6') , 2
# ('m3', ('m-3', 'M-2'), ('m3', 'P1'), 'P5') , 2
# ('P8', ('M-2', 'm-2'), ('M2', 'M-2'), 'M6') , 2
# ('P8', ('M2', 'P1'), ('m-2', 'P4'), 'm7') , 2
# ('m3', ('P1', 'M-2'), ('P4', 'P-5'), 'm3') , 2
# ('P8', ('M2', 'm-3'), ('m-2', 'm3'), 'M6') , 2
# ('m3', ('M-2', 'm-2'), ('P-5', 'm3'), 'M3') , 2
# ('m6', ('m-3', 'M-3'), ('m2', 'm-6'), 'm6') , 2
# ('P8', ('M2', 'P4'), ('P1', 'm-2'), 'm6') , 2
# ('P8', ('M2', 'M-2'), ('M-2', 'P4'), 'M6') , 2
# ('m6', ('M2', 'P4'), ('m2', 'M2'), 'P8') , 2
# ('m3', ('P1', 'M2'), ('M-2', 'M-2'), 'M6') , 2
# ('m3', ('P1', 'M2'), ('P-4', 'm2'), 'M6') , 2
# ('M6', ('P4', 'm-3'), ('M2', 'P-5'), 'M3') , 2
# ('P4', ('P1', 'P1'), ('M2', 'P-4'), 'm6') , 2
# ('P5', ('M2', 'P4'), ('m-3', 'm-3'), 'm6') , 2
# ('M2', ('M2', 'M-2'), ('P1', 'P-5'), 'M6') , 2
# ('m3', ('P1', 'M2'), ('m3', 'P1'), 'M2') , 2
# ('M6', ('M-3', 'M2'), ('M2', 'M2'), 'm3') , 2
# ('P8', ('P1', 'M-3'), ('P1', 'P4'), 'm3') , 2
# ('P5', ('M-2', 'M2'), ('m-3', 'm2'), 'M6') , 2
# ('m3', ('M-2', 'm-2'), ('m2', 'P5'), 'M3') , 2
# ('M6', ('M-2', 'M2'), ('P1', 'P-5'), 'M3') , 2
# ('m3', ('M2', 'm2'), ('m2', 'P4'), 'P8') , 2
# ('m3', ('m-2', 'M-3'), ('M2', 'P4'), 'm3') , 2
# ('P8', ('M-3', 'M2'), ('P4', 'M-3'), 'M6') , 2
# ('P8', ('m-3', 'P1'), ('M2', 'P1'), 'P5') , 2
# ('m3', ('M2', 'P1'), ('m-3', 'M-3'), 'P8') , 2
# ('m3', ('P1', 'm-3'), ('m3', 'P-5'), 'M3') , 2
# ('P8', ('M3', 'M-2'), ('P5', 'P1'), 'P5') , 2
# ('m3', ('m-2', 'M-2'), ('M-2', 'P-4'), 'P5') , 1
# ('P8', ('M2', 'M2'), ('P4', 'M2'), 'M6') , 1
# ('M3', ('m3', 'P-5'), ('P-4', 'm-2'), 'd5') , 1
# ('P8', ('P-5', 'm-2'), ('m-2', 'm2'), 'M3') , 1
# ('M6', ('M2', 'M-2'), ('M2', 'P1'), 'P5') , 1
# ('M3', ('m3', 'P-5'), ('P-4', 'M2'), 'm3') , 1
# ('P8', ('P-5', 'm-2'), ('M2', 'P-4'), 'P5') , 1
# ('P8', ('m2', 'M2'), ('M-2', 'M-3'), 'M6') , 1
# ('R', ('M2', 'M2'), ('R', 'R'), 'M3') , 1
# ('R', ('M2', 'm3'), ('R', 'M2'), 'P4') , 1
# ('P8', ('M2', 'M-2'), ('M-2', 'P-4'), 'P5') , 1
# ('M3', ('P1', 'M-2'), ('P-5', 'P1'), 'M6') , 1
# ('M7', ('M-2', 'M2'), ('P1', 'm-2'), 'P8') , 1
# ('R', ('M2', 'm2'), ('R', 'M2'), 'm3') , 1
# ('m3', ('M2', 'm3'), ('m2', 'M2'), 'P4') , 1
# ('P8', ('M2', 'M2'), ('P8', 'P1'), 'M3') , 1
# ('M2', ('M2', 'm3'), ('P1', 'R'), 'R') , 1
# ('M3', ('m3', 'P-5'), ('R', 'R'), 'd5') , 1
# ('R', ('P-5', 'm-2'), ('R', 'm2'), 'M3') , 1
# ('P8', ('M2', 'M2'), ('M7', 'm2'), 'M3') , 1
# ('m3', ('M2', 'm3'), ('m2', 'R'), 'R') , 1
# ('M3', ('m3', 'P-5'), ('R', 'R'), 'm6') , 1
# ('R', ('P-5', 'm-2'), ('R', 'R'), 'R') , 1
# ('P8', ('M2', 'M2'), ('P8', 'P-4'), 'M6') , 1
# ('M2', ('M2', 'M-2'), ('P-4', 'P-8'), 'P5') , 1
# ('m3', ('m-2', 'M-2'), ('P4', 'P-4'), 'P8') , 1
# ('M6', ('M2', 'm2'), ('P8', 'm-3'), 'm3') , 1
# ('M7', ('m2', 'M2'), ('m-3', 'P-4'), 'm7') , 1
# ('m3', ('M2', 'M2'), ('P-4', 'm3'), 'M6') , 1
# ('m7', ('M2', 'M-2'), ('m3', 'R'), 'R') , 1
# ('M6', ('M-2', 'M-2'), ('R', 'R'), 'P8') , 1
# ('m3', ('m-2', 'M-2'), ('P4', 'M2'), 'P4') , 1
# ('P8', ('M3', 'm2'), ('P-8', 'M2'), 'm3') , 1
# ('P4', ('m-2', 'm2'), ('P1', 'M-3'), 'M6') , 1
# ('P8', ('m2', 'M2'), ('M-2', 'm-2'), 'd5') , 1
# ('m3', ('M2', 'M-2'), ('m-2', 'm2'), 'm3') , 1
# ('R', ('P5', 'P1'), ('R', 'R'), 'P5') , 1
# ('R', ('P1', 'P1'), ('R', 'P4'), 'M2') , 1
# ('P8', ('P5', 'P1'), ('m-2', 'M-3'), 'P8') , 1
# ('P8', ('P1', 'P1'), ('P4', 'm-6'), 'm3') , 1
# ('R', ('M-2', 'm-2'), ('R', 'R'), 'M6') , 1
# ('R', ('m-2', 'M-2'), ('R', 'm-2'), 'm6') , 1
# ('M6', ('M-2', 'M3'), ('m-2', 'M-3'), 'M3') , 1
# ('P5', ('M2', 'm3'), ('P1', 'M3'), 'm6') , 1
# ('P8', ('P1', 'P1'), ('M2', 'P-4'), 'm3') , 1
# ('m7', ('P1', 'P1'), ('P-4', 'm3'), 'P8') , 1
# ('m3', ('P1', 'm-3'), ('m3', 'M2'), 'P5') , 1
# ('d5', ('M-2', 'M3'), ('m2', 'P1'), 'P5') , 1
# ('m3', ('M3', 'm3'), ('P1', 'M-2'), 'P8') , 1
# ('P5', ('P1', 'P1'), ('P1', 'M2'), 'P4') , 1
# ('m3', ('M2', 'm3'), ('m2', 'M3'), 'm3') , 1
# ('M3', ('m3', 'M2'), ('M3', 'm-3'), 'm6') , 1
# ('M6', ('M-2', 'M3'), ('m-2', 'P4'), 'P5') , 1
# ('m6', ('M3', 'm3'), ('P4', 'M-2'), 'P8') , 1
# ('R', ('P1', 'P1'), ('R', 'P-5'), 'P5') , 1
# ('P8', ('P1', 'P1'), ('P-5', 'P1'), 'P5') , 1
# ('P5', ('M2', 'M-2'), ('P4', 'M2'), 'P8') , 1
# ('A4', ('P1', 'M-2'), ('m-2', 'M-3'), 'M6') , 1
# ('P8', ('M-2', 'm-2'), ('m2', 'm-2'), 'M6') , 1
# ('A4', ('P1', 'M-2'), ('m-2', 'M2'), 'm3') , 1
# ('m3', ('M3', 'm3'), ('P1', 'P-4'), 'm3') , 1
# ('A2', ('m2', 'm-2'), ('m-2', 'P1'), 'M3') , 1
# ('P8', ('M3', 'P1'), ('P8', 'm-6'), 'P8') , 1
# ('M3', ('P1', 'M-2'), ('m-6', 'm2'), 'M6') , 1
# ('P5', ('M-2', 'P1'), ('M2', 'P-5'), 'm7') , 1
# ('P8', ('M3', 'P1'), ('m-3', 'P5'), 'P8') , 1
# ('P5', ('P1', 'M-2'), ('P5', 'P-4'), 'm3') , 1
# ('m3', ('M-2', 'P1'), ('M-2', 'm3'), 'P8') , 1
# ('m3', ('P1', 'm-2'), ('m3', 'm-6'), 'P5') , 1
# ('P8', ('P5', 'P1'), ('M2', 'M2'), 'm3') , 1
# ('m6', ('M3', 'P1'), ('M-3', 'P1'), 'M3') , 1
# ('M3', ('P1', 'M-2'), ('P1', 'm-2'), 'm3') , 1
# ('P8', ('m-2', 'M-2'), ('M2', 'A1'), 'd5') , 1
# ('P5', ('P1', 'M2'), ('P1', 'P1'), 'M6') , 1
# ('P5', ('M2', 'M2'), ('P1', 'P1'), 'M7') , 1
# ('M7', ('m2', 'P1'), ('P1', 'm-3'), 'm3') , 1
# ('m3', ('M3', 'P1'), ('m-2', 'm2'), 'P5') , 1
# ('d5', ('m-2', 'M-2'), ('m2', 'd-5'), 'm6') , 1
# ('M3', ('M-2', 'P1'), ('d-5', 'M2'), 'd5') , 1
# ('P4', ('P1', 'M2'), ('M-2', 'P1'), 'M6') , 1
# ('P8', ('m-3', 'M2'), ('M2', 'P-5'), 'M3') , 1
# ('P5', ('M2', 'm2'), ('P-5', 'P4'), 'P8') , 1
# ('P8', ('M3', 'P1'), ('P8', 'm-3'), 'P5') , 1
# ('M3', ('m2', 'm-2'), ('M-3', 'm-2'), 'M6') , 1
# ('m3', ('P1', 'm-2'), ('P1', 'M2'), 'P8') , 1
# ('P5', ('M-2', 'P1'), ('m-3', 'M2'), 'd5') , 1
# ('m3', ('M-2', 'm3'), ('m2', 'm-3'), 'd5') , 1
# ('P8', ('m3', 'm-2'), ('m-3', 'm2'), 'M3') , 1
# ('P5', ('M-2', 'm-2'), ('m2', 'm-2'), 'M3') , 1
# ('m3', ('M2', 'M-2'), ('m6', 'm-2'), 'm6') , 1
# ('P8', ('P1', 'M-2'), ('m3', 'M-2'), 'M6') , 1
# ('m6', ('M-2', 'm-3'), ('m3', 'P1'), 'P8') , 1
# ('P8', ('P5', 'P1'), ('m-2', 'd1'), 'M6') , 1
# ('A2', ('m2', 'P1'), ('m-2', 'M-2'), 'P5') , 1
# ('P4', ('P1', 'P1'), ('M-2', 'P5'), 'P8') , 1
# ('M6', ('M-2', 'm-3'), ('M3', 'P-5'), 'P5') , 1
# ('m3', ('M3', 'P1'), ('m-2', 'd1'), 'M6') , 1
# ('M6', ('M-2', 'M-2'), ('m-2', 'M-2'), 'm6') , 1
# ('m3', ('P1', 'm-2'), ('m-3', 'm-3'), 'm6') , 1
# ...
# ('P4', ('M2', 'M2'), ('m3', 'm-3'), 'M6') , 1
# ('P8', ('m-3', 'M-2'), ('M2', 'M2'), 'm3') , 1
# ('m3', ('M-2', 'P1'), ('m2', 'P-5'), 'P5') , 1
# ('P5', ('M2', 'P1'), ('P1', 'P4'), 'M3') , 1
# ('M6', ('P1', 'M-2'), ('P4', 'm-2'), 'm3') , 1
# ('M3', ('M-2', 'P4'), ('m-2', 'P4'), 'm3') , 1
# ('m3', ('P4', 'P1'), ('P4', 'M-3'), 'P5') , 1
# ('d5', ('m-2', 'M-2'), ('m2', 'd-4'), 'd5') , 1
# ('P8', ('M3', 'm3'), ('P8', 'm-6'), 'm3') , 1
# ('M3', ('m3', 'm-3'), ('m-6', 'm3'), 'M6') , 1
# ('A2', ('m2', 'P1'), ('m-2', 'P4'), 'P8') , 1
# ('M2', ('P4', 'P1'), ('m-2', 'm3'), 'P4') , 1
# ('R', ('M3', 'm3'), ('R', 'R'), 'P5') , 1
# ('R', ('m3', 'm-3'), ('R', 'M3'), 'P8') , 1
# ('R', ('M-2', 'm-3'), ('R', 'R'), 'P5') , 1
# ('R', ('m-3', 'M-2'), ('R', 'M-3'), 'M6') , 1
# ('R', ('M2', 'P1'), ('R', 'R'), 'M6') , 1
# ('R', ('P1', 'M-2'), ('R', 'M2'), 'P4') , 1
# ('M6', ('M-2', 'P4'), ('M2', 'M-2'), 'P8') , 1
# ('P4', ('P4', 'P1'), ('M-2', 'P4'), 'P5') , 1
# ('R', ('m2', 'm-2'), ('R', 'R'), 'P8') , 1
# ('R', ('m-2', 'M-2'), ('R', 'm2'), 'M6') , 1
# ('m6', ('m-3', 'M-2'), ('m2', 'm-2'), 'm3') , 1
# ('m3', ('M-2', 'm-3'), ('m2', 'P1'), 'M6') , 1
# ('P8', ('m-3', 'M-2'), ('P1', 'A1'), 'd5') , 1
# ('M2', ('P4', 'P1'), ('m-2', 'd4'), 'M3') , 1
# ('m6', ('P1', 'm-2'), ('d4', 'm-2'), 'M3') , 1
# ('P5', ('M-2', 'P4'), ('M2', 'P-5'), 'm3') , 1
# ('m3', ('P4', 'm-2'), ('P-5', 'M2'), 'P8') , 1
# ('M3', ('P1', 'P1'), ('M3', 'M-3'), 'M3') , 1
# ('P5', ('M-2', 'P4'), ('M2', 'M2'), 'd5') , 1
# ('P5', ('M-2', 'M-2'), ('m2', 'P1'), 'M2') , 1
# ('M3', ('P1', 'P1'), ('d-4', 'm2'), 'P5') , 1
# ('M6', ('M-2', 'P4'), ('m-2', 'P-4'), 'd5') , 1
# ('m6', ('P4', 'm-2'), ('P-4', 'm2'), 'M3') , 1
# ('m6', ('M2', 'm3'), ('M-2', 'P4'), 'm7') , 1
# ('P8', ('m3', 'm-2'), ('P4', 'P-5'), 'M3') , 1
# ('m7', ('m-2', 'M-2'), ('P-5', 'P-4'), 'P5') , 1
# ('M6', ('M-2', 'M-2'), ('m3', 'M2'), 'P8') , 1
# ('m6', ('P1', 'M-2'), ('d1', 'M-2'), 'M6') , 1
# ('P5', ('M2', 'm3'), ('m-3', 'P-4'), 'm6') , 1
# ('P8', ('m3', 'm-2'), ('P-4', 'm3'), 'M3') , 1
# ('M2', ('P1', 'P1'), ('m-2', 'd5'), 'M6') , 1
# ('m3', ('P1', 'M-2'), ('d5', 'M-2'), 'M6') , 1
# ('M6', ('M-2', 'm-3'), ('m-2', 'P1'), 'P4') , 1
# ('m6', ('M2', 'm3'), ('m3', 'M-2'), 'P8') , 1
# ('P5', ('m3', 'm-2'), ('M-2', 'M2'), 'M6') , 1
# ('m3', ('M-2', 'M-2'), ('m2', 'P5'), 'm3') , 1
# ('P8', ('M-2', 'P4'), ('P5', 'M-3'), 'P8') , 1
# ('m3', ('P4', 'M2'), ('M-3', 'm-2'), 'm3') , 1
# ('M3', ('P1', 'P1'), ('m-2', 'M-2'), 'P5') , 1
# ('P4', ('P1', 'M-2'), ('M-2', 'm6'), 'M6') , 1
# ('M6', ('M-2', 'P4'), ('m-2', 'P4'), 'm6') , 1
# ('m6', ('P4', 'm-2'), ('P4', 'M-2'), 'M6') , 1
# ('M6', ('M-2', 'm-3'), ('m-2', 'P4'), 'P8') , 1
# ('m6', ('m-3', 'M-3'), ('m2', 'M6'), 'm3') , 1
# ('M3', ('M-3', 'M2'), ('M6', 'M-3'), 'M6') , 1
# ('m3', ('M2', 'm3'), ('M-3', 'P1'), 'P8') , 1
# ('M6', ('m3', 'm-2'), ('P1', 'M2'), 'M6') , 1
# ('P8', ('P1', 'm-2'), ('P-4', 'A1'), 'm3') , 1
# ('m3', ('M-2', 'M-2'), ('m2', 'm3'), 'P5') , 1
# ('P8', ('P1', 'P1'), ('M-3', 'm-3'), 'P5') , 1
# ('P5', ('M-2', 'm-3'), ('M2', 'P1'), 'P8') , 1
# ('P8', ('m-3', 'M-3'), ('P4', 'm-3'), 'm3') , 1
# ('m3', ('M2', 'm3'), ('M-2', 'M2'), 'm6') , 1
# ('m6', ('m-2', 'M-2'), ('M-2', 'm3'), 'M3') , 1
# ('M6', ('M-2', 'M-2'), ('m3', 'P1'), 'M2') , 1
# ('P5', ('P1', 'P1'), ('P8', 'M-2'), 'M6') , 1
# ('R', ('m-3', 'M-3'), ('R', 'R'), 'P8') , 1
# ('R', ('M-3', 'M2'), ('R', 'm-2'), 'm3') , 1
# ('P8', ('M2', 'm3'), ('m-2', 'M-3'), 'm7') , 1
# ('m3', ('m3', 'm-2'), ('M-3', 'P4'), 'M3') , 1
# ('m7', ('m-2', 'M-2'), ('P4', 'P-4'), 'P5') , 1
# ('M3', ('P4', 'M2'), ('P4', 'm-3'), 'M6') , 1
# ('M3', ('m3', 'P-4'), ('m-2', 'P-4'), 'm6') , 1
# ('m6', ('P-4', 'm-3'), ('P-4', 'm2'), 'M3') , 1
# ('M3', ('P4', 'M2'), ('m-3', 'm-2'), 'm3') , 1
# ('P5', ('m3', 'P-4'), ('M-2', 'm-2'), 'm6') , 1
# ('P8', ('P-4', 'm-3'), ('m-2', 'm2'), 'M3') , 1
# ('M6', ('m2', 'P1'), ('M-2', 'm6'), 'M3') , 1
# ('P8', ('P1', 'm-2'), ('m6', 'm-2'), 'M3') , 1
# ('M3', ('m2', 'P1'), ('M6', 'M2'), 'd5') , 1
# ('M3', ('m3', 'P-4'), ('m-2', 'm3'), 'P8') , 1
# ('m6', ('P-4', 'm-3'), ('m3', 'M2'), 'P5') , 1
# ('P8', ('m-3', 'm2'), ('M2', 'P-5'), 'm3') , 1
# ('P8', ('M-2', 'P1'), ('M-6', 'P1'), 'P5') , 1
# ('M3', ('P4', 'M2'), ('m-3', 'd1'), 'A2') , 1
# ('M3', ('M2', 'M2'), ('m-3', 'P5'), 'M3') , 1
# ('M6', ('M2', 'm2'), ('P5', 'm2'), 'M3') , 1
# ('M3', ('m2', 'P1'), ('P4', 'M2'), 'm7') , 1
# ('M2', ('M2', 'm2'), ('P1', 'm2'), 'M3') , 1
# ('M3', ('P1', 'm-2'), ('m-3', 'm-3'), 'M6') , 1
# ('P5', ('m-2', 'm2'), ('m-3', 'M-2'), 'P8') , 1
# ('M3', ('P4', 'M2'), ('P4', 'd-7'), 'm3') , 1
# ('m3', ('m2', 'P1'), ('m2', 'd1'), 'M3') , 1
# ('M3', ('m3', 'P-4'), ('m-2', 'M-2'), 'P4') , 1
# ('m6', ('P-4', 'm-3'), ('M-2', 'M-2'), 'M3') , 1
# ('P4', ('m-3', 'm2'), ('M-2', 'P1'), 'P4') , 1
# ('m6', ('m-3', 'P4'), ('m2', 'P1'), 'M6') , 1
# ('M3', ('P4', 'M2'), ('P1', 'M2'), 'M6') , 1
# ('M6', ('m2', 'P1'), ('M2', 'M2'), 'd5') , 1
# ('M6', ('m3', 'P-4'), ('m-3', 'M2'), 'm6') , 1
# ('m3', ('P-4', 'm-3'), ('M2', 'M2'), 'm3') , 1
# ('m6', ('m-3', 'm2'), ('M2', 'm2'), 'm3') , 1
# ('M2', ('M2', 'M2'), ('M-2', 'm-2'), 'M6') , 1
# ('M6', ('m2', 'P1'), ('M-2', 'P5'), 'P4') , 1
# ('P5', ('m-3', 'P4'), ('P1', 'P1'), 'M6') , 1
# ('M3', ('P4', 'M2'), ('P1', 'P1'), 'M7') , 1
# ('M7', ('m2', 'P1'), ('P1', 'M2'), 'm7') , 1
# ('M3', ('M2', 'm2'), ('M2', 'm2'), 'M3') , 1
# ('m3', ('P1', 'M2'), ('P-4', 'M2'), 'm6') , 1
# ('M3', ('m3', 'M-2'), ('M3', 'M-2'), 'm3') , 1
# ('M3', ('m2', 'P1'), ('m-3', 'm2'), 'P5') , 1
# ('P5', ('M-2', 'm3'), ('m2', 'P1'), 'P5') , 1
# ('M3', ('m3', 'M-2'), ('P1', 'm-3'), 'm6') , 1
# ('P5', ('m-2', 'M-2'), ('M2', 'P-4'), 'P5') , 1
# ('M3', ('M-2', 'm3'), ('P-4', 'M2'), 'm6') , 1
# ('P8', ('P1', 'M2'), ('m-3', 'm-3'), 'm6') , 1
# ('d5', ('M-2', 'P1'), ('m2', 'P-5'), 'm7') , 1
# ('m3', ('m2', 'P1'), ('m2', 'P-4'), 'm6') , 1
# ('m3', ('M-2', 'm3'), ('m2', 'P1'), 'm3') , 1
# ('P4', ('M2', 'm-3'), ('m-2', 'd1'), 'A4') , 1
# ('m6', ('m-3', 'm3'), ('d1', 'm-2'), 'm7') , 1
# ('m7', ('M-2', 'P1'), ('P4', 'P-5'), 'm7') , 1
# ('A2', ('m2', 'P1'), ('m-2', 'P1'), 'P4') , 1
# ('P4', ('P1', 'M2'), ('P1', 'M-2'), 'M6') , 1
# ('P5', ('M2', 'M-2'), ('m-3', 'm2'), 'M6') , 1
# ('P8', ('P1', 'm-2'), ('P1', 'P1'), 'M7') , 1
# ('P8', ('m-2', 'M-2'), ('P1', 'P1'), 'M6') , 1
# ('M7', ('M-2', 'm3'), ('P1', 'M3'), 'm6') , 1
# ('P5', ('m2', 'P1'), ('P4', 'P1'), 'm3') , 1
# ('m3', ('P1', 'M2'), ('P1', 'M2'), 'm3') , 1
# ('P8', ('M-2', 'M2'), ('m3', 'P1'), 'M6') , 1
# ('P8', ('P1', 'm-2'), ('P5', 'A1'), 'm3') , 1
# ('P8', ('P1', 'M2'), ('P4', 'm-3'), 'P8') , 1
# ('P5', ('M2', 'm-3'), ('m-3', 'P4'), 'M3') , 1
# ('P8', ('m-3', 'm3'), ('P4', 'm-3'), 'm7') , 1
# ('M3', ('m3', 'M-2'), ('m-3', 'P4'), 'm3') , 1
# ('m7', ('M-2', 'P1'), ('P4', 'M-6'), 'P8') , 1
# ('m6', ('P1', 'M2'), ('P1', 'M-2'), 'P8') , 1
# ('P5', ('M-2', 'm3'), ('m2', 'P5'), 'P8') , 1
# ('M3', ('m3', 'M2'), ('P5', 'P1'), 'M2') , 1
# ('M3', ('m2', 'P1'), ('P1', 'M-2'), 'P5') , 1
# ('P4', ('P1', 'M2'), ('M-2', 'm-3'), 'P8') , 1
# ('M3', ('M-2', 'm3'), ('M-2', 'm-2'), 'm6') , 1
# ('P8', ('P1', 'M2'), ('m-3', 'P4'), 'P8') , 1
# ('P8', ('m-3', 'm3'), ('P-5', 'M-2'), 'M6') , 1
# ('M3', ('M-2', 'P1'), ('m-2', 'M-3'), 'P5') , 1
# ('M3', ('M-2', 'M2'), ('P-4', 'm-3'), 'P8') , 1
# ('P8', ('M-2', 'm-2'), ('M2', 'P1'), 'P5') , 1
# ('P5', ('M2', 'P1'), ('m-3', 'M-3'), 'M3') , 1
# ('P8', ('M-2', 'M-2'), ('m3', 'P4'), 'P8') , 1
# ('P5', ('M-2', 'P1'), ('P4', 'P-4'), 'P4') , 1
# ('m3', ('m-2', 'm2'), ('P-4', 'P-5'), 'm3') , 1
# ('M3', ('m2', 'm-2'), ('P1', 'P1'), 'M3') , 1
# ('m3', ('M2', 'm3'), ('M-2', 'M-2'), 'P8') , 1
# ('P5', ('m3', 'M2'), ('M-2', 'P1'), 'M2') , 1
# ('P4', ('m-2', 'm2'), ('M-2', 'm-2'), 'm6') , 1
# ('P8', ('P1', 'M-2'), ('P4', 'm-3'), 'm6') , 1
# ('P8', ('M-2', 'P1'), ('M2', 'M-2'), 'm7') , 1
# ('P8', ('M-2', 'M-2'), ('m2', 'M3'), 'm3') , 1
# ('M6', ('M-2', 'P1'), ('M3', 'P-5'), 'm7') , 1
# ('m3', ('P1', 'M2'), ('m3', 'M-2'), 'M3') , 1
# ('P8', ('M2', 'P1'), ('M-2', 'm-3'), 'P5') , 1
# ('M6', ('M2', 'm3'), ('m-2', 'P8'), 'm3') , 1
# ('P8', ('m3', 'M2'), ('P8', 'M-3'), 'M6') , 1
# ('m3', ('m-2', 'm2'), ('P-4', 'm-2'), 'd7') , 1
# ('P5', ('P1', 'P1'), ('P5', 'm-3'), 'm3') , 1
# ('P8', ('P1', 'M2'), ('m-3', 'm2'), 'M3') , 1
# ('M3', ('P1', 'M-2'), ('P-8', 'M2'), 'P8') , 1
# ('m6', ('M-2', 'P1'), ('m3', 'M-3'), 'P5') , 1
# ('A4', ('P1', 'M2'), ('m-2', 'A1'), 'm6') , 1
# ('m6', ('M2', 'M-2'), ('m2', 'M-2'), 'M6') , 1
# ('A4', ('P1', 'M2'), ('m-2', 'P4'), 'M3') , 1
# ('d5', ('m-2', 'M-2'), ('m2', 'M2'), 'P8') , 1
# ('M6', ('M2', 'm3'), ('m-2', 'P-4'), 'm6') , 1
# ('P8', ('m3', 'M2'), ('P-4', 'P4'), 'P4') , 1
# ('P5', ('M-2', 'M-2'), ('M-3', 'M-2'), 'M6') , 1
# ('M6', ('M-2', 'P1'), ('M-2', 'P4'), 'M3') , 1
# ('m3', ('M2', 'P1'), ('m2', 'A1'), 'm3') , 1
# ('M6', ('M-2', 'P1'), ('P1', 'M2'), 'P4') , 1
# ('P5', ('P1', 'm-2'), ('M2', 'P1'), 'M3') , 1
# ('P5', ('M2', 'm3'), ('P1', 'P1'), 'P8') , 1
# ('M6', ('m3', 'M2'), ('P1', 'P-5'), 'M6') , 1
# ('P8', ('M2', 'P1'), ('P-5', 'M2'), 'P5') , 1
# ('P4', ('m-2', 'm2'), ('M-2', 'M-2'), 'M6') , 1
# ('P4', ('P1', 'm-2'), ('P1', 'P-8'), 'M3') , 1
# ('P8', ('P1', 'M-2'), ('M6', 'P-4'), 'd5') , 1
# ('m6', ('m-3', 'm2'), ('m2', 'P1'), 'P4') , 1
# ('m6', ('M2', 'P1'), ('M-2', 'm-3'), 'm3') , 1
# ('P8', ('P1', 'M-2'), ('m-3', 'M-2'), 'm3') , 1
# ('A2', ('m2', 'M2'), ('m-2', 'm-2'), 'm6') , 1
# ('M6', ('m2', 'm-2'), ('P-4', 'P5'), 'P5') , 1
# ('P5', ('P1', 'm-3'), ('m-2', 'd1'), 'A4') , 1
# ('m6', ('m-3', 'm2'), ('d1', 'm-2'), 'm6') , 1
# ('M6', ('M-2', 'P1'), ('m-2', 'M-3'), 'P8') , 1
# ('P8', ('P4', 'P-4'), ('P1', 'P1'), 'P8') , 1
# ('P4', ('P-4', 'M2'), ('P1', 'M-2'), 'M3') , 1
# ('P8', ('M2', 'M-2'), ('M-2', 'd-4'), 'd5') , 1
# ('M6', ('m-2', 'M-2'), ('m-2', 'P1'), 'P5') , 1
# ('P5', ('P4', 'P-4'), ('m-3', 'P5'), 'm3') , 1
# ('m3', ('P-4', 'M2'), ('P5', 'm2'), 'M3') , 1
# ('m3', ('m-2', 'M-2'), ('P-5', 'P-4'), 'P8') , 1
# ('m3', ('P1', 'm-3'), ('m3', 'P4'), 'M3') , 1
# ('P8', ('m-3', 'm2'), ('P4', 'm-3'), 'm6') , 1
# ('M3', ('m2', 'M2'), ('m-3', 'M2'), 'm6') , 1
# ('m6', ('M3', 'm2'), ('M-3', 'm-3'), 'm6') , 1
# ('P8', ('P1', 'M-2'), ('M6', 'P-5'), 'm6') , 1
# ('P8', ('M2', 'M-2'), ('M-2', 'P-5'), 'M6') , 1
# ('P5', ('P1', 'm-3'), ('P-4', 'P1'), 'M6') , 1
# ('P8', ('m-3', 'm2'), ('P1', 'M-2'), 'P8') , 1
# ('m3', ('m-3', 'M-2'), ('m3', 'A1'), 'd5') , 1
# ('m3', ('M2', 'P1'), ('m-3', 'P4'), 'm3') , 1
# ('M6', ('M2', 'M2'), ('M2', 'M2'), 'M6') , 1
# ('M2', ('P1', 'M-2'), ('M-2', 'd-5'), 'm6') , 1
# ('M3', ('M-2', 'P1'), ('d-5', 'R'), 'R') , 1
# ('P8', ('P4', 'P-4'), ('m-3', 'M-2'), 'P4') , 1
# ('m6', ('P-4', 'M2'), ('M-2', 'M-2'), 'M6') , 1
# ('P4', ('M2', 'M-2'), ('M-2', 'M7'), 'm6') , 1
# ('M3', ('M-2', 'M-2'), ('P-5', 'P-4'), 'P8') , 1
# ('m3', ('M2', 'P4'), ('M-2', 'M3'), 'm6') , 1
# ('P5', ('P4', 'm-3'), ('M3', 'm2'), 'M3') , 1
# ('m6', ('M2', 'P4'), ('M-2', 'P-8'), 'P4') , 1
# ('P8', ('P4', 'm-3'), ('P-8', 'P5'), 'P5') , 1
# ('M3', ('M-3', 'M2'), ('P8', 'P1'), 'M2') , 1
# ('m6', ('M2', 'P4'), ('m2', 'm-3'), 'P4') , 1
# ('M6', ('P4', 'm-3'), ('M2', 'A1'), 'm6') , 1
# ('m6', ('M-3', 'M2'), ('m2', 'M-2'), 'P5') , 1
# ('P8', ('m-3', 'P1'), ('P-5', 'P1'), 'M3') , 1
# ('m6', ('M2', 'P4'), ('M-2', 'm-3'), 'm6') , 1
# ('P8', ('P1', 'P1'), ('P-4', 'M2'), 'm3') , 1
# ('m6', ('M2', 'P4'), ('m2', 'P1'), 'M2') , 1
# ('M6', ('P4', 'm-3'), ('P1', 'M3'), 'P5') , 1
# ('M2', ('m-3', 'P1'), ('M3', 'P1'), 'P5') , 1
# ('m6', ('P1', 'P1'), ('m2', 'M3'), 'm3') , 1
# ('P5', ('P1', 'M2'), ('M3', 'M2'), 'm3') , 1
# ('M3', ('M-3', 'M2'), ('m-3', 'M-3'), 'M6') , 1
# ('m3', ('M2', 'P4'), ('M-3', 'M2'), 'P8') , 1
# ('P8', ('m-3', 'M-3'), ('P-5', 'M6'), 'm3') , 1
# ('M3', ('M-3', 'M2'), ('M6', 'M-2'), 'P5') , 1
# ('P5', ('P1', 'M2'), ('P-4', 'm-2'), 'm3') , 1
# ('P4', ('M2', 'P4'), ('M-2', 'm-3'), 'P4') , 1
# ('m3', ('P1', 'P1'), ('M-3', 'P1'), 'P5') , 1
# ('m3', ('P1', 'P1'), ('M-3', 'P8'), 'P5') , 1
# ('P5', ('P1', 'M2'), ('P8', 'm-3'), 'P8') , 1
# ('m3', ('P1', 'M2'), ('M-3', 'm-3'), 'P8') , 1
# ('m3', ('M2', 'P4'), ('M-2', 'R'), 'R') , 1
# ('P5', ('P4', 'm-3'), ('R', 'R'), 'M3') , 1
# ('R', ('m-3', 'M-3'), ('R', 'm-6'), 'm6') , 1
# ('P8', ('P1', 'P1'), ('M2', 'm3'), 'P5') , 1
# ('m7', ('P1', 'P1'), ('m3', 'M3'), 'm3') , 1
# ('P5', ('P1', 'M2'), ('M3', 'M-3'), 'M6') , 1
# ('P5', ('P1', 'P1'), ('m-2', 'd5'), 'M2') , 1
# ('m6', ('P1', 'P1'), ('d5', 'm-2'), 'm3') , 1
# ('M2', ('P1', 'M2'), ('m-2', 'M-3'), 'M6') , 1
# ('m3', ('M2', 'P4'), ('M-3', 'm-3'), 'P4') , 1
# ('P5', ('P1', 'M2'), ('m-2', 'P5'), 'm3') , 1
# ('m6', ('M2', 'M2'), ('P5', 'm2'), 'M3') , 1
# ('m3', ('M2', 'P4'), ('M-3', 'd-5'), 'm6') , 1
# ('m6', ('m-3', 'M-3'), ('m2', 'P8'), 'P8') , 1
# ('M3', ('M-3', 'M2'), ('P8', 'P-4'), 'P5') , 1
# ('m3', ('P1', 'P1'), ('M-3', 'P5'), 'P8') , 1
# ('P8', ('P1', 'P1'), ('P5', 'M2'), 'm3') , 1
# ('P4', ('P1', 'P1'), ('M2', 'm3'), 'P8') , 1
# ('m3', ('M2', 'm2'), ('m2', 'P-5'), 'P8') , 1
# ('M3', ('m2', 'm-2'), ('P-5', 'M2'), 'M6') , 1
# ('M3', ('M-2', 'M-2'), ('m-2', 'P-4'), 'd5') , 1
# ('m6', ('M2', 'M-2'), ('M-2', 'P-4'), 'm3') , 1
# ('P5', ('M-2', 'M2'), ('m2', 'm-2'), 'P5') , 1
# ('P8', ('M-2', 'm-2'), ('M2', 'P-8'), 'P5') , 1
# ('m3', ('M2', 'M2'), ('P1', 'P1'), 'P5') , 1
# ('P4', ('M2', 'P1'), ('P1', 'm-2'), 'm6') , 1
# ('P5', ('P1', 'M-3'), ('m-2', 'm2'), 'm3') , 1
# ('M6', ('m3', 'M-2'), ('m-3', 'm2'), 'P8') , 1
# ('P8', ('m-2', 'M-2'), ('P5', 'd-4'), 'd5') , 1
# ('d5', ('M-2', 'M2'), ('m2', 'M-3'), 'M6') , 1
# ('P8', ('M2', 'M2'), ('P-4', 'P1'), 'M6') , 1
# ('M6', ('P1', 'M-2'), ('M2', 'M2'), 'm3') , 1
# ('M3', ('m2', 'm-2'), ('M2', 'P4'), 'M6') , 1
# ('m6', ('m-2', 'M-3'), ('P-4', 'm2'), 'P5') , 1
# ('P8', ('M-3', 'M2'), ('m2', 'm-3'), 'P8') , 1
# ('P8', ('M2', 'P1'), ('M-2', 'P1'), 'M3') , 1
# ('M3', ('P1', 'M-3'), ('P1', 'P4'), 'P5') , 1
# ('P8', ('M2', 'M-2'), ('M-2', 'M2'), 'P8') , 1
# ('M3', ('M-2', 'M-2'), ('P5', 'm-2'), 'd5') , 1
# ('P5', ('M-2', 'm-2'), ('m-2', 'm2'), 'M3') , 1
# ('M3', ('m2', 'm-2'), ('P4', 'M2'), 'M6') , 1
# ('P5', ('m2', 'M2'), ('P4', 'P-5'), 'P8') , 1
# ('m3', ('M2', 'M2'), ('M-3', 'P-4'), 'M3') , 1
# ('M6', ('M2', 'P1'), ('P-4', 'M3'), 'P8') , 1
# ('M3', ('P1', 'M-3'), ('M3', 'P-5'), 'm3') , 1
# ('m6', ('M-2', 'm-2'), ('M-2', 'P-4'), 'P8') , 1
# ('M3', ('m3', 'M-2'), ('M3', 'P-4'), 'd5') , 1
# ('d5', ('m-2', 'M-3'), ('m2', 'P-5'), 'P5') , 1
# ('M3', ('M-3', 'M2'), ('P-5', 'P1'), 'M6') , 1
# ('M6', ('M-2', 'M2'), ('m-2', 'm3'), 'P5') , 1
# ('m6', ('M2', 'P1'), ('m3', 'P1'), 'P5') , 1
# ('P5', ('M2', 'M-2'), ('P4', 'd-4'), 'd5') , 1
# ('M3', ('m3', 'M-2'), ('P1', 'M2'), 'm3') , 1
# ('P8', ('P1', 'M-3'), ('P1', 'm2'), 'P5') , 1
# ('P8', ('P5', 'M2'), ('M3', 'm2'), 'M3') , 1
# ('P8', ('M3', 'M-2'), ('P8', 'm-2'), 'm3') , 1
# ('M3', ('m2', 'm-3'), ('M6', 'M-3'), 'M6') , 1
# ('P8', ('M3', 'M-2'), ('P8', 'P4'), 'M6') , 1
# ('P8', ('P5', 'M2'), ('m-2', 'P-4'), 'm3') , 1
# ('M3', ('m2', 'm-3'), ('P4', 'A1'), 'm6') , 1
# ('P8', ('m-3', 'P1'), ('A1', 'm2'), 'P5') , 1
# ('P8', ('M3', 'M-2'), ('P5', 'M-2'), 'M6') , 1
# ('P8', ('P5', 'M2'), ('M3', 'M-2'), 'P5') , 1
# ('m6', ('m-3', 'P1'), ('M-3', 'P1'), 'M6') , 1
# ('m6', ('M2', 'P1'), ('P-4', 'm3'), 'P8') , 1
# ('m3', ('P5', 'M2'), ('m2', 'm-2'), 'P8') , 1
# ('P8', ('M2', 'm2'), ('M-2', 'P8'), 'P4') , 1
# ('M3', ('m2', 'm-3'), ('P8', 'P1'), 'M2') , 1
# ('P8', ('M2', 'P1'), ('m-2', 'm3'), 'P8') , 1
# ('m3', ('P5', 'M2'), ('P5', 'm2'), 'M3') , 1
# ('A4', ('m2', 'm-3'), ('m-2', 'm2'), 'M3') , 1
# ('M6', ('M-2', 'P1'), ('m-2', 'P4'), 'm3') , 1
# ('M6', ('M-2', 'M2'), ('P1', 'd-5'), 'm3') , 1
# ('m3', ('m2', 'M2'), ('m2', 'm-3'), 'm6') , 1
# ('m3', ('M2', 'P1'), ('m-3', 'P1'), 'm6') , 1
# ('m6', ('P5', 'M2'), ('P-4', 'M-2'), 'P8') , 1
# ('M3', ('m2', 'm-3'), ('P4', 'M2'), 'P5') , 1
# ('P8', ('m-3', 'P1'), ('M2', 'P-8'), 'P5') , 1
# ('m6', ('P1', 'm-2'), ('M-2', 'P-5'), 'M3') , 1
# ('m7', ('m-2', 'm2'), ('P-5', 'P4'), 'P8') , 1
# ('R', ('M3', 'M-2'), ('R', 'P8'), 'M2') , 1
# ('M3', ('M-2', 'M2'), ('P8', 'P1'), 'M3') , 1
# ('P8', ('P5', 'M2'), ('M3', 'P1'), 'P4') , 1
# ('P4', ('P1', 'm-2'), ('P1', 'P1'), 'M3') , 1
# ('P8', ('P5', 'P1'), ('m-6', 'm3'), 'P8') , 1
# ('P8', ('P1', 'P1'), ('P-5', 'M3'), 'm3') , 1
# ('M3', ('M-2', 'm-3'), ('M2', 'P4'), 'M3') , 1
# ('P8', ('P5', 'P1'), ('P1', 'm-2'), 'm6') , 1
# ('m6', ('P1', 'P1'), ('m2', 'm-6'), 'm3') , 1
# ('M3', ('m3', 'M2'), ('P-4', 'P1'), 'M2') , 1
# ('m3', ('M-2', 'M3'), ('m2', 'm-3'), 'P5') , 1
# ('P8', ('M3', 'm3'), ('m-3', 'M-2'), 'P8') , 1
# ('R', ('P1', 'P1'), ('R', 'P4'), 'P5') , 1
# ('m6', ('P1', 'P1'), ('m2', 'M2'), 'P4') , 1
# ('P4', ('P1', 'm-3'), ('P-5', 'M2'), 'P5') , 1
# ('M6', ('M-2', 'P1'), ('M2', 'M-2'), 'P5') , 1
# ('P5', ('M-2', 'M3'), ('m-3', 'M-3'), 'M3') , 1

# %% [markdown]
# ### 3HN Full Phrase End

# %%
def full3HNPhraseEnd(k):
    graceNotes = []
    for n in k.recurse().notes:
        if n.duration.isGrace:
            graceNotes.append(n)

    # remove grace notes  
    for grace in graceNotes:
        grace.activeSite.remove(grace)

    k_ = copy.deepcopy(k)
    k_c = k_.chordify()
    data = []
    for i in range(1, len(k_.parts[0].getElementsByClass('Measure')) + 1):
        k_mel = k_.measure(i).parts[0].asTimespans()
        k_bass = k_.measure(i).parts[1].asTimespans()
        mel = []
        bass = []
        off = k_c.measure(i).notes[-1].offset - 4

        # starting window
        har_1 = getHarmony(k_mel.getVerticalityAt(off).toChord(),
                           k_bass.getVerticalityAt(off).toChord())
        mel.append(getInterval(k_mel.getVerticalityAt(off).toChord(),
                               k_mel.getVerticalityAt(off + 2).toChord()))
        mel.append(getInterval(k_mel.getVerticalityAt(off + 2).toChord(),
                               k_mel.getVerticalityAt(off + 4).toChord()))
        bass.append(getInterval(k_bass.getVerticalityAt(off).toChord(),
                                k_bass.getVerticalityAt(off + 2).toChord()))
        bass.append(getInterval(k_bass.getVerticalityAt(off + 2).toChord(),
                                k_bass.getVerticalityAt(off + 4).toChord()))
        har_2 = getHarmony(k_mel.getVerticalityAt(off + 4).toChord(),
                           k_bass.getVerticalityAt(off + 4).toChord())
        data.append((har_1, mel.copy(), bass.copy(), har_2))
    data = map(lambda x: (x[0], tuple(x[1]), tuple(x[2]), x[3]), data)
    return data

# %%
getData(full3HNPhraseEnd, kittelBundle)
# Out:
# ('M6', ('P1', 'M-2'), ('M2', 'P-5'), 'P8') , 121
# ('P5', ('P1', 'M-2'), ('P1', 'P-5'), 'P8') , 62
# ('P5', ('P1', 'M-2'), ('P-8', 'P4'), 'P8') , 37
# ('P5', ('m-2', 'm2'), ('M2', 'P-5'), 'P8') , 29
# ('M6', ('M-2', 'M-2'), ('P-8', 'P4'), 'P8') , 22
# ('P5', ('M2', 'm2'), ('P4', 'P-5'), 'P8') , 20
# ('M2', ('P1', 'M-2'), ('m-2', 'm2'), 'P8') , 19
# ('P4', ('m-2', 'm2'), ('P-8', 'P4'), 'P8') , 16
# ('m6', ('P1', 'M-2'), ('m2', 'P-5'), 'P8') , 15
# ('M3', ('M2', 'm2'), ('m-3', 'M-2'), 'P8') , 12
# ('m7', ('m-2', 'm2'), ('P4', 'P-5'), 'P8') , 12
# ('M6', ('P1', 'M2'), ('M2', 'P-5'), 'M3') , 10
# ('M3', ('M2', 'm2'), ('M2', 'P-5'), 'P8') , 9
# ('P8', ('P1', 'M-2'), ('P4', 'P-5'), 'P8') , 9
# ('M6', ('M-2', 'M2'), ('P-8', 'P4'), 'M3') , 8
# ('P5', ('M-2', 'P1'), ('m-3', 'M-3'), 'P8') , 8
# ('P5', ('P1', 'M-2'), ('P1', 'P4'), 'P8') , 7
# ('M3', ('M-2', 'M-2'), ('P-4', 'P-5'), 'P8') , 7
# ('m6', ('m-3', 'M-2'), ('m2', 'P-4'), 'P5') , 7
# ('m6', ('P1', 'P1'), ('m2', 'P-4'), 'P8') , 7
# ('P8', ('P1', 'm-3'), ('P1', 'P4'), 'M3') , 7
# ('P4', ('m-2', 'm2'), ('P1', 'P-5'), 'P8') , 7
# ('m3', ('m-2', 'M-2'), ('M2', 'm3'), 'P5') , 7
# ('m3', ('m-2', 'M-2'), ('M-2', 'P5'), 'P5') , 6
# ('m3', ('P1', 'm-2'), ('P-5', 'P4'), 'M3') , 6
# ('m3', ('P1', 'P1'), ('P1', 'm3'), 'P8') , 6
# ('M3', ('m2', 'P1'), ('m-3', 'M-3'), 'P8') , 6
# ('M3', ('P1', 'M-2'), ('P-8', 'P5'), 'P5') , 6
# ('M3', ('P1', 'M-2'), ('m-6', 'm3'), 'P5') , 6
# ('P8', ('P1', 'm-3'), ('P1', 'P-5'), 'M3') , 6
# ('P5', ('P1', 'M2'), ('P1', 'P-5'), 'M3') , 6
# ('M6', ('M-2', 'M-2'), ('P1', 'P-5'), 'P8') , 5
# ('m6', ('m-2', 'M-2'), ('P-8', 'P4'), 'P8') , 5
# ('M2', ('P1', 'M2'), ('m-2', 'm2'), 'M3') , 5
# ('m6', ('M2', 'M2'), ('M-2', 'M-2'), 'M3') , 5
# ('m6', ('P1', 'M2'), ('m2', 'P-5'), 'M3') , 5
# ('m6', ('m-2', 'M-2'), ('m3', 'P-4'), 'P5') , 5
# ('m6', ('m-2', 'M-2'), ('P-4', 'm3'), 'P5') , 4
# ('m6', ('m-2', 'M-2'), ('M-2', 'P1'), 'P5') , 4
# ('m6', ('m-2', 'M-2'), ('M-2', 'm-2'), 'm6') , 4
# ('P5', ('M-2', 'M2'), ('M-3', 'm-2'), 'P8') , 4
# ('m6', ('P1', 'M-2'), ('M2', 'm2'), 'm3') , 4
# ('M6', ('m-3', 'M-3'), ('M2', 'P-8'), 'P8') , 4
# ('M3', ('m-2', 'm2'), ('m-2', 'P-5'), 'P8') , 4
# ('P4', ('P1', 'M-2'), ('M-2', 'P-5'), 'P8') , 4
# ('m6', ('P1', 'm-3'), ('P1', 'm2'), 'M3') , 4
# ('M3', ('M-2', 'P1'), ('P1', 'M2'), 'P8') , 4
# ('m6', ('P1', 'm-2'), ('M2', 'm2'), 'M3') , 4
# ('M6', ('P1', 'M2'), ('P1', 'm-2'), 'P8') , 4
# ('M3', ('M-3', 'M2'), ('m-6', 'm3'), 'P5') , 4
# ('M3', ('P1', 'P1'), ('P1', 'M3'), 'P8') , 4
# ('m6', ('M3', 'M-2'), ('M-3', 'P5'), 'P5') , 4
# ('P4', ('m-3', 'P1'), ('P5', 'P1'), 'P5') , 4
# ('M3', ('M-2', 'M-2'), ('P5', 'P-5'), 'P8') , 3
# ('M3', ('P1', 'M-2'), ('P1', 'P-4'), 'P5') , 3
# ('M3', ('M-2', 'M-2'), ('P-4', 'P4'), 'P8') , 3
# ('M3', ('M-2', 'm-3'), ('M2', 'P-5'), 'M3') , 3
# ('P8', ('P1', 'P1'), ('m-3', 'm3'), 'P8') , 3
# ('P4', ('P1', 'm-2'), ('m-2', 'm2'), 'M3') , 3
# ('d5', ('M-2', 'P1'), ('m2', 'M-6'), 'P8') , 3
# ('M3', ('m-2', 'm2'), ('m-2', 'm-3'), 'm6') , 3
# ('M6', ('M-2', 'M2'), ('M-2', 'M3'), 'P5') , 3
# ('P5', ('M2', 'm2'), ('P1', 'M-2'), 'P8') , 3
# ('P8', ('P1', 'm-2'), ('m-3', 'M-2'), 'M3') , 3
# ('m3', ('m-3', 'M-2'), ('P4', 'P-5'), 'P8') , 3
# ('M3', ('P1', 'M-2'), ('M3', 'm3'), 'P5') , 3
# ('P4', ('M2', 'm2'), ('M-2', 'M-2'), 'P8') , 3
# ('P8', ('P1', 'M-2'), ('M-3', 'P5'), 'P5') , 3
# ('P8', ('M-2', 'M2'), ('m2', 'm-2'), 'P8') , 3
# ('m6', ('m-2', 'M-2'), ('P1', 'P-5'), 'P8') , 3
# ('m6', ('P1', 'M-2'), ('d1', 'm-2'), 'm6') , 3
# ('M6', ('P1', 'm-2'), ('P4', 'm-2'), 'M3') , 3
# ('m6', ('m-2', 'm2'), ('M-2', 'M-2'), 'P8') , 3
# ('m7', ('m-2', 'm2'), ('P1', 'M-2'), 'P8') , 3
# ('m6', ('m-2', 'm2'), ('P1', 'P-5'), 'm3') , 3
# ('m3', ('P1', 'm-2'), ('P4', 'P-5'), 'M3') , 3
# ('P5', ('P1', 'M2'), ('P1', 'P4'), 'M3') , 3
# ('P8', ('m-2', 'M-2'), ('P-4', 'P5'), 'P5') , 3
# ('m6', ('P1', 'M-2'), ('m2', 'm-3'), 'm6') , 3
# ('m3', ('M2', 'M2'), ('M-3', 'm-2'), 'P8') , 3
# ('P8', ('M2', 'm2'), ('M-2', 'm-3'), 'm6') , 3
# ('d5', ('m-2', 'M-2'), ('m2', 'P-4'), 'P5') , 3
# ('M3', ('M-2', 'P1'), ('P5', 'P1'), 'P5') , 3
# ('M3', ('P1', 'M-2'), ('m-3', 'm-3'), 'm6') , 3
# ('m3', ('m-2', 'M-2'), ('P5', 'm-3'), 'm6') , 2
# ('M3', ('M-2', 'm-3'), ('M2', 'M2'), 'P5') , 2
# ('P8', ('m-3', 'M-2'), ('M2', 'm-3'), 'm6') , 2
# ('m3', ('M3', 'm3'), ('P1', 'M2'), 'm6') , 2
# ('m3', ('m-3', 'M-2'), ('P1', 'm3'), 'P5') , 2
# ('m6', ('M3', 'm3'), ('M-3', 'm-2'), 'm6') , 2
# ('P8', ('M-2', 'm-3'), ('M2', 'm2'), 'M3') , 2
# ('P8', ('P1', 'P1'), ('P4', 'P-4'), 'P8') , 2
# ('M3', ('M-2', 'M-2'), ('P-4', 'M2'), 'm3') , 2
# ('M6', ('P1', 'M-2'), ('P1', 'm-2'), 'm6') , 2
# ('m3', ('P1', 'm-2'), ('P1', 'P-4'), 'P5') , 2
# ('A4', ('P1', 'M-2'), ('m-2', 'm-3'), 'm6') , 2
# ('M3', ('M-2', 'M2'), ('P-5', 'M3'), 'P5') , 2
# ('m6', ('M-2', 'M-2'), ('M-3', 'P4'), 'm3') , 2
# ('M2', ('P1', 'M-2'), ('m-2', 'M-2'), 'm3') , 2
# ('P8', ('m-3', 'M-2'), ('M2', 'P-5'), 'P8') , 2
# ('m6', ('M2', 'M-2'), ('m3', 'P-5'), 'P8') , 2
# ('P8', ('M-2', 'M-2'), ('P1', 'P-5'), 'm3') , 2
# ('P4', ('M2', 'M-2'), ('P-8', 'P4'), 'P8') , 2
# ('P4', ('m-2', 'm2'), ('P-8', 'm2'), 'M3') , 2
# ('m6', ('m-3', 'M-3'), ('m2', 'P1'), 'P8') , 2
# ('P8', ('m-2', 'M-2'), ('M3', 'P-5'), 'P8') , 2
# ('P8', ('P1', 'm-3'), ('P1', 'M2'), 'P5') , 2
# ('P4', ('P1', 'M-2'), ('m-2', 'm2'), 'm3') , 2
# ('M3', ('m-2', 'm2'), ('m-2', 'P4'), 'P8') , 2
# ('M6', ('P1', 'M-2'), ('M2', 'm2'), 'M3') , 2
# ('M6', ('P1', 'm-2'), ('m-2', 'P4'), 'M3') , 2
# ('d5', ('m-2', 'm2'), ('m2', 'P-5'), 'P8') , 2
# ('M3', ('P1', 'M-2'), ('A1', 'm2'), 'P8') , 2
# ('P4', ('m-2', 'm2'), ('P1', 'P4'), 'P8') , 2
# ('P4', ('m-2', 'm2'), ('A1', 'm2'), 'm3') , 2
# ('A4', ('P1', 'M-2'), ('m-2', 'P-5'), 'P8') , 2
# ('m6', ('P1', 'M2'), ('m2', 'P4'), 'M3') , 2
# ('M6', ('M-2', 'M2'), ('P1', 'P4'), 'M3') , 2
# ('m6', ('M2', 'M2'), ('P-4', 'm2'), 'M3') , 2
# ('m3', ('M2', 'M2'), ('M2', 'm2'), 'M3') , 2
# ('m3', ('M-2', 'm-2'), ('m2', 'P-4'), 'M3') , 2
# ('P8', ('M2', 'M2'), ('m-2', 'm2'), 'M3') , 2
# ('P5', ('P1', 'P1'), ('P1', 'P-4'), 'P8') , 2
# ('m3', ('M2', 'M2'), ('M-2', 'P4'), 'M3') , 2
# ('M3', ('M-3', 'M2'), ('M3', 'm3'), 'P5') , 2
# ('m3', ('m-2', 'M-2'), ('M2', 'M-6'), 'P5') , 2
# ('M6', ('P1', 'M2'), ('m-3', 'M-2'), 'M3') , 2
# ('P8', ('P1', 'P1'), ('P1', 'P1'), 'P8') , 2
# ('P8', ('m-3', 'M-2'), ('P4', 'P-4'), 'P5') , 2
# ('P4', ('P1', 'M2'), ('M-2', 'P4'), 'M3') , 2
# ('m3', ('P1', 'M-2'), ('P1', 'm2'), 'P8') , 2
# ('P4', ('P1', 'M2'), ('M2', 'm2'), 'M3') , 2
# ('m3', ('M2', 'M2'), ('P1', 'm-2'), 'm6') , 2
# ('P8', ('P1', 'm-2'), ('M2', 'P-5'), 'M3') , 2
# ('m6', ('m-3', 'P1'), ('m2', 'P-8'), 'M3') , 2
# ('M3', ('P1', 'M-3'), ('P1', 'P-5'), 'P5') , 2
# ('P8', ('P1', 'M-3'), ('P1', 'P4'), 'm3') , 2
# ('M6', ('M-2', 'M2'), ('P1', 'P-5'), 'M3') , 2
# ('M3', ('M-2', 'M2'), ('P-4', 'P4'), 'M3') , 2
# ('m6', ('P1', 'm-3'), ('M-3', 'P4'), 'M3') , 2
# ('m3', ('P1', 'm-3'), ('m3', 'P-5'), 'M3') , 2
# ('M6', ('P1', 'M-2'), ('M2', 'm-3'), 'm6') , 1
# ('m3', ('m-2', 'M-2'), ('P4', 'P-4'), 'P8') , 1
# ('M6', ('M-2', 'M-2'), ('R', 'R'), 'P8') , 1
# ('P4', ('m-2', 'm2'), ('P1', 'M-3'), 'M6') , 1
# ('m3', ('M3', 'm3'), ('P1', 'M-2'), 'P8') , 1
# ('m6', ('M3', 'm3'), ('P4', 'M-2'), 'P8') , 1
# ('A4', ('P1', 'M-2'), ('m-2', 'M-3'), 'M6') , 1
# ('m3', ('M3', 'm3'), ('P1', 'P-4'), 'm3') , 1
# ('m3', ('P1', 'm-2'), ('m3', 'm-6'), 'P5') , 1
# ('M6', ('M-2', 'M-2'), ('A1', 'm2'), 'm3') , 1
# ('P5', ('M2', 'm2'), ('P-5', 'P4'), 'P8') , 1
# ('m3', ('P1', 'm-2'), ('P1', 'M2'), 'P8') , 1
# ('P4', ('P1', 'P1'), ('M-2', 'P5'), 'P8') , 1
# ('m3', ('P1', 'm-2'), ('m-3', 'm-3'), 'm6') , 1
# ('P5', ('M-2', 'M-2'), ('P-4', 'P4'), 'm3') , 1
# ('M6', ('P1', 'M-2'), ('d-7', 'm2'), 'm3') , 1
# ('P5', ('M-2', 'M-2'), ('m-2', 'm2'), 'm3') , 1
# ('P8', ('M-2', 'M-2'), ('m3', 'M2'), 'm3') , 1
# ('P8', ('M2', 'M-2'), ('P5', 'P-5'), 'P8') , 1
# ('P8', ('M2', 'M-2'), ('P8', 'P1'), 'P8') , 1
# ('M6', ('M-2', 'M-2'), ('M-2', 'm-2'), 'm6') , 1
# ('m3', ('M2', 'M-2'), ('M2', 'm2'), 'P8') , 1
# ('M3', ('M2', 'm2'), ('P1', 'M-2'), 'M6') , 1
# ('m3', ('m-3', 'M-2'), ('P-5', 'P4'), 'P8') , 1
# ('m3', ('m-3', 'M-2'), ('P4', 'M2'), 'm3') , 1
# ('m3', ('M-2', 'M2'), ('m2', 'd-5'), 'm6') , 1
# ('M2', ('M2', 'm2'), ('P-8', 'P4'), 'P8') , 1
# ('P8', ('m-2', 'm2'), ('M2', 'm2'), 'M6') , 1
# ('M3', ('M-2', 'M2'), ('P5', 'P-5'), 'M3') , 1
# ('M3', ('M-2', 'M-2'), ('d-4', 'm2'), 'm3') , 1
# ('P8', ('M2', 'M-2'), ('m-2', 'm2'), 'P8') , 1
# ('m3', ('m-3', 'M-2'), ('M2', 'P-5'), 'm3') , 1
# ('M3', ('M2', 'm2'), ('M2', 'P4'), 'P8') , 1
# ('M3', ('P1', 'M-2'), ('P1', 'P5'), 'P5') , 1
# ('M3', ('M2', 'm2'), ('M2', 'M2'), 'm3') , 1
# ('M3', ('P1', 'M-2'), ('P8', 'P-4'), 'P5') , 1
# ('M2', ('M2', 'm2'), ('M-2', 'm-2'), 'm6') , 1
# ('m3', ('m-2', 'M-2'), ('P5', 'P-5'), 'P8') , 1
# ('P8', ('m-3', 'M-3'), ('P4', 'P-8'), 'P8') , 1
# ('m6', ('m-3', 'M-3'), ('m2', 'P-8'), 'P8') , 1
# ('P5', ('M-2', 'M2'), ('P1', 'm-2'), 'm6') , 1
# ('A2', ('m2', 'P1'), ('m-2', 'P-5'), 'P8') , 1
# ('P8', ('P1', 'm-3'), ('m-3', 'M-3'), 'M3') , 1
# ('P8', ('P1', 'm-2'), ('m3', 'M3'), 'M3') , 1
# ('P8', ('P1', 'm-2'), ('M-3', 'm-2'), 'M3') , 1
# ('P8', ('P1', 'm-2'), ('P4', 'M2'), 'M3') , 1
# ('R', ('P1', 'M-2'), ('R', 'P-5'), 'P8') , 1
# ('m6', ('P1', 'M-2'), ('P4', 'P-5'), 'm6') , 1
# ('M3', ('P1', 'P1'), ('M3', 'P-8'), 'P8') , 1
# ('M6', ('P1', 'M2'), ('m-3', 'P5'), 'P5') , 1
# ('M3', ('P1', 'M2'), ('P1', 'm-2'), 'P5') , 1
# ('m3', ('m-2', 'm2'), ('M-2', 'm-3'), 'm6') , 1
# ('P4', ('m-2', 'm2'), ('P1', 'm-3'), 'm6') , 1
# ('P4', ('m-2', 'm2'), ('P-4', 'M2'), 'm6') , 1
# ('m6', ('P1', 'M2'), ('m2', 'A1'), 'm6') , 1
# ('P8', ('m-2', 'm2'), ('P-4', 'P4'), 'P8') , 1
# ('P8', ('M-2', 'm-2'), ('M2', 'm3'), 'M3') , 1
# ('P8', ('M-2', 'm-2'), ('A1', 'm2'), 'P5') , 1
# ('m3', ('P1', 'm-2'), ('m3', 'M3'), 'P5') , 1
# ('d5', ('M-2', 'm-2'), ('m2', 'M2'), 'P8') , 1
# ('P4', ('M2', 'M2'), ('P-8', 'P4'), 'M3') , 1
# ('m6', ('M-2', 'm-2'), ('m3', 'P-4'), 'P5') , 1
# ('m3', ('P1', 'm-2'), ('P-8', 'P5'), 'P5') , 1
# ('m3', ('M-2', 'm-2'), ('m2', 'M3'), 'P5') , 1
# ('P5', ('M-2', 'm-2'), ('P1', 'P1'), 'M3') , 1
# ('P8', ('M2', 'M2'), ('P4', 'm-2'), 'P8') , 1
# ('m6', ('P1', 'm-2'), ('m2', 'M2'), 'M3') , 1
# ('P4', ('M2', 'M2'), ('M-2', 'm-2'), 'P8') , 1
# ('m3', ('P1', 'P1'), ('m3', 'P-5'), 'P5') , 1
# ('M3', ('M-3', 'M2'), ('P-8', 'P5'), 'P5') , 1
# ('P8', ('P1', 'M2'), ('P4', 'P-5'), 'M3') , 1
# ('m3', ('M3', 'M-2'), ('P-4', 'm3'), 'P5') , 1
# ('P4', ('P1', 'P1'), ('P-5', 'P4'), 'P5') , 1
# ('P8', ('P1', 'P1'), ('P-8', 'P4'), 'P5') , 1
# ('P8', ('M-3', 'M2'), ('P4', 'm-3'), 'm6') , 1
# ('M3', ('P1', 'M-2'), ('m-6', 'M2'), 'm6') , 1
# ('P5', ('P1', 'P1'), ('m-2', 'm2'), 'P5') , 1
# ('m6', ('M-3', 'M2'), ('m2', 'm-3'), 'm6') , 1
# ('M3', ('P1', 'M-2'), ('P1', 'P1'), 'M2') , 1
# ('m3', ('P1', 'P1'), ('P-4', 'm2'), 'P5') , 1
# ('M3', ('M-3', 'M2'), ('P1', 'P1'), 'M2') , 1
# ('P8', ('P1', 'P1'), ('P1', 'P4'), 'P5') , 1
# ('M3', ('M-3', 'M2'), ('P1', 'P5'), 'P5') , 1
# ('m3', ('m-2', 'M-2'), ('P-4', 'P-5'), 'P8') , 1
# ('m3', ('P1', 'P1'), ('M-2', 'M-2'), 'P5') , 1
# ('M3', ('M-3', 'M2'), ('m-3', 'm-3'), 'm6') , 1
# ('M3', ('P1', 'M-2'), ('P1', 'd-5'), 'm6') , 1
# ('m6', ('P1', 'P1'), ('m3', 'M-2'), 'P5') , 1
# ('M3', ('M-3', 'm-2'), ('M2', 'P-5'), 'M3') , 1
# ('P8', ('P1', 'P1'), ('P1', 'P-8'), 'P8') , 1
# ('P8', ('M-3', 'm-2'), ('P4', 'P-4'), 'P5') , 1
# ('m6', ('M-3', 'm-2'), ('m2', 'M2'), 'P8') , 1
# ('M3', ('P1', 'P1'), ('P1', 'm-6'), 'P8') , 1
# ('P8', ('M-3', 'm-2'), ('P4', 'd-5'), 'm6') , 1
# ('M3', ('P1', 'P1'), ('m-3', 'P-4'), 'P8') , 1
# ('M6', ('P1', 'M2'), ('d-5', 'm-3'), 'm6') , 1
# ('m6', ('M-3', 'm-2'), ('m2', 'P-4'), 'P5') , 1
# ('m6', ('M-3', 'm-2'), ('m2', 'P1'), 'M2') , 1
# ('P5', ('P1', 'M2'), ('P1', 'A1'), 'm6') , 1
# ('m6', ('M-3', 'm-2'), ('m2', 'd-5'), 'm6') , 1
# ('M3', ('P1', 'P1'), ('m-3', 'P5'), 'P8') , 1
# ('P5', ('M-3', 'm-2'), ('P4', 'P-5'), 'M3') , 1
# ('P5', ('P4', 'm-3'), ('m-3', 'M-3'), 'M3') , 1
# ('P4', ('P1', 'M2'), ('m3', 'd-4'), 'm6') , 1
# ('M6', ('M-3', 'm-2'), ('m-2', 'm2'), 'M3') , 1
# ('m6', ('m-3', 'M-2'), ('m2', 'd-5'), 'm6') , 1
# ('m3', ('M2', 'M2'), ('m6', 'd-7'), 'm6') , 1
# ('P5', ('m-3', 'M-2'), ('M3', 'm3'), 'P5') , 1
# ('m6', ('P1', 'M2'), ('m2', 'd-5'), 'm3') , 1
# ('m3', ('m-3', 'M-2'), ('M-3', 'P-4'), 'P5') , 1
# ('m3', ('P1', 'M2'), ('M-3', 'P4'), 'M3') , 1
# ('M2', ('m-3', 'M-2'), ('A1', 'm2'), 'P5') , 1
# ('P4', ('P1', 'M2'), ('M-2', 'P-5'), 'M3') , 1
# ('m3', ('P1', 'P1'), ('M-2', 'P4'), 'P8') , 1
# ('m3', ('M2', 'M2'), ('M-3', 'M3'), 'P5') , 1
# ('m6', ('M3', 'M-2'), ('M-3', 'P1'), 'M2') , 1
# ('m3', ('M2', 'M2'), ('m6', 'm-2'), 'P8') , 1
# ('P4', ('M3', 'M-2'), ('m-3', 'm3'), 'P5') , 1
# ('P8', ('M3', 'M-2'), ('P8', 'P-4'), 'P5') , 1
# ('P5', ('m-2', 'm2'), ('M2', 'P4'), 'P8') , 1
# ('M6', ('M2', 'm2'), ('m-2', 'M-2'), 'm3') , 1
# ('A2', ('m2', 'P1'), ('m-2', 'P4'), 'P8') , 1
# ('P8', ('M2', 'm2'), ('M-2', 'P4'), 'P8') , 1
# ('M3', ('M2', 'm2'), ('m-3', 'm2'), 'M6') , 1
# ('P5', ('m-2', 'm2'), ('m-3', 'M-2'), 'P8') , 1
# ('m3', ('P1', 'm-2'), ('d1', 'm-2'), 'M3') , 1
# ('M3', ('M-2', 'P1'), ('P5', 'P-8'), 'P5') , 1
# ('m6', ('P1', 'm-2'), ('M-2', 'P4'), 'M3') , 1
# ('P8', ('M-2', 'P1'), ('m3', 'P1'), 'P5') , 1
# ('P8', ('M-2', 'P1'), ('m3', 'P-8'), 'P5') , 1
# ('M3', ('M-2', 'P1'), ('P-4', 'P1'), 'P5') , 1
# ('m3', ('P1', 'm-2'), ('M-6', 'M3'), 'P5') , 1
# ('M3', ('M-2', 'P1'), ('m-2', 'M-3'), 'P5') , 1
# ('m3', ('m-2', 'm2'), ('P-4', 'P-5'), 'm3') , 1
# ('P4', ('m-2', 'm2'), ('M-2', 'm-2'), 'm6') , 1
# ('P8', ('P1', 'M-2'), ('P4', 'm-3'), 'm6') , 1
# ('m3', ('m-2', 'm2'), ('P-4', 'm-2'), 'd7') , 1
# ('M3', ('P1', 'M-2'), ('P-8', 'M2'), 'P8') , 1
# ('P4', ('P1', 'M-2'), ('M-2', 'm-3'), 'm6') , 1
# ('P4', ('m-2', 'm2'), ('M-2', 'M-2'), 'M6') , 1
# ('M6', ('M-2', 'P1'), ('m-2', 'M-3'), 'P8') , 1
# ('m3', ('m-2', 'M-2'), ('P-4', 'm-3'), 'm6') , 1
# ('m3', ('m-2', 'M-2'), ('P-5', 'P-4'), 'P8') , 1
# ('m6', ('m-2', 'M-2'), ('m3', 'P1'), 'M2') , 1
# ('M3', ('M-2', 'P1'), ('d-5', 'R'), 'R') , 1
# ('M3', ('M-2', 'M-2'), ('P-5', 'P-4'), 'P8') , 1
# ('M3', ('M-3', 'M2'), ('m-3', 'M-2'), 'P5') , 1
# ('m6', ('M-3', 'M2'), ('m2', 'M-2'), 'P5') , 1
# ('P8', ('m-3', 'P1'), ('P-5', 'P1'), 'M3') , 1
# ('M2', ('m-3', 'P1'), ('M3', 'P1'), 'P5') , 1
# ('M3', ('M-3', 'M2'), ('M6', 'M-2'), 'P5') , 1
# ('M3', ('M-3', 'M2'), ('P8', 'P-4'), 'P5') , 1
# ('M6', ('M-2', 'M2'), ('M-2', 'm-2'), 'P8') , 1
# ('P5', ('M-2', 'M2'), ('m2', 'm-2'), 'P5') , 1
# ('P5', ('P1', 'M-3'), ('m-2', 'm2'), 'm3') , 1
# ('M6', ('P1', 'M-2'), ('M2', 'M2'), 'm3') , 1
# ('M3', ('P1', 'M-3'), ('P1', 'P4'), 'P5') , 1
# ('M3', ('P1', 'M-3'), ('M3', 'P-5'), 'm3') , 1
# ('P8', ('P1', 'M-3'), ('P1', 'm2'), 'P5') , 1
# ('P8', ('M-2', 'M2'), ('m3', 'P-5'), 'M3') , 1
# ('m7', ('m-2', 'm2'), ('P-5', 'P4'), 'P8') , 1
# ('M3', ('M-2', 'm-3'), ('M2', 'P4'), 'M3') , 1
# ('P8', ('M3', 'm3'), ('m-3', 'M-2'), 'P8') , 1
